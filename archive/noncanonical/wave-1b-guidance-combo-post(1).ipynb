# %% [markdown]
# # FreeFine — Wave 1B — Exhaustive Core Metrics — Guidance/Combo/Post Family
# BGC, SUBC, WRAP_E, MD across 20 task/difficulty groups.

# %% [markdown]
# ## 1. Clone pinned FreeFine

# %%
# ===== Clone pinned FreeFine + clock =====
import os,time,subprocess,json,glob,shutil,csv,re,hashlib,random
NB_START=time.time()
COMMIT="4c9fdb971572b32edbeac13464659274c28decbb"
subprocess.run(
    f"mkdir -p /kaggle/temp && cd /kaggle/temp && rm -rf FreeFine && "
    f"git clone -q https://github.com/CIawevy/FreeFine.git && "
    f"cd FreeFine && git checkout -q {COMMIT}",
    shell=True,check=True
)
print("✓ cloned + pinned FreeFine",COMMIT[:14])
# Out:
# ✓ cloned + pinned FreeFine 4c9fdb971572b3

# %% [markdown]
# ## 2. Metric environment

# %%
# %%bash
# set -e
# V=/kaggle/temp/metric_env
# PY=$V/bin/python
# REPO=/kaggle/temp/FreeFine
# rm -rf "$V"
# uv venv --python 3.10.13 "$V"
# uv pip install --python "$PY" torch==2.6.0 torchvision==0.21.0 torchaudio==2.6.0 --index-url https://download.pytorch.org/whl/cu124
# uv pip install --python "$PY" "setuptools<70" wheel pip
# grep -vi '^clip' $REPO/evaluation/metrics/requirements.txt > /tmp/m.txt
# uv pip install --python "$PY" -r /tmp/m.txt
# uv pip install --python "$PY" "setuptools<70"
# uv pip install --python "$PY" --no-build-isolation "clip @ git+https://github.com/openai/CLIP.git@dcba3cb2e2827b402d2701e7e1c7d9fed8a20ef1"
# uv pip install --python "$PY" "pyarrow<16" "datasets<3"
# wget -q https://dl.fbaipublicfiles.com/mmf/clip/bpe_simple_vocab_16e6.txt.gz -P /tmp
# for d in $(find $V -path '*/site-packages/clip' -o -path '*open_clip' -type d); do
#   cp /tmp/bpe_simple_vocab_16e6.txt.gz "$d/" 2>/dev/null || true
# done
# echo "✓ metric_env OK"
# Out:
# ✓ metric_env OK
# warning: The `--system` flag has no effect, `uv venv` always ignores virtual environments when finding a Python interpreter; did you mean `--no-managed-python`?
# Downloading cpython-3.10.13-linux-x86_64-gnu (download) (26.1MiB)
#  Downloaded cpython-3.10.13-linux-x86_64-gnu (download)
# Using CPython 3.10.13
# Creating virtual environment at: /kaggle/temp/metric_env
# Activate with: source /kaggle/temp/metric_env/bin/activate
# Using Python 3.10.13 environment at: /kaggle/temp/metric_env
# Resolved 27 packages in 592ms
# Downloading pillow (6.6MiB)
# Downloading nvidia-cublas-cu12 (346.6MiB)
# Downloading nvidia-cudnn-cu12 (634.0MiB)
# Downloading torchaudio (3.3MiB)
# Downloading nvidia-cusparselt-cu12 (143.1MiB)
# Downloading numpy (16.0MiB)
# Downloading sympy (5.9MiB)
# Downloading networkx (1.6MiB)
# Downloading torchvision (6.9MiB)
# Downloading triton (158.9MiB)
# Downloading torch (732.8MiB)
# Downloading nvidia-nccl-cu12 (179.9MiB)
# Downloading nvidia-cufft-cu12 (201.7MiB)
# Downloading nvidia-cuda-nvrtc-cu12 (23.5MiB)
# Downloading nvidia-cusparse-cu12 (197.8MiB)
# Downloading nvidia-cuda-cupti-cu12 (13.2MiB)
# Downloading nvidia-cusolver-cu12 (122.0MiB)
# Downloading nvidia-nvjitlink-cu12 (20.1MiB)
# Downloading nvidia-curand-cu12 (53.7MiB)
#  Downloaded torchaudio
#  Downloaded nvidia-cuda-cupti-cu12
#  Downloaded nvidia-nvjitlink-cu12
#  Downloaded nvidia-cuda-nvrtc-cu12
#  Downloaded torchvision
#  Downloaded pillow
#  Downloaded networkx
#  Downloaded nvidia-cublas-cu12
#  Downloaded nvidia-nccl-cu12
#  Downloaded nvidia-curand-cu12
#  Downloaded nvidia-cusparse-cu12
#  Downloaded nvidia-cudnn-cu12
#  Downloaded nvidia-cusparselt-cu12
#  Downloaded nvidia-cusolver-cu12
#  Downloaded nvidia-cufft-cu12
#  Downloaded sympy
#  Downloaded triton
#  Downloaded numpy
#  Downloaded torch
# Prepared 27 packages in 31.33s
# Installed 27 packages in 362ms
#  + filelock==3.32.3
#  + fsspec==2026.7.0
#  + jinja2==3.1.6
#  + markupsafe==3.0.3
#  + mpmath==1.3.0
#  + networkx==3.4.2
#  + numpy==2.2.6
#  + nvidia-cublas-cu12==12.4.5.8
#  + nvidia-cuda-cupti-cu12==12.4.127
#  + nvidia-cuda-nvrtc-cu12==12.4.127
#  + nvidia-cuda-runtime-cu12==12.4.127
#  + nvidia-cudnn-cu12==9.1.0.70
#  + nvidia-cufft-cu12==11.2.1.3
#  + nvidia-curand-cu12==10.3.5.147
#  + nvidia-cusolver-cu12==11.6.1.9
#  + nvidia-cusparse-cu12==12.3.1.170
#  + nvidia-cusparselt-cu12==0.6.2
#  + nvidia-nccl-cu12==2.21.5
#  + nvidia-nvjitlink-cu12==12.4.127
#  + nvidia-nvtx-cu12==12.4.127
#  + pillow==12.3.0
#  + sympy==1.13.1
#  + torch==2.6.0+cu124
#  + torchaudio==2.6.0+cu124
#  + torchvision==0.21.0+cu124
#  + triton==3.2.0
#  + typing-extensions==4.16.0
# Using Python 3.10.13 environment at: /kaggle/temp/metric_env
# Resolved 4 packages in 207ms
# Downloading pip (1.7MiB)
#  Downloaded pip
# Prepared 4 packages in 215ms
# Installed 4 packages in 1.38s
#  + packaging==26.3
#  + pip==26.2.1
#  + setuptools==69.5.1
#  + wheel==0.48.0
# Using Python 3.10.13 environment at: /kaggle/temp/metric_env
# Resolved 95 packages in 2.93s
# Downloading transformers (9.2MiB)
# Downloading tokenizers (3.0MiB)
# Downloading protobuf (1.0MiB)
# Downloading pyarrow (47.7MiB)
# Downloading scipy (35.9MiB)
# Downloading sentencepiece (1.3MiB)
# Downloading matplotlib (8.2MiB)
# Downloading aiohttp (1.6MiB)
# Downloading pandas (12.2MiB)
# Downloading fonttools (5.0MiB)
# Downloading kiwisolver (1.6MiB)
# Downloading diffusers (3.1MiB)
# Downloading scikit-learn (12.9MiB)
# Downloading opencv-python (60.1MiB)
# Downloading numpy (15.6MiB)
# Downloading hpsv2 (7.3MiB)
#    Building fairscale==0.4.13
#    Building clint==0.5.1
#    Building args==0.1.0
#  Downloaded protobuf
#  Downloaded sentencepiece
#       Built args==0.1.0
#       Built clint==0.5.1
#  Downloaded kiwisolver
#  Downloaded aiohttp
#       Built fairscale==0.4.13
#  Downloaded tokenizers
#  Downloaded diffusers
#  Downloaded fonttools
#  Downloaded hpsv2
#  Downloaded matplotlib
#  Downloaded scikit-learn
#  Downloaded numpy
#  Downloaded transformers
#  Downloaded opencv-python
#  Downloaded pandas
#  Downloaded scipy
#  Downloaded pyarrow
# Prepared 69 packages in 4.25s
# Uninstalled 1 package in 21ms
# Installed 69 packages in 1.06s
#  + accelerate==1.3.0
#  + aiohappyeyeballs==2.7.1
#  + aiohttp==3.14.3
#  + aiosignal==1.4.0
#  + args==0.1.0
#  + async-timeout==5.0.1
#  + attrs==26.1.0
#  + braceexpand==0.1.7
#  + certifi==2026.7.22
#  + charset-normalizer==3.5.1
#  + clint==0.5.1
#  + cloudpickle==3.1.2
#  + contourpy==1.3.2
#  + cycler==0.12.1
#  + datasets==2.14.4
#  + diffusers==0.32.2
#  + dill==0.3.7
#  + einops==0.8.2
#  + exceptiongroup==1.3.1
#  + fairscale==0.4.13
#  + fonttools==4.64.0
#  + frozenlist==1.8.0
#  + ftfy==6.3.1
#  + hpsv2==1.2.0
#  + huggingface-hub==0.28.1
#  + idna==3.19
#  + image-reward==1.5
#  + importlib-metadata==9.0.1
#  + iniconfig==2.3.0
#  + joblib==1.6.0
#  + kiwisolver==1.5.1
#  + matplotlib==3.10.3
#  + multidict==6.7.1
#  + multiprocess==0.70.15
#  - numpy==2.2.6
#  + numpy==2.2.2
#  + opencv-python==4.11.0.86
#  + pandas==2.3.3
#  + pluggy==1.6.0
#  + propcache==0.5.2
#  + protobuf==3.20.3
#  + psutil==7.2.2
#  + pyarrow==25.0.1
#  + pyparsing==3.3.2
#  + pytest==7.2.0
#  + pytest-split==0.8.0
#  + python-dateutil==2.9.0.post0
#  + pytorch-fid==0.3.0
#  + pytz==2026.3.post1
#  + pyyaml==6.0.3
#  + regex==2026.9.3
#  + requests==2.34.2
#  + safetensors==0.8.0
#  + scikit-learn==1.6.1
#  + scipy==1.15.3
#  + sentencepiece==0.2.2
#  + six==1.17.0
#  + threadpoolctl==3.6.0
#  + timm==0.6.13
#  + tokenizers==0.21.4
#  + tomli==2.4.1
#  + tqdm==4.70.0
#  + transformers==4.48.3
#  + tzdata==2026.3
#  + urllib3==2.7.0
#  + wcwidth==0.8.3
#  + webdataset==1.0.2
#  + xxhash==4.0.1
#  + yarl==1.24.5
#  + zipp==4.1.0
# Using Python 3.10.13 environment at: /kaggle/temp/metric_env
# Checked 1 package in 3ms
# Using Python 3.10.13 environment at: /kaggle/temp/metric_env
#    Updating https://github.com/openai/CLIP.git (dcba3cb2e2827b402d2701e7e1c7d9fed8a20ef1)
#     Updated https://github.com/openai/CLIP.git (dcba3cb2e2827b402d2701e7e1c7d9fed8a20ef1)
# Resolved 32 packages in 5.22s
#    Building clip @ git+https://github.com/openai/CLIP.git@dcba3cb2e2827b402d2701e7e1c7d9fed8a20ef1
#       Built clip @ git+https://github.com/openai/CLIP.git@dcba3cb2e2827b402d2701e7e1c7d9fed8a20ef1
# Prepared 1 package in 498ms
# Installed 1 package in 1ms
#  + clip==1.0 (from git+https://github.com/openai/CLIP.git@dcba3cb2e2827b402d2701e7e1c7d9fed8a20ef1)
# Using Python 3.10.13 environment at: /kaggle/temp/metric_env
# Resolved 32 packages in 152ms
# Downloading pyarrow (36.6MiB)
# Downloading numpy (17.4MiB)
#  Downloaded pyarrow
#  Downloaded numpy
# Prepared 2 packages in 1.05s
# Uninstalled 2 packages in 33ms
# Installed 2 packages in 28ms
#  - numpy==2.2.2
#  + numpy==1.26.4
#  - pyarrow==25.0.1
#  + pyarrow==15.0.2

# %% [markdown]
# ## 3. Deterministic metric patches

# %%
# ===== Deterministic metric patches =====
import pathlib,re,py_compile
mr=pathlib.Path("/kaggle/temp/FreeFine/evaluation/metrics")
mp=mr/"main.py"
s=mp.read_text()
s=s.replace("args.3d","getattr(args,'3d')")
anchor="    args = parser.parse_args()\n"
assert anchor in s
seed_patch=anchor+"""    # Reproducible metric-side RNG (especially KD and model initialization paths)
    import random as _random, numpy as _np
    try:
        import torch as _torch
    except Exception:
        _torch=None
    _metric_seed=int(os.environ.get('FF_METRIC_SEED','42'))
    _random.seed(_metric_seed); _np.random.seed(_metric_seed)
    if _torch is not None:
        _torch.manual_seed(_metric_seed)
        if _torch.cuda.is_available(): _torch.cuda.manual_seed_all(_metric_seed)
"""
s=s.replace(anchor,seed_patch,1)
mp.write_text(s)

for f in [mr/"MD"/"mean_distance.py",mr/"MD"/"dift_sd.py"]:
    f.write_text(f.read_text().replace(
        "stabilityai/stable-diffusion-2-1",
        "sd2-community/stable-diffusion-2-1"
    ))

md=mr/"MD"/"mean_distance.py"
s=md.read_text()
needle="all_dist = []"
assert needle in s
s=s.replace(
    needle,
    needle+"\n    import torch as _st, os as _os; "
           "_seed=int(_os.environ.get('FF_MD_SEED','42')); "
           "_st.manual_seed(_seed); _st.cuda.manual_seed_all(_seed)",
    1
)
md.write_text(s)
for f in [mr/"main.py",mr/"MD"/"mean_distance.py",mr/"MD"/"dift_sd.py"]:
    py_compile.compile(str(f),doraise=True)
print("✓ deterministic metric patches installed")
# Out:
# ✓ deterministic metric patches installed

# %% [markdown]
# ## 4. Exact balanced-200 and expanded groups

# %%
# ===== Exact historical balanced-200 + expanded analysis groups =====
import os,glob,json,csv,random,shutil,hashlib
from collections import defaultdict,Counter
GEO="/kaggle/temp/GeoBenchMeta"
os.makedirs(f"{GEO}/Geo-Bench-2D",exist_ok=True)

def one(pattern,desc):
    xs=glob.glob(pattern,recursive=True)
    if not xs:
        raise FileNotFoundError(
            f"Missing {desc}. Attach the same original GeoBench inputs used by the final generation notebooks. Pattern={pattern}"
        )
    return xs[0]

cc=[c for c in glob.glob("/kaggle/input/**/Geo-Bench-2D",recursive=True)
    if os.path.isdir(f"{c}/source_img")]
if not cc:
    raise FileNotFoundError("Geo-Bench-2D/source_img not found under /kaggle/input")
CACHE=cc[0]
COARSE=one("/kaggle/input/**/coarse_img/*/*/*.png","coarse_img").split("/coarse_img/")[0]+"/coarse_img"
GENBASE=one("/kaggle/input/**/gen_results_2d_final/gen_results_2d_backup","baseline generation directory")
IB=os.path.dirname(os.path.dirname(os.path.dirname(
    one("/kaggle/input/**/inp_img_blended/**/inp_img.png","inp_img_blended")
)))
ANNs=one("/kaggle/input/**/annotation_2d.json","annotation_2d.json")
META=one("/kaggle/input/**/sample_metadata.csv","sample_metadata.csv")

for nm in ["source_img","source_mask","target_mask","source_img_full_v2"]:
    d=f"{GEO}/Geo-Bench-2D/{nm}"
    if os.path.lexists(d):
        os.remove(d) if os.path.islink(d) else shutil.rmtree(d)
    os.symlink(f"{CACHE}/{nm}",d)
for nm,sc in [("coarse_img",COARSE),("inp_img_blended",IB)]:
    d=f"{GEO}/Geo-Bench-2D/{nm}"
    if os.path.lexists(d):
        os.remove(d) if os.path.islink(d) else shutil.rmtree(d)
    os.symlink(sc,d)

shutil.copy(ANNs,f"{GEO}/annotation_2d.json")
ann=json.load(open(f"{GEO}/annotation_2d.json"))
meta=[r for r in csv.DictReader(open(META))
      if os.path.exists(f"{IB}/{r['da_n']}/{r['ins_id']}/inp_img.png")]

random.seed(42)
cells=defaultdict(list)
for r in meta:
    cells[(r["edit_type"],r["difficulty"])].append(r)
keys=sorted(cells)
per=200//len(keys)
picked=[]
for k in keys:
    pool=cells[k][:]
    random.shuffle(pool)
    picked += pool[:per]
chosen={(r["da_n"],r["ins_id"],r["case_id"]) for r in picked}
left=[r for r in meta if (r["da_n"],r["ins_id"],r["case_id"]) not in chosen]
random.shuffle(left)
for r in left:
    if len(picked)>=200: break
    picked.append(r)
picked=picked[:200]
counts=Counter(r["edit_type"] for r in picked)
assert counts==Counter({"move":67,"resize":67,"rotate":66}), counts
json.dump(picked,open(f"{GEO}/subset_meta.json","w"),indent=2)
sha=hashlib.sha256(
    "\n".join(sorted(f"{r['da_n']}|{r['ins_id']}|{r['case_id']}" for r in picked)).encode()
).hexdigest()
print("balanced-200:",dict(counts))
print("SHA256:",sha)
assert sha=="3d7c0172cba1e35693a3f20b562004bcfd6fc43e187160c945a23224d40cbd3c"

EVALROOT=f"{GEO}/gen_eval"
os.makedirs(EVALROOT,exist_ok=True)
d=f"{EVALROOT}/baseline"
if os.path.lexists(d):
    os.remove(d) if os.path.islink(d) else shutil.rmtree(d)
os.symlink(GENBASE,d)

def krow(r): return (r["da_n"],r["ins_id"],r["case_id"])
def mem(pred): return [krow(r) for r in picked if pred(r)]

groups={"all_200":mem(lambda r:True)}
for diff in ["easy","medium","hard"]:
    groups[f"all_{diff}"]=mem(lambda r,diff=diff:r["difficulty"]==diff)
groups["all_nonhard"]=mem(lambda r:r["difficulty"]!="hard")
for et in ["move","rotate","resize"]:
    groups[f"{et}_all"]=mem(lambda r,et=et:r["edit_type"]==et)
    groups[f"{et}_nonhard"]=mem(lambda r,et=et:r["edit_type"]==et and r["difficulty"]!="hard")
    for diff in ["easy","medium","hard"]:
        groups[f"{et}_{diff}"]=mem(lambda r,et=et,diff=diff:r["edit_type"]==et and r["difficulty"]==diff)

GROUP_ORDER=[
    "move_all","move_easy","move_medium","move_hard","move_nonhard",
    "rotate_all","rotate_easy","rotate_medium","rotate_hard","rotate_nonhard",
    "resize_all","resize_easy","resize_medium","resize_hard","resize_nonhard",
    "all_200","all_easy","all_medium","all_hard","all_nonhard",
]
assert all(g in groups for g in GROUP_ORDER)
print("group sizes:",{g:len(groups[g]) for g in GROUP_ORDER})
print("✓ dataset + expanded groups ready")
# Out:
# balanced-200: {'move': 67, 'resize': 67, 'rotate': 66}
# SHA256: 3d7c0172cba1e35693a3f20b562004bcfd6fc43e187160c945a23224d40cbd3c
# group sizes: {'move_all': 67, 'move_easy': 23, 'move_medium': 22, 'move_hard': 22, 'move_nonhard': 45, 'rotate_all': 66, 'rotate_easy': 22, 'rotate_medium': 22, 'rotate_hard': 22, 'rotate_nonhard': 44, 'resize_all': 67, 'resize_easy': 22, 'resize_medium': 22, 'resize_hard': 23, 'resize_nonhard': 44, 'all_200': 200, 'all_easy': 67, 'all_medium': 66, 'all_hard': 67, 'all_nonhard': 133}
# ✓ dataset + expanded groups ready

# %% [markdown]
# ## 5. Discover generated outputs

# %%
# ===== Discover Account B raw outputs + rebuild full post-hoc variants =====
import os,glob,json,shutil,numpy as np,cv2
from PIL import Image
RAW_ALL=['CFG10_PROMPT_ALL', 'EPSREC_PROMPT_ALL', 'EPSREC_R1_ALL', 'PRES03_GLOBAL', 'HF30_EPSREC_R1_ALL', 'HF30_EPSREC_PROMPT_ALL', 'MIDHF_EPSREC_PROMPT_ALL', 'EPSREC_PURE_ALL', 'EPSREC_BETA05_ALL', 'APG_NOMOM_ALL', 'EPSREC_ETA025_ALL', 'HF30_EPSREC_PURE_ALL', 'MIDHF_EPSREC_PURE_ALL']
MOVE_RAW=['EXACT_RING8_MOVE', 'AA_RING8_MOVE']
EXPECTED={**{t:200 for t in RAW_ALL}, **{t:67 for t in MOVE_RAW}}
RAW=RAW_ALL+MOVE_RAW

def pc(p):
    return len(glob.glob(p+"/**/*.png",recursive=True)) if os.path.isdir(p) else 0

EVALROOT=f"{GEO}/gen_eval"
roots={}; inventory={}
for tag in RAW:
    cands=glob.glob(f"/kaggle/input/**/finalB_guidance_move/variants/{tag}",recursive=True)
    if not cands:
        inventory[tag]={"pngs":0,"expected":EXPECTED[tag],"complete":False,"root":None}
        print(f"{tag:32s} MISSING")
        continue
    root=max(cands,key=pc); n=pc(root); roots[tag]=root
    inventory[tag]={"pngs":n,"expected":EXPECTED[tag],"complete":n>=EXPECTED[tag],"root":root}
    print(f"{tag:32s} {n}/{EXPECTED[tag]}", "✓" if n>=EXPECTED[tag] else "PARTIAL", root)
    d=f"{EVALROOT}/{tag}"
    if os.path.lexists(d):
        os.remove(d) if os.path.islink(d) else shutil.rmtree(d)
    os.symlink(root,d)
json.dump(inventory,open("/kaggle/working/B_inventory.json","w"),indent=2)
COMPLETE_ALL=[t for t in RAW_ALL if inventory[t]["complete"]]

BASE=f"{EVALROOT}/baseline"
WORK="/kaggle/working/finalB_post_variants"
os.makedirs(WORK,exist_ok=True)
picked=json.load(open(f"{GEO}/subset_meta.json"))

def key(r): return (r["da_n"],r["ins_id"],r["case_id"])
def reset(p):
    if os.path.lexists(p):
        os.remove(p) if os.path.islink(p) or os.path.isfile(p) else shutil.rmtree(p)
    os.makedirs(p,exist_ok=True)
def link(tag,root):
    d=f"{EVALROOT}/{tag}"
    if os.path.lexists(d):
        os.remove(d) if os.path.islink(d) else shutil.rmtree(d)
    os.symlink(root,d)
def ring(tag,w,global_apply=False):
    root=f"{WORK}/{tag}"; reset(root)
    for r in picked:
        d,i,e=key(r)
        bp=f"{BASE}/{d}/{i}/{e}.png"
        dst=f"{root}/{d}/{i}/{e}.png"
        os.makedirs(os.path.dirname(dst),exist_ok=True)
        if not(global_apply or r["edit_type"]=="move"):
            os.symlink(os.path.realpath(bp),dst); continue
        C=np.array(Image.open(f"{GEO}/Geo-Bench-2D/coarse_img/{d}/{i}/{e}.png").convert("RGB"))
        G=np.array(Image.open(bp).convert("RGB"))
        T=np.array(Image.open(f"{GEO}/Geo-Bench-2D/target_mask/{d}/{i}/{e}.png").convert("L"))>127
        interior=cv2.erode(T.astype(np.uint8),np.ones((2*w+1,2*w+1),np.uint8),iterations=1).astype(bool)
        Image.fromarray(np.where(interior[:,:,None],C,G).astype(np.uint8)).save(dst)
    link(tag,root); print("built",tag)

for w in [4,8,16,24]:
    ring(f"RING{w}_MOVE_POST",w)
ring("RING8_GLOBAL_POST",8,True)

def task_model(tag,source,task):
    assert source in roots and inventory[source]["complete"], (source,inventory.get(source))
    root=f"{WORK}/{tag}"; reset(root); srcroot=roots[source]
    for r in picked:
        d,i,e=key(r)
        src=f"{srcroot}/{d}/{i}/{e}.png" if r["edit_type"]==task else f"{BASE}/{d}/{i}/{e}.png"
        dst=f"{root}/{d}/{i}/{e}.png"; os.makedirs(os.path.dirname(dst),exist_ok=True)
        os.symlink(os.path.realpath(src),dst)
    link(tag,root); print("built",tag)

if inventory.get("EXACT_RING8_MOVE",{}).get("complete"):
    task_model("EXACT_RING8_MODEL","EXACT_RING8_MOVE","move")
if inventory.get("AA_RING8_MOVE",{}).get("complete"):
    task_model("AA_RING8_MODEL","AA_RING8_MOVE","move")
if inventory.get("PRES03_GLOBAL",{}).get("complete"):
    task_model("PRES03_MOVE_MODEL","PRES03_GLOBAL","move")

def hard_router(tag,source,task="resize"):
    assert source in roots and inventory[source]["complete"]
    root=f"{WORK}/{tag}"; reset(root); srcroot=roots[source]
    for r in picked:
        d,i,e=key(r)
        use=(r["edit_type"]==task and r["difficulty"]=="hard")
        src=f"{srcroot}/{d}/{i}/{e}.png" if use else f"{BASE}/{d}/{i}/{e}.png"
        dst=f"{root}/{d}/{i}/{e}.png"; os.makedirs(os.path.dirname(dst),exist_ok=True)
        os.symlink(os.path.realpath(src),dst)
    link(tag,root); print("built",tag)

for source,tag in [
    ("EPSREC_R1_ALL","ROUTER_EPSREC_RES_HARD"),
    ("EPSREC_PROMPT_ALL","ROUTER_EPSREC_PROMPT_RES_HARD"),
    ("HF30_EPSREC_R1_ALL","ROUTER_HF30_EPSREC_RES_HARD"),
    ("EPSREC_PURE_ALL","ROUTER_EPSREC_PURE_RES_HARD"),
]:
    if inventory.get(source,{}).get("complete"):
        hard_router(tag,source)

POST=[
    "RING4_MOVE_POST","RING8_MOVE_POST","RING16_MOVE_POST","RING24_MOVE_POST","RING8_GLOBAL_POST",
    "EXACT_RING8_MODEL","AA_RING8_MODEL","PRES03_MOVE_MODEL",
    "ROUTER_EPSREC_RES_HARD","ROUTER_EPSREC_PROMPT_RES_HARD",
    "ROUTER_HF30_EPSREC_RES_HARD","ROUTER_EPSREC_PURE_RES_HARD",
]
POST=[t for t in POST if os.path.exists(f"{EVALROOT}/{t}")]
print("COMPLETE RAW ALL",COMPLETE_ALL)
print("POST",POST)
# Out:
# CFG10_PROMPT_ALL                 200/200 ✓ /kaggle/input/notebooks/giorgostzam/freefine-final-exhaustive-run-account-b-guidan/finalB_guidance_move/variants/CFG10_PROMPT_ALL
# EPSREC_PROMPT_ALL                200/200 ✓ /kaggle/input/notebooks/giorgostzam/freefine-final-exhaustive-run-account-b-guidan/finalB_guidance_move/variants/EPSREC_PROMPT_ALL
# EPSREC_R1_ALL                    200/200 ✓ /kaggle/input/notebooks/giorgostzam/freefine-final-exhaustive-run-account-b-guidan/finalB_guidance_move/variants/EPSREC_R1_ALL
# PRES03_GLOBAL                    200/200 ✓ /kaggle/input/notebooks/giorgostzam/02-w0b-complete-pres03-and-guidance-gaps-t4x2-v1/finalB_guidance_move/variants/PRES03_GLOBAL
# HF30_EPSREC_R1_ALL               200/200 ✓ /kaggle/input/notebooks/giorgostzam/freefine-final-exhaustive-run-account-b-guidan/finalB_guidance_move/variants/HF30_EPSREC_R1_ALL
# HF30_EPSREC_PROMPT_ALL           200/200 ✓ /kaggle/input/notebooks/giorgostzam/freefine-final-exhaustive-run-account-b-guidan/finalB_guidance_move/variants/HF30_EPSREC_PROMPT_ALL
# MIDHF_EPSREC_PROMPT_ALL          200/200 ✓ /kaggle/input/notebooks/giorgostzam/freefine-final-exhaustive-run-account-b-guidan/finalB_guidance_move/variants/MIDHF_EPSREC_PROMPT_ALL
# EPSREC_PURE_ALL                  200/200 ✓ /kaggle/input/notebooks/giorgostzam/02-w0b-complete-pres03-and-guidance-gaps-t4x2-v1/finalB_guidance_move/variants/EPSREC_PURE_ALL
# EPSREC_BETA05_ALL                200/200 ✓ /kaggle/input/notebooks/giorgostzam/02-w0b-complete-pres03-and-guidance-gaps-t4x2-v1/finalB_guidance_move/variants/EPSREC_BETA05_ALL
# APG_NOMOM_ALL                    200/200 ✓ /kaggle/input/notebooks/giorgostzam/02-w0b-complete-pres03-and-guidance-gaps-t4x2-v1/finalB_guidance_move/variants/APG_NOMOM_ALL
# EPSREC_ETA025_ALL                200/200 ✓ /kaggle/input/notebooks/giorgostzam/02-w0b-complete-pres03-and-guidance-gaps-t4x2-v1/finalB_guidance_move/variants/EPSREC_ETA025_ALL
# HF30_EPSREC_PURE_ALL             200/200 ✓ /kaggle/input/notebooks/giorgostzam/02-w0b-complete-pres03-and-guidance-gaps-t4x2-v1/finalB_guidance_move/variants/HF30_EPSREC_PURE_ALL
# MIDHF_EPSREC_PURE_ALL            200/200 ✓ /kaggle/input/notebooks/giorgostzam/02-w0b-complete-pres03-and-guidance-gaps-t4x2-v1/finalB_guidance_move/variants/MIDHF_EPSREC_PURE_ALL
# EXACT_RING8_MOVE                 67/67 ✓ /kaggle/input/notebooks/giorgostzam/freefine-final-exhaustive-run-account-b-guidan/finalB_guidance_move/variants/EXACT_RING8_MOVE
# AA_RING8_MOVE                    67/67 ✓ /kaggle/input/notebooks/giorgostzam/freefine-final-exhaustive-run-account-b-guidan/finalB_guidance_move/variants/AA_RING8_MOVE
# built RING4_MOVE_POST
# built RING8_MOVE_POST
# built RING16_MOVE_POST
# built RING24_MOVE_POST
# built RING8_GLOBAL_POST
# built EXACT_RING8_MODEL
# built AA_RING8_MODEL
# built PRES03_MOVE_MODEL
# built ROUTER_EPSREC_RES_HARD
# built ROUTER_EPSREC_PROMPT_RES_HARD
# built ROUTER_HF30_EPSREC_RES_HARD
# built ROUTER_EPSREC_PURE_RES_HARD
# COMPLETE RAW ALL ['CFG10_PROMPT_ALL', 'EPSREC_PROMPT_ALL', 'EPSREC_R1_ALL', 'PRES03_GLOBAL', 'HF30_EPSREC_R1_ALL', 'HF30_EPSREC_PROMPT_ALL', 'MIDHF_EPSREC_PROMPT_ALL', 'EPSREC_PURE_ALL', 'EPSREC_BETA05_ALL', 'APG_NOMOM_ALL', 'EPSREC_ETA025_ALL', 'HF30_EPSREC_PURE_ALL', 'MIDHF_EPSREC_PURE_ALL']
# POST ['RING4_MOVE_POST', 'RING8_MOVE_POST', 'RING16_MOVE_POST', 'RING24_MOVE_POST', 'RING8_GLOBAL_POST', 'EXACT_RING8_MODEL', 'AA_RING8_MODEL', 'PRES03_MOVE_MODEL', 'ROUTER_EPSREC_RES_HARD', 'ROUTER_EPSREC_PROMPT_RES_HARD', 'ROUTER_HF30_EPSREC_RES_HARD', 'ROUTER_EPSREC_PURE_RES_HARD']

# %% [markdown]
# ## 6. Metric helpers

# %%
# ===== Metric helpers =====
import os,json,re,subprocess,time,threading,queue,pandas as pd
MET="/kaggle/temp/FreeFine/evaluation/metrics"
PY="/kaggle/temp/metric_env/bin/python"
EVALROOT=f"{GEO}/gen_eval"
ann=json.load(open(f"{GEO}/annotation_2d.json"))

def manifest(tag,group_name,ids):
    out={}; base=f"{EVALROOT}/{tag}"; used=0
    for d,i,e in ids:
        gp=f"{base}/{d}/{i}/{e}.png"
        if not os.path.exists(gp): continue
        lf=dict(ann[d]["instances"][i][e])
        lf["gen_img_path"]=f"gen_eval/{tag}/{d}/{i}/{e}.png"
        out.setdefault(d,{"instances":{}})["instances"].setdefault(i,{})[e]=lf
        used+=1
    p=f"{GEO}/m_{re.sub(r'[^A-Za-z0-9_.-]+','_',tag+'_'+group_name)}.json"
    json.dump(out,open(p,"w"))
    return p,used

def run_metric(manifest_path,task,gpu,md_seed=42,metric_seed=42):
    env=os.environ.copy()
    env.update({
        "CUDA_VISIBLE_DEVICES":str(gpu),
        "MPLBACKEND":"Agg",
        "HF_HOME":"/kaggle/temp/hf",
        "TORCH_HOME":"/kaggle/temp/torch",
        "PYTORCH_CUDA_ALLOC_CONF":"expandable_segments:True",
        "FF_MD_SEED":str(md_seed),
        "FF_METRIC_SEED":str(metric_seed),
        "TOKENIZERS_PARALLELISM":"false",
    })
    p=subprocess.run(
        [PY,"main.py","--path",manifest_path,"--use_relative_path","--base_dir",GEO,
         "--fid_path",f"{GEO}/Geo-Bench-2D/source_img_full_v2","--task",task,"--level","0"],
        cwd=MET,env=env,capture_output=True,text=True
    )
    txt=p.stdout+p.stderr
    vals={}
    for k in ["FID_DINO","FID_KD","FID","SUBC","BGC","WRAP_E","MD"]:
        h=re.findall(rf"(?:^|\s){k}:\s*([-\d.eE]+)",txt)
        if h: vals[k]=round(float(h[-1]),4)
    if p.returncode!=0:
        vals["_rc"]=p.returncode; vals["_tail"]=txt[-1800:]
    return vals

def parallel_jobs(jobs,worker_fn,deadline_hours=11.6):
    q=queue.Queue()
    for x in jobs: q.put(x)
    deadline=NB_START+deadline_hours*3600
    def _w(gpu):
        while time.time()<deadline-120:
            try: job=q.get_nowait()
            except queue.Empty: return
            try: worker_fn(gpu,*job)
            finally: q.task_done()
    ts=[threading.Thread(target=_w,args=(g,),daemon=True) for g in [0,1]]
    [t.start() for t in ts]; [t.join() for t in ts]
    return list(q.queue)
print("✓ metric helpers ready")
# Out:
# ✓ metric helpers ready

# %% [markdown]
# ## 7. Run

# %%
# ===== Exhaustive core metrics: BGC / SUBC / WRAP_E / MD =====
RESULT_JSON="/kaggle/working/B_core_results.json"
RESULT_CSV="/kaggle/working/B_core_results.csv"
TAGS=COMPLETE_ALL+POST
TAGS=["baseline"]+[t for t in TAGS if os.path.exists(f"{EVALROOT}/{t}")]
TAGS=list(dict.fromkeys(TAGS))
results={}
lock=threading.Lock()

# Baseline gate on the canonical all_200 group.
m,u=manifest("baseline","all_200",groups["all_200"])
gate=run_metric(m,"000111100",0,42,42)
assert u==200
assert abs(gate.get("SUBC",-9)-0.9154)<5e-4, gate
assert abs(gate.get("BGC",-9)-0.9657)<8e-4, gate
assert abs(gate.get("WRAP_E",-9)-0.0488)<8e-4, gate
assert abs(gate.get("MD",-9)-7.6023)<0.03, gate
print("✓ baseline core gate",gate)

jobs=[(tag,g) for tag in TAGS for g in GROUP_ORDER]

def save():
    with lock:
        json.dump(results,open(RESULT_JSON,"w"),indent=2)
        rows=[]
        for tag,gd in results.items():
            for g,v in gd.items(): rows.append({"set":tag,"group":g,**v})
        pd.DataFrame(rows).to_csv(RESULT_CSV,index=False)

def work(gpu,tag,g):
    m,u=manifest(tag,g,groups[g])
    if not u: return
    v=run_metric(m,"000111100",gpu,42,42)
    v["n"]=u; v["expected_n"]=len(groups[g]); v["complete_group"]=(u==len(groups[g]))
    with lock: results.setdefault(tag,{})[g]=v
    save()
    print(f"[GPU{gpu}] {tag:34s} {g:16s} -> {v}",flush=True)

remaining=parallel_jobs(jobs,work,11.65)
save()
missing=[]
for tag in TAGS:
    for g in GROUP_ORDER:
        v=results.get(tag,{}).get(g,{})
        if any(k not in v for k in ["BGC","SUBC","WRAP_E","MD"]) or not v.get("complete_group"):
            missing.append((tag,g))
print("MISSING CORE",len(missing),missing[:120])
print("remaining queue",len(remaining))
print("saved",RESULT_JSON,RESULT_CSV)
# Out:
# ✓ baseline core gate {'SUBC': 0.9154, 'BGC': 0.9657, 'WRAP_E': 0.0488, 'MD': 7.6023}
# [GPU1] baseline                           move_easy        -> {'SUBC': 0.9637, 'BGC': 0.9645, 'WRAP_E': 0.0494, 'MD': 3.3161, 'n': 23, 'expected_n': 23, 'complete_group': True}
# [GPU1] baseline                           move_medium      -> {'SUBC': 0.9584, 'BGC': 0.9654, 'WRAP_E': 0.0584, 'MD': 3.2666, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU0] baseline                           move_all         -> {'SUBC': 0.959, 'BGC': 0.9639, 'WRAP_E': 0.0495, 'MD': 3.408, 'n': 67, 'expected_n': 67, 'complete_group': True}
# [GPU1] baseline                           move_hard        -> {'SUBC': 0.9545, 'BGC': 0.9617, 'WRAP_E': 0.0407, 'MD': 3.1192, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU0] baseline                           move_nonhard     -> {'SUBC': 0.9611, 'BGC': 0.965, 'WRAP_E': 0.0538, 'MD': 3.3449, 'n': 45, 'expected_n': 45, 'complete_group': True}
# [GPU0] baseline                           rotate_easy      -> {'SUBC': 0.9287, 'BGC': 0.979, 'WRAP_E': 0.0471, 'MD': 5.047, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] baseline                           rotate_all       -> {'SUBC': 0.8962, 'BGC': 0.9684, 'WRAP_E': 0.0423, 'MD': 9.6294, 'n': 66, 'expected_n': 66, 'complete_group': True}
# [GPU0] baseline                           rotate_medium    -> {'SUBC': 0.9075, 'BGC': 0.9598, 'WRAP_E': 0.0383, 'MD': 8.3667, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] baseline                           rotate_hard      -> {'SUBC': 0.8523, 'BGC': 0.9664, 'WRAP_E': 0.0416, 'MD': 14.0096, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU0] baseline                           rotate_nonhard   -> {'SUBC': 0.9181, 'BGC': 0.9694, 'WRAP_E': 0.0427, 'MD': 6.1397, 'n': 44, 'expected_n': 44, 'complete_group': True}
# [GPU0] baseline                           resize_easy      -> {'SUBC': 0.9383, 'BGC': 0.967, 'WRAP_E': 0.0426, 'MD': 5.3292, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] baseline                           resize_all       -> {'SUBC': 0.8906, 'BGC': 0.9647, 'WRAP_E': 0.0544, 'MD': 10.9331, 'n': 67, 'expected_n': 67, 'complete_group': True}
# [GPU0] baseline                           resize_medium    -> {'SUBC': 0.8969, 'BGC': 0.9641, 'WRAP_E': 0.062, 'MD': 9.3508, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] baseline                           resize_hard      -> {'SUBC': 0.8391, 'BGC': 0.9631, 'WRAP_E': 0.0585, 'MD': 19.4713, 'n': 23, 'expected_n': 23, 'complete_group': True}
# [GPU0] baseline                           resize_nonhard   -> {'SUBC': 0.9176, 'BGC': 0.9655, 'WRAP_E': 0.0523, 'MD': 7.5773, 'n': 44, 'expected_n': 44, 'complete_group': True}
# [GPU0] baseline                           all_easy         -> {'SUBC': 0.9439, 'BGC': 0.9701, 'WRAP_E': 0.0464, 'MD': 4.5656, 'n': 67, 'expected_n': 67, 'complete_group': True}
# [GPU0] baseline                           all_medium       -> {'SUBC': 0.9209, 'BGC': 0.9631, 'WRAP_E': 0.0529, 'MD': 6.5983, 'n': 66, 'expected_n': 66, 'complete_group': True}
# [GPU1] baseline                           all_200          -> {'SUBC': 0.9154, 'BGC': 0.9657, 'WRAP_E': 0.0488, 'MD': 7.6023, 'n': 200, 'expected_n': 200, 'complete_group': True}
# [GPU0] baseline                           all_hard         -> {'SUBC': 0.8813, 'BGC': 0.9637, 'WRAP_E': 0.0471, 'MD': 11.4838, 'n': 67, 'expected_n': 67, 'complete_group': True}
# [GPU0] CFG10_PROMPT_ALL                   move_all         -> {'SUBC': 0.9587, 'BGC': 0.9639, 'WRAP_E': 0.0497, 'MD': 3.2879, 'n': 67, 'expected_n': 67, 'complete_group': True}
# [GPU0] CFG10_PROMPT_ALL                   move_easy        -> {'SUBC': 0.9634, 'BGC': 0.9647, 'WRAP_E': 0.0496, 'MD': 3.3462, 'n': 23, 'expected_n': 23, 'complete_group': True}
# [GPU1] baseline                           all_nonhard      -> {'SUBC': 0.9325, 'BGC': 0.9666, 'WRAP_E': 0.0496, 'MD': 5.477, 'n': 133, 'expected_n': 133, 'complete_group': True}
# [GPU0] CFG10_PROMPT_ALL                   move_medium      -> {'SUBC': 0.9581, 'BGC': 0.9645, 'WRAP_E': 0.0587, 'MD': 3.3379, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] CFG10_PROMPT_ALL                   move_hard        -> {'SUBC': 0.9545, 'BGC': 0.9626, 'WRAP_E': 0.0408, 'MD': 3.1573, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU0] CFG10_PROMPT_ALL                   move_nonhard     -> {'SUBC': 0.9608, 'BGC': 0.9646, 'WRAP_E': 0.0541, 'MD': 3.3686, 'n': 45, 'expected_n': 45, 'complete_group': True}
# [GPU0] CFG10_PROMPT_ALL                   rotate_easy      -> {'SUBC': 0.9285, 'BGC': 0.9788, 'WRAP_E': 0.0471, 'MD': 5.0151, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] CFG10_PROMPT_ALL                   rotate_all       -> {'SUBC': 0.8963, 'BGC': 0.9691, 'WRAP_E': 0.0424, 'MD': 9.7934, 'n': 66, 'expected_n': 66, 'complete_group': True}
# [GPU0] CFG10_PROMPT_ALL                   rotate_medium    -> {'SUBC': 0.9075, 'BGC': 0.9604, 'WRAP_E': 0.0385, 'MD': 8.3586, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] CFG10_PROMPT_ALL                   rotate_hard      -> {'SUBC': 0.8529, 'BGC': 0.968, 'WRAP_E': 0.0416, 'MD': 14.6852, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU0] CFG10_PROMPT_ALL                   rotate_nonhard   -> {'SUBC': 0.918, 'BGC': 0.9696, 'WRAP_E': 0.0428, 'MD': 6.0062, 'n': 44, 'expected_n': 44, 'complete_group': True}
# [GPU0] CFG10_PROMPT_ALL                   resize_easy      -> {'SUBC': 0.9376, 'BGC': 0.9662, 'WRAP_E': 0.0428, 'MD': 5.1829, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] CFG10_PROMPT_ALL                   resize_all       -> {'SUBC': 0.8908, 'BGC': 0.9642, 'WRAP_E': 0.0547, 'MD': 11.2776, 'n': 67, 'expected_n': 67, 'complete_group': True}
# [GPU0] CFG10_PROMPT_ALL                   resize_medium    -> {'SUBC': 0.8979, 'BGC': 0.964, 'WRAP_E': 0.0624, 'MD': 9.702, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] CFG10_PROMPT_ALL                   resize_hard      -> {'SUBC': 0.8391, 'BGC': 0.9625, 'WRAP_E': 0.0587, 'MD': 17.7459, 'n': 23, 'expected_n': 23, 'complete_group': True}
# [GPU0] CFG10_PROMPT_ALL                   resize_nonhard   -> {'SUBC': 0.9177, 'BGC': 0.9651, 'WRAP_E': 0.0526, 'MD': 7.7973, 'n': 44, 'expected_n': 44, 'complete_group': True}
# [GPU0] CFG10_PROMPT_ALL                   all_easy         -> {'SUBC': 0.9435, 'BGC': 0.9698, 'WRAP_E': 0.0466, 'MD': 4.4756, 'n': 67, 'expected_n': 67, 'complete_group': True}
# [GPU0] CFG10_PROMPT_ALL                   all_medium       -> {'SUBC': 0.9212, 'BGC': 0.963, 'WRAP_E': 0.0532, 'MD': 6.7825, 'n': 66, 'expected_n': 66, 'complete_group': True}
# [GPU1] CFG10_PROMPT_ALL                   all_200          -> {'SUBC': 0.9154, 'BGC': 0.9657, 'WRAP_E': 0.049, 'MD': 7.7206, 'n': 200, 'expected_n': 200, 'complete_group': True}
# [GPU0] CFG10_PROMPT_ALL                   all_hard         -> {'SUBC': 0.8815, 'BGC': 0.9643, 'WRAP_E': 0.0472, 'MD': 11.8178, 'n': 67, 'expected_n': 67, 'complete_group': True}
# [GPU0] EPSREC_PROMPT_ALL                  move_all         -> {'SUBC': 0.9588, 'BGC': 0.9637, 'WRAP_E': 0.0496, 'MD': 3.3474, 'n': 67, 'expected_n': 67, 'complete_group': True}
# [GPU0] EPSREC_PROMPT_ALL                  move_easy        -> {'SUBC': 0.9634, 'BGC': 0.9646, 'WRAP_E': 0.0495, 'MD': 3.4367, 'n': 23, 'expected_n': 23, 'complete_group': True}
# [GPU1] CFG10_PROMPT_ALL                   all_nonhard      -> {'SUBC': 0.9324, 'BGC': 0.9664, 'WRAP_E': 0.0499, 'MD': 5.4704, 'n': 133, 'expected_n': 133, 'complete_group': True}
# [GPU0] EPSREC_PROMPT_ALL                  move_medium      -> {'SUBC': 0.9582, 'BGC': 0.9643, 'WRAP_E': 0.0585, 'MD': 3.3236, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] EPSREC_PROMPT_ALL                  move_hard        -> {'SUBC': 0.9546, 'BGC': 0.9622, 'WRAP_E': 0.0407, 'MD': 3.2282, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU0] EPSREC_PROMPT_ALL                  move_nonhard     -> {'SUBC': 0.9609, 'BGC': 0.9645, 'WRAP_E': 0.0539, 'MD': 3.3827, 'n': 45, 'expected_n': 45, 'complete_group': True}
# [GPU0] EPSREC_PROMPT_ALL                  rotate_easy      -> {'SUBC': 0.9286, 'BGC': 0.979, 'WRAP_E': 0.047, 'MD': 5.1262, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] EPSREC_PROMPT_ALL                  rotate_all       -> {'SUBC': 0.8964, 'BGC': 0.9687, 'WRAP_E': 0.0423, 'MD': 9.7925, 'n': 66, 'expected_n': 66, 'complete_group': True}
# [GPU0] EPSREC_PROMPT_ALL                  rotate_medium    -> {'SUBC': 0.9076, 'BGC': 0.9599, 'WRAP_E': 0.0384, 'MD': 8.3899, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] EPSREC_PROMPT_ALL                  rotate_hard      -> {'SUBC': 0.8528, 'BGC': 0.9672, 'WRAP_E': 0.0415, 'MD': 14.4762, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU0] EPSREC_PROMPT_ALL                  rotate_nonhard   -> {'SUBC': 0.9181, 'BGC': 0.9695, 'WRAP_E': 0.0427, 'MD': 6.0837, 'n': 44, 'expected_n': 44, 'complete_group': True}
# [GPU0] EPSREC_PROMPT_ALL                  resize_easy      -> {'SUBC': 0.9379, 'BGC': 0.9665, 'WRAP_E': 0.0427, 'MD': 5.2038, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] EPSREC_PROMPT_ALL                  resize_all       -> {'SUBC': 0.8907, 'BGC': 0.9641, 'WRAP_E': 0.0545, 'MD': 10.9187, 'n': 67, 'expected_n': 67, 'complete_group': True}
# [GPU0] EPSREC_PROMPT_ALL                  resize_medium    -> {'SUBC': 0.8976, 'BGC': 0.9634, 'WRAP_E': 0.0622, 'MD': 9.5629, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] EPSREC_PROMPT_ALL                  resize_hard      -> {'SUBC': 0.8391, 'BGC': 0.9625, 'WRAP_E': 0.0585, 'MD': 16.6061, 'n': 23, 'expected_n': 23, 'complete_group': True}
# [GPU0] EPSREC_PROMPT_ALL                  resize_nonhard   -> {'SUBC': 0.9178, 'BGC': 0.9649, 'WRAP_E': 0.0524, 'MD': 7.7788, 'n': 44, 'expected_n': 44, 'complete_group': True}
# [GPU0] EPSREC_PROMPT_ALL                  all_easy         -> {'SUBC': 0.9436, 'BGC': 0.97, 'WRAP_E': 0.0464, 'MD': 4.562, 'n': 67, 'expected_n': 67, 'complete_group': True}
# [GPU0] EPSREC_PROMPT_ALL                  all_medium       -> {'SUBC': 0.9211, 'BGC': 0.9626, 'WRAP_E': 0.053, 'MD': 6.7937, 'n': 66, 'expected_n': 66, 'complete_group': True}
# [GPU1] EPSREC_PROMPT_ALL                  all_200          -> {'SUBC': 0.9154, 'BGC': 0.9655, 'WRAP_E': 0.0488, 'MD': 7.5552, 'n': 200, 'expected_n': 200, 'complete_group': True}
# [GPU0] EPSREC_PROMPT_ALL                  all_hard         -> {'SUBC': 0.8815, 'BGC': 0.9639, 'WRAP_E': 0.0471, 'MD': 11.3109, 'n': 67, 'expected_n': 67, 'complete_group': True}
# [GPU0] EPSREC_R1_ALL                      move_all         -> {'SUBC': 0.961, 'BGC': 0.9624, 'WRAP_E': 0.0468, 'MD': 3.5176, 'n': 67, 'expected_n': 67, 'complete_group': True}
# [GPU0] EPSREC_R1_ALL                      move_easy        -> {'SUBC': 0.9654, 'BGC': 0.963, 'WRAP_E': 0.0466, 'MD': 3.5317, 'n': 23, 'expected_n': 23, 'complete_group': True}
# [GPU1] EPSREC_PROMPT_ALL                  all_nonhard      -> {'SUBC': 0.9325, 'BGC': 0.9663, 'WRAP_E': 0.0497, 'MD': 5.4908, 'n': 133, 'expected_n': 133, 'complete_group': True}
# [GPU0] EPSREC_R1_ALL                      move_medium      -> {'SUBC': 0.9605, 'BGC': 0.965, 'WRAP_E': 0.0555, 'MD': 3.4844, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] EPSREC_R1_ALL                      move_hard        -> {'SUBC': 0.957, 'BGC': 0.9592, 'WRAP_E': 0.0382, 'MD': 3.3104, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU0] EPSREC_R1_ALL                      move_nonhard     -> {'SUBC': 0.963, 'BGC': 0.964, 'WRAP_E': 0.051, 'MD': 3.4832, 'n': 45, 'expected_n': 45, 'complete_group': True}
# [GPU0] EPSREC_R1_ALL                      rotate_easy      -> {'SUBC': 0.9287, 'BGC': 0.979, 'WRAP_E': 0.0471, 'MD': 5.047, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] EPSREC_R1_ALL                      rotate_all       -> {'SUBC': 0.8962, 'BGC': 0.9684, 'WRAP_E': 0.0423, 'MD': 9.6294, 'n': 66, 'expected_n': 66, 'complete_group': True}
# [GPU0] EPSREC_R1_ALL                      rotate_medium    -> {'SUBC': 0.9075, 'BGC': 0.9598, 'WRAP_E': 0.0383, 'MD': 8.3667, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] EPSREC_R1_ALL                      rotate_hard      -> {'SUBC': 0.8523, 'BGC': 0.9664, 'WRAP_E': 0.0416, 'MD': 14.0096, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU0] EPSREC_R1_ALL                      rotate_nonhard   -> {'SUBC': 0.9181, 'BGC': 0.9694, 'WRAP_E': 0.0427, 'MD': 6.1397, 'n': 44, 'expected_n': 44, 'complete_group': True}
# [GPU0] EPSREC_R1_ALL                      resize_easy      -> {'SUBC': 0.9379, 'BGC': 0.9665, 'WRAP_E': 0.0427, 'MD': 5.2038, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] EPSREC_R1_ALL                      resize_all       -> {'SUBC': 0.8907, 'BGC': 0.9641, 'WRAP_E': 0.0545, 'MD': 10.9187, 'n': 67, 'expected_n': 67, 'complete_group': True}
# [GPU0] EPSREC_R1_ALL                      resize_medium    -> {'SUBC': 0.8976, 'BGC': 0.9634, 'WRAP_E': 0.0622, 'MD': 9.5629, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] EPSREC_R1_ALL                      resize_hard      -> {'SUBC': 0.8391, 'BGC': 0.9625, 'WRAP_E': 0.0585, 'MD': 16.6061, 'n': 23, 'expected_n': 23, 'complete_group': True}
# [GPU0] EPSREC_R1_ALL                      resize_nonhard   -> {'SUBC': 0.9178, 'BGC': 0.9649, 'WRAP_E': 0.0524, 'MD': 7.7788, 'n': 44, 'expected_n': 44, 'complete_group': True}
# [GPU0] EPSREC_R1_ALL                      all_easy         -> {'SUBC': 0.9443, 'BGC': 0.9694, 'WRAP_E': 0.0455, 'MD': 4.5681, 'n': 67, 'expected_n': 67, 'complete_group': True}
# [GPU0] EPSREC_R1_ALL                      all_medium       -> {'SUBC': 0.9219, 'BGC': 0.9628, 'WRAP_E': 0.052, 'MD': 6.803, 'n': 66, 'expected_n': 66, 'complete_group': True}
# [GPU1] EPSREC_R1_ALL                      all_200          -> {'SUBC': 0.9161, 'BGC': 0.965, 'WRAP_E': 0.0479, 'MD': 7.6154, 'n': 200, 'expected_n': 200, 'complete_group': True}
# [GPU0] EPSREC_R1_ALL                      all_hard         -> {'SUBC': 0.8822, 'BGC': 0.9627, 'WRAP_E': 0.0463, 'MD': 11.2513, 'n': 67, 'expected_n': 67, 'complete_group': True}
# [GPU0] PRES03_GLOBAL                      move_all         -> {'SUBC': 0.961, 'BGC': 0.9624, 'WRAP_E': 0.0468, 'MD': 3.5176, 'n': 67, 'expected_n': 67, 'complete_group': True}
# [GPU0] PRES03_GLOBAL                      move_easy        -> {'SUBC': 0.9654, 'BGC': 0.963, 'WRAP_E': 0.0466, 'MD': 3.5317, 'n': 23, 'expected_n': 23, 'complete_group': True}
# [GPU1] EPSREC_R1_ALL                      all_nonhard      -> {'SUBC': 0.9332, 'BGC': 0.9661, 'WRAP_E': 0.0487, 'MD': 5.5651, 'n': 133, 'expected_n': 133, 'complete_group': True}
# [GPU0] PRES03_GLOBAL                      move_medium      -> {'SUBC': 0.9605, 'BGC': 0.965, 'WRAP_E': 0.0555, 'MD': 3.4844, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] PRES03_GLOBAL                      move_hard        -> {'SUBC': 0.957, 'BGC': 0.9592, 'WRAP_E': 0.0382, 'MD': 3.3104, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU0] PRES03_GLOBAL                      move_nonhard     -> {'SUBC': 0.963, 'BGC': 0.964, 'WRAP_E': 0.051, 'MD': 3.4832, 'n': 45, 'expected_n': 45, 'complete_group': True}
# [GPU0] PRES03_GLOBAL                      rotate_easy      -> {'SUBC': 0.9297, 'BGC': 0.9753, 'WRAP_E': 0.042, 'MD': 4.9241, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] PRES03_GLOBAL                      rotate_all       -> {'SUBC': 0.8978, 'BGC': 0.9656, 'WRAP_E': 0.0392, 'MD': 9.7987, 'n': 66, 'expected_n': 66, 'complete_group': True}
# [GPU0] PRES03_GLOBAL                      rotate_medium    -> {'SUBC': 0.9101, 'BGC': 0.9552, 'WRAP_E': 0.0358, 'MD': 8.5485, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] PRES03_GLOBAL                      rotate_hard      -> {'SUBC': 0.8536, 'BGC': 0.9663, 'WRAP_E': 0.0397, 'MD': 14.6308, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU0] PRES03_GLOBAL                      rotate_nonhard   -> {'SUBC': 0.9199, 'BGC': 0.9652, 'WRAP_E': 0.0389, 'MD': 6.0088, 'n': 44, 'expected_n': 44, 'complete_group': True}
# [GPU0] PRES03_GLOBAL                      resize_easy      -> {'SUBC': 0.9409, 'BGC': 0.9628, 'WRAP_E': 0.0398, 'MD': 5.3193, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] PRES03_GLOBAL                      resize_all       -> {'SUBC': 0.8933, 'BGC': 0.9614, 'WRAP_E': 0.0503, 'MD': 12.4837, 'n': 67, 'expected_n': 67, 'complete_group': True}
# [GPU0] PRES03_GLOBAL                      resize_medium    -> {'SUBC': 0.9006, 'BGC': 0.9609, 'WRAP_E': 0.0571, 'MD': 10.0845, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] PRES03_GLOBAL                      resize_hard      -> {'SUBC': 0.8409, 'BGC': 0.9605, 'WRAP_E': 0.0538, 'MD': 21.7356, 'n': 23, 'expected_n': 23, 'complete_group': True}
# [GPU0] PRES03_GLOBAL                      resize_nonhard   -> {'SUBC': 0.9208, 'BGC': 0.9619, 'WRAP_E': 0.0485, 'MD': 8.1406, 'n': 44, 'expected_n': 44, 'complete_group': True}
# [GPU0] PRES03_GLOBAL                      all_easy         -> {'SUBC': 0.9456, 'BGC': 0.967, 'WRAP_E': 0.0429, 'MD': 4.5635, 'n': 67, 'expected_n': 67, 'complete_group': True}
# [GPU0] PRES03_GLOBAL                      all_medium       -> {'SUBC': 0.9237, 'BGC': 0.9604, 'WRAP_E': 0.0495, 'MD': 6.8308, 'n': 66, 'expected_n': 66, 'complete_group': True}
# [GPU1] PRES03_GLOBAL                      all_200          -> {'SUBC': 0.9175, 'BGC': 0.9631, 'WRAP_E': 0.0454, 'MD': 8.1113, 'n': 200, 'expected_n': 200, 'complete_group': True}
# [GPU0] PRES03_GLOBAL                      all_hard         -> {'SUBC': 0.8832, 'BGC': 0.962, 'WRAP_E': 0.0441, 'MD': 12.8012, 'n': 67, 'expected_n': 67, 'complete_group': True}
# [GPU0] HF30_EPSREC_R1_ALL                 move_all         -> {'SUBC': 0.961, 'BGC': 0.9624, 'WRAP_E': 0.0468, 'MD': 3.5278, 'n': 67, 'expected_n': 67, 'complete_group': True}
# [GPU0] HF30_EPSREC_R1_ALL                 move_easy        -> {'SUBC': 0.9654, 'BGC': 0.963, 'WRAP_E': 0.0466, 'MD': 3.5452, 'n': 23, 'expected_n': 23, 'complete_group': True}
# [GPU1] PRES03_GLOBAL                      all_nonhard      -> {'SUBC': 0.9348, 'BGC': 0.9637, 'WRAP_E': 0.0461, 'MD': 5.6698, 'n': 133, 'expected_n': 133, 'complete_group': True}
# [GPU0] HF30_EPSREC_R1_ALL                 move_medium      -> {'SUBC': 0.9605, 'BGC': 0.9651, 'WRAP_E': 0.0555, 'MD': 3.4472, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] HF30_EPSREC_R1_ALL                 move_hard        -> {'SUBC': 0.9571, 'BGC': 0.9591, 'WRAP_E': 0.0382, 'MD': 3.3342, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU0] HF30_EPSREC_R1_ALL                 move_nonhard     -> {'SUBC': 0.963, 'BGC': 0.964, 'WRAP_E': 0.051, 'MD': 3.4631, 'n': 45, 'expected_n': 45, 'complete_group': True}
# [GPU0] HF30_EPSREC_R1_ALL                 rotate_easy      -> {'SUBC': 0.9287, 'BGC': 0.979, 'WRAP_E': 0.0471, 'MD': 5.0343, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] HF30_EPSREC_R1_ALL                 rotate_all       -> {'SUBC': 0.8962, 'BGC': 0.9685, 'WRAP_E': 0.0423, 'MD': 9.6425, 'n': 66, 'expected_n': 66, 'complete_group': True}
# [GPU0] HF30_EPSREC_R1_ALL                 rotate_medium    -> {'SUBC': 0.9075, 'BGC': 0.9599, 'WRAP_E': 0.0383, 'MD': 8.3202, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] HF30_EPSREC_R1_ALL                 rotate_hard      -> {'SUBC': 0.8524, 'BGC': 0.9665, 'WRAP_E': 0.0416, 'MD': 13.9128, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU0] HF30_EPSREC_R1_ALL                 rotate_nonhard   -> {'SUBC': 0.9181, 'BGC': 0.9694, 'WRAP_E': 0.0427, 'MD': 6.1137, 'n': 44, 'expected_n': 44, 'complete_group': True}
# [GPU0] HF30_EPSREC_R1_ALL                 resize_easy      -> {'SUBC': 0.938, 'BGC': 0.9665, 'WRAP_E': 0.0426, 'MD': 5.2441, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] HF30_EPSREC_R1_ALL                 resize_all       -> {'SUBC': 0.8908, 'BGC': 0.9642, 'WRAP_E': 0.0545, 'MD': 11.4041, 'n': 67, 'expected_n': 67, 'complete_group': True}
# [GPU0] HF30_EPSREC_R1_ALL                 resize_medium    -> {'SUBC': 0.8976, 'BGC': 0.9634, 'WRAP_E': 0.0622, 'MD': 9.5993, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] HF30_EPSREC_R1_ALL                 resize_hard      -> {'SUBC': 0.8391, 'BGC': 0.9626, 'WRAP_E': 0.0585, 'MD': 17.6452, 'n': 23, 'expected_n': 23, 'complete_group': True}
# [GPU0] HF30_EPSREC_R1_ALL                 resize_nonhard   -> {'SUBC': 0.9178, 'BGC': 0.965, 'WRAP_E': 0.0524, 'MD': 7.8479, 'n': 44, 'expected_n': 44, 'complete_group': True}
# [GPU0] HF30_EPSREC_R1_ALL                 all_easy         -> {'SUBC': 0.9443, 'BGC': 0.9694, 'WRAP_E': 0.0455, 'MD': 4.5887, 'n': 67, 'expected_n': 67, 'complete_group': True}
# [GPU0] HF30_EPSREC_R1_ALL                 all_medium       -> {'SUBC': 0.9219, 'BGC': 0.9628, 'WRAP_E': 0.052, 'MD': 6.7966, 'n': 66, 'expected_n': 66, 'complete_group': True}
# [GPU1] HF30_EPSREC_R1_ALL                 all_200          -> {'SUBC': 0.9161, 'BGC': 0.965, 'WRAP_E': 0.0479, 'MD': 7.7788, 'n': 200, 'expected_n': 200, 'complete_group': True}
# [GPU0] HF30_EPSREC_R1_ALL                 all_hard         -> {'SUBC': 0.8822, 'BGC': 0.9627, 'WRAP_E': 0.0463, 'MD': 11.6887, 'n': 67, 'expected_n': 67, 'complete_group': True}
# [GPU0] HF30_EPSREC_PROMPT_ALL             move_all         -> {'SUBC': 0.9588, 'BGC': 0.9638, 'WRAP_E': 0.0496, 'MD': 3.3415, 'n': 67, 'expected_n': 67, 'complete_group': True}
# [GPU0] HF30_EPSREC_PROMPT_ALL             move_easy        -> {'SUBC': 0.9635, 'BGC': 0.9647, 'WRAP_E': 0.0495, 'MD': 3.4475, 'n': 23, 'expected_n': 23, 'complete_group': True}
# [GPU1] HF30_EPSREC_R1_ALL                 all_nonhard      -> {'SUBC': 0.9332, 'BGC': 0.9661, 'WRAP_E': 0.0487, 'MD': 5.5902, 'n': 133, 'expected_n': 133, 'complete_group': True}
# [GPU0] HF30_EPSREC_PROMPT_ALL             move_medium      -> {'SUBC': 0.9582, 'BGC': 0.9645, 'WRAP_E': 0.0585, 'MD': 3.315, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] HF30_EPSREC_PROMPT_ALL             move_hard        -> {'SUBC': 0.9545, 'BGC': 0.9623, 'WRAP_E': 0.0407, 'MD': 3.1547, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU0] HF30_EPSREC_PROMPT_ALL             move_nonhard     -> {'SUBC': 0.9609, 'BGC': 0.9646, 'WRAP_E': 0.0539, 'MD': 3.389, 'n': 45, 'expected_n': 45, 'complete_group': True}
# [GPU0] HF30_EPSREC_PROMPT_ALL             rotate_easy      -> {'SUBC': 0.9286, 'BGC': 0.9788, 'WRAP_E': 0.047, 'MD': 5.1635, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] HF30_EPSREC_PROMPT_ALL             rotate_all       -> {'SUBC': 0.8964, 'BGC': 0.9687, 'WRAP_E': 0.0423, 'MD': 9.9089, 'n': 66, 'expected_n': 66, 'complete_group': True}
# [GPU0] HF30_EPSREC_PROMPT_ALL             rotate_medium    -> {'SUBC': 0.9076, 'BGC': 0.9599, 'WRAP_E': 0.0384, 'MD': 8.386, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] HF30_EPSREC_PROMPT_ALL             rotate_hard      -> {'SUBC': 0.8528, 'BGC': 0.9672, 'WRAP_E': 0.0415, 'MD': 14.7629, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU0] HF30_EPSREC_PROMPT_ALL             rotate_nonhard   -> {'SUBC': 0.9181, 'BGC': 0.9694, 'WRAP_E': 0.0427, 'MD': 6.0934, 'n': 44, 'expected_n': 44, 'complete_group': True}
# [GPU0] HF30_EPSREC_PROMPT_ALL             resize_easy      -> {'SUBC': 0.938, 'BGC': 0.9665, 'WRAP_E': 0.0426, 'MD': 5.2441, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] HF30_EPSREC_PROMPT_ALL             resize_all       -> {'SUBC': 0.8908, 'BGC': 0.9642, 'WRAP_E': 0.0545, 'MD': 11.4041, 'n': 67, 'expected_n': 67, 'complete_group': True}
# [GPU0] HF30_EPSREC_PROMPT_ALL             resize_medium    -> {'SUBC': 0.8976, 'BGC': 0.9634, 'WRAP_E': 0.0622, 'MD': 9.5993, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] HF30_EPSREC_PROMPT_ALL             resize_hard      -> {'SUBC': 0.8391, 'BGC': 0.9626, 'WRAP_E': 0.0585, 'MD': 17.6452, 'n': 23, 'expected_n': 23, 'complete_group': True}
# [GPU0] HF30_EPSREC_PROMPT_ALL             resize_nonhard   -> {'SUBC': 0.9178, 'BGC': 0.965, 'WRAP_E': 0.0524, 'MD': 7.8479, 'n': 44, 'expected_n': 44, 'complete_group': True}
# [GPU0] HF30_EPSREC_PROMPT_ALL             all_easy         -> {'SUBC': 0.9437, 'BGC': 0.9699, 'WRAP_E': 0.0464, 'MD': 4.5842, 'n': 67, 'expected_n': 67, 'complete_group': True}
# [GPU0] HF30_EPSREC_PROMPT_ALL             all_medium       -> {'SUBC': 0.9211, 'BGC': 0.9626, 'WRAP_E': 0.053, 'MD': 6.8218, 'n': 66, 'expected_n': 66, 'complete_group': True}
# [GPU1] HF30_EPSREC_PROMPT_ALL             all_200          -> {'SUBC': 0.9154, 'BGC': 0.9655, 'WRAP_E': 0.0488, 'MD': 7.7106, 'n': 200, 'expected_n': 200, 'complete_group': True}
# [GPU0] HF30_EPSREC_PROMPT_ALL             all_hard         -> {'SUBC': 0.8815, 'BGC': 0.964, 'WRAP_E': 0.0471, 'MD': 11.7638, 'n': 67, 'expected_n': 67, 'complete_group': True}
# [GPU0] MIDHF_EPSREC_PROMPT_ALL            move_all         -> {'SUBC': 0.9588, 'BGC': 0.9638, 'WRAP_E': 0.0496, 'MD': 3.3535, 'n': 67, 'expected_n': 67, 'complete_group': True}
# [GPU0] MIDHF_EPSREC_PROMPT_ALL            move_easy        -> {'SUBC': 0.9635, 'BGC': 0.9647, 'WRAP_E': 0.0495, 'MD': 3.4441, 'n': 23, 'expected_n': 23, 'complete_group': True}
# [GPU1] HF30_EPSREC_PROMPT_ALL             all_nonhard      -> {'SUBC': 0.9325, 'BGC': 0.9663, 'WRAP_E': 0.0497, 'MD': 5.4974, 'n': 133, 'expected_n': 133, 'complete_group': True}
# [GPU0] MIDHF_EPSREC_PROMPT_ALL            move_medium      -> {'SUBC': 0.9582, 'BGC': 0.9644, 'WRAP_E': 0.0585, 'MD': 3.3154, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] MIDHF_EPSREC_PROMPT_ALL            move_hard        -> {'SUBC': 0.9545, 'BGC': 0.9622, 'WRAP_E': 0.0407, 'MD': 3.2563, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU0] MIDHF_EPSREC_PROMPT_ALL            move_nonhard     -> {'SUBC': 0.9609, 'BGC': 0.9645, 'WRAP_E': 0.0539, 'MD': 3.3832, 'n': 45, 'expected_n': 45, 'complete_group': True}
# [GPU0] MIDHF_EPSREC_PROMPT_ALL            rotate_easy      -> {'SUBC': 0.9286, 'BGC': 0.979, 'WRAP_E': 0.047, 'MD': 5.1292, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] MIDHF_EPSREC_PROMPT_ALL            rotate_all       -> {'SUBC': 0.8964, 'BGC': 0.9687, 'WRAP_E': 0.0423, 'MD': 9.8952, 'n': 66, 'expected_n': 66, 'complete_group': True}
# [GPU0] MIDHF_EPSREC_PROMPT_ALL            rotate_medium    -> {'SUBC': 0.9076, 'BGC': 0.96, 'WRAP_E': 0.0384, 'MD': 8.4295, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] MIDHF_EPSREC_PROMPT_ALL            rotate_hard      -> {'SUBC': 0.8528, 'BGC': 0.9671, 'WRAP_E': 0.0415, 'MD': 14.5787, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU0] MIDHF_EPSREC_PROMPT_ALL            rotate_nonhard   -> {'SUBC': 0.9181, 'BGC': 0.9695, 'WRAP_E': 0.0427, 'MD': 6.1037, 'n': 44, 'expected_n': 44, 'complete_group': True}
# [GPU0] MIDHF_EPSREC_PROMPT_ALL            resize_easy      -> {'SUBC': 0.9379, 'BGC': 0.9665, 'WRAP_E': 0.0426, 'MD': 5.1906, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] MIDHF_EPSREC_PROMPT_ALL            resize_all       -> {'SUBC': 0.8908, 'BGC': 0.9641, 'WRAP_E': 0.0545, 'MD': 10.9687, 'n': 67, 'expected_n': 67, 'complete_group': True}
# [GPU0] MIDHF_EPSREC_PROMPT_ALL            resize_medium    -> {'SUBC': 0.8976, 'BGC': 0.9635, 'WRAP_E': 0.0622, 'MD': 9.5471, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] MIDHF_EPSREC_PROMPT_ALL            resize_hard      -> {'SUBC': 0.8391, 'BGC': 0.9625, 'WRAP_E': 0.0585, 'MD': 16.4279, 'n': 23, 'expected_n': 23, 'complete_group': True}
# [GPU0] MIDHF_EPSREC_PROMPT_ALL            resize_nonhard   -> {'SUBC': 0.9178, 'BGC': 0.965, 'WRAP_E': 0.0524, 'MD': 7.7771, 'n': 44, 'expected_n': 44, 'complete_group': True}
# [GPU0] MIDHF_EPSREC_PROMPT_ALL            all_easy         -> {'SUBC': 0.9436, 'BGC': 0.97, 'WRAP_E': 0.0464, 'MD': 4.5546, 'n': 67, 'expected_n': 67, 'complete_group': True}
# [GPU0] MIDHF_EPSREC_PROMPT_ALL            all_medium       -> {'SUBC': 0.9212, 'BGC': 0.9626, 'WRAP_E': 0.053, 'MD': 6.8039, 'n': 66, 'expected_n': 66, 'complete_group': True}
# [GPU1] MIDHF_EPSREC_PROMPT_ALL            all_200          -> {'SUBC': 0.9154, 'BGC': 0.9655, 'WRAP_E': 0.0488, 'MD': 7.5833, 'n': 200, 'expected_n': 200, 'complete_group': True}
# [GPU0] MIDHF_EPSREC_PROMPT_ALL            all_hard         -> {'SUBC': 0.8815, 'BGC': 0.9639, 'WRAP_E': 0.0471, 'MD': 11.3577, 'n': 67, 'expected_n': 67, 'complete_group': True}
# [GPU0] EPSREC_PURE_ALL                    move_all         -> {'SUBC': 0.959, 'BGC': 0.9639, 'WRAP_E': 0.0495, 'MD': 3.4075, 'n': 67, 'expected_n': 67, 'complete_group': True}
# [GPU0] EPSREC_PURE_ALL                    move_easy        -> {'SUBC': 0.9637, 'BGC': 0.9645, 'WRAP_E': 0.0494, 'MD': 3.3161, 'n': 23, 'expected_n': 23, 'complete_group': True}
# [GPU1] MIDHF_EPSREC_PROMPT_ALL            all_nonhard      -> {'SUBC': 0.9325, 'BGC': 0.9663, 'WRAP_E': 0.0497, 'MD': 5.4985, 'n': 133, 'expected_n': 133, 'complete_group': True}
# [GPU0] EPSREC_PURE_ALL                    move_medium      -> {'SUBC': 0.9584, 'BGC': 0.9654, 'WRAP_E': 0.0584, 'MD': 3.2683, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] EPSREC_PURE_ALL                    move_hard        -> {'SUBC': 0.9545, 'BGC': 0.9618, 'WRAP_E': 0.0407, 'MD': 3.1192, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU0] EPSREC_PURE_ALL                    move_nonhard     -> {'SUBC': 0.9611, 'BGC': 0.9649, 'WRAP_E': 0.0538, 'MD': 3.3449, 'n': 45, 'expected_n': 45, 'complete_group': True}
# [GPU0] EPSREC_PURE_ALL                    rotate_easy      -> {'SUBC': 0.9287, 'BGC': 0.9789, 'WRAP_E': 0.0471, 'MD': 5.047, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] EPSREC_PURE_ALL                    rotate_all       -> {'SUBC': 0.8962, 'BGC': 0.9684, 'WRAP_E': 0.0423, 'MD': 9.6294, 'n': 66, 'expected_n': 66, 'complete_group': True}
# [GPU0] EPSREC_PURE_ALL                    rotate_medium    -> {'SUBC': 0.9075, 'BGC': 0.9598, 'WRAP_E': 0.0383, 'MD': 8.3667, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] EPSREC_PURE_ALL                    rotate_hard      -> {'SUBC': 0.8523, 'BGC': 0.9664, 'WRAP_E': 0.0416, 'MD': 14.0096, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU0] EPSREC_PURE_ALL                    rotate_nonhard   -> {'SUBC': 0.9181, 'BGC': 0.9694, 'WRAP_E': 0.0427, 'MD': 6.1397, 'n': 44, 'expected_n': 44, 'complete_group': True}
# [GPU0] EPSREC_PURE_ALL                    resize_easy      -> {'SUBC': 0.9383, 'BGC': 0.9669, 'WRAP_E': 0.0426, 'MD': 5.3292, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] EPSREC_PURE_ALL                    resize_all       -> {'SUBC': 0.8906, 'BGC': 0.9647, 'WRAP_E': 0.0544, 'MD': 10.9331, 'n': 67, 'expected_n': 67, 'complete_group': True}
# [GPU0] EPSREC_PURE_ALL                    resize_medium    -> {'SUBC': 0.8969, 'BGC': 0.9641, 'WRAP_E': 0.062, 'MD': 9.3508, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] EPSREC_PURE_ALL                    resize_hard      -> {'SUBC': 0.8391, 'BGC': 0.9631, 'WRAP_E': 0.0585, 'MD': 19.4713, 'n': 23, 'expected_n': 23, 'complete_group': True}
# [GPU0] EPSREC_PURE_ALL                    resize_nonhard   -> {'SUBC': 0.9176, 'BGC': 0.9655, 'WRAP_E': 0.0523, 'MD': 7.5773, 'n': 44, 'expected_n': 44, 'complete_group': True}
# [GPU0] EPSREC_PURE_ALL                    all_easy         -> {'SUBC': 0.9439, 'BGC': 0.97, 'WRAP_E': 0.0464, 'MD': 4.5656, 'n': 67, 'expected_n': 67, 'complete_group': True}
# [GPU0] EPSREC_PURE_ALL                    all_medium       -> {'SUBC': 0.9209, 'BGC': 0.9631, 'WRAP_E': 0.0529, 'MD': 6.5989, 'n': 66, 'expected_n': 66, 'complete_group': True}
# [GPU1] EPSREC_PURE_ALL                    all_200          -> {'SUBC': 0.9154, 'BGC': 0.9656, 'WRAP_E': 0.0488, 'MD': 7.6023, 'n': 200, 'expected_n': 200, 'complete_group': True}
# [GPU0] EPSREC_PURE_ALL                    all_hard         -> {'SUBC': 0.8813, 'BGC': 0.9638, 'WRAP_E': 0.0471, 'MD': 11.4838, 'n': 67, 'expected_n': 67, 'complete_group': True}
# [GPU0] EPSREC_BETA05_ALL                  move_all         -> {'SUBC': 0.959, 'BGC': 0.9639, 'WRAP_E': 0.0495, 'MD': 3.4075, 'n': 67, 'expected_n': 67, 'complete_group': True}
# [GPU0] EPSREC_BETA05_ALL                  move_easy        -> {'SUBC': 0.9637, 'BGC': 0.9645, 'WRAP_E': 0.0494, 'MD': 3.3161, 'n': 23, 'expected_n': 23, 'complete_group': True}
# [GPU1] EPSREC_PURE_ALL                    all_nonhard      -> {'SUBC': 0.9325, 'BGC': 0.9666, 'WRAP_E': 0.0496, 'MD': 5.477, 'n': 133, 'expected_n': 133, 'complete_group': True}
# [GPU0] EPSREC_BETA05_ALL                  move_medium      -> {'SUBC': 0.9584, 'BGC': 0.9654, 'WRAP_E': 0.0584, 'MD': 3.2683, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] EPSREC_BETA05_ALL                  move_hard        -> {'SUBC': 0.9545, 'BGC': 0.9618, 'WRAP_E': 0.0407, 'MD': 3.1192, 'n': 22, 'expected_n': 22, 'complete_group': True}
# MISSING CORE 336 [('EPSREC_BETA05_ALL', 'move_nonhard'), ('EPSREC_BETA05_ALL', 'rotate_all'), ('EPSREC_BETA05_ALL', 'rotate_easy'), ('EPSREC_BETA05_ALL', 'rotate_medium'), ('EPSREC_BETA05_ALL', 'rotate_hard'), ('EPSREC_BETA05_ALL', 'rotate_nonhard'), ('EPSREC_BETA05_ALL', 'resize_all'), ('EPSREC_BETA05_ALL', 'resize_easy'), ('EPSREC_BETA05_ALL', 'resize_medium'), ('EPSREC_BETA05_ALL', 'resize_hard'), ('EPSREC_BETA05_ALL', 'resize_nonhard'), ('EPSREC_BETA05_ALL', 'all_200'), ('EPSREC_BETA05_ALL', 'all_easy'), ('EPSREC_BETA05_ALL', 'all_medium'), ('EPSREC_BETA05_ALL', 'all_hard'), ('EPSREC_BETA05_ALL', 'all_nonhard'), ('APG_NOMOM_ALL', 'move_all'), ('APG_NOMOM_ALL', 'move_easy'), ('APG_NOMOM_ALL', 'move_medium'), ('APG_NOMOM_ALL', 'move_hard'), ('APG_NOMOM_ALL', 'move_nonhard'), ('APG_NOMOM_ALL', 'rotate_all'), ('APG_NOMOM_ALL', 'rotate_easy'), ('APG_NOMOM_ALL', 'rotate_medium'), ('APG_NOMOM_ALL', 'rotate_hard'), ('APG_NOMOM_ALL', 'rotate_nonhard'), ('APG_NOMOM_ALL', 'resize_all'), ('APG_NOMOM_ALL', 'resize_easy'), ('APG_NOMOM_ALL', 'resize_medium'), ('APG_NOMOM_ALL', 'resize_hard'), ('APG_NOMOM_ALL', 'resize_nonhard'), ('APG_NOMOM_ALL', 'all_200'), ('APG_NOMOM_ALL', 'all_easy'), ('APG_NOMOM_ALL', 'all_medium'), ('APG_NOMOM_ALL', 'all_hard'), ('APG_NOMOM_ALL', 'all_nonhard'), ('EPSREC_ETA025_ALL', 'move_all'), ('EPSREC_ETA025_ALL', 'move_easy'), ('EPSREC_ETA025_ALL', 'move_medium'), ('EPSREC_ETA025_ALL', 'move_hard'), ('EPSREC_ETA025_ALL', 'move_nonhard'), ('EPSREC_ETA025_ALL', 'rotate_all'), ('EPSREC_ETA025_ALL', 'rotate_easy'), ('EPSREC_ETA025_ALL', 'rotate_medium'), ('EPSREC_ETA025_ALL', 'rotate_hard'), ('EPSREC_ETA025_ALL', 'rotate_nonhard'), ('EPSREC_ETA025_ALL', 'resize_all'), ('EPSREC_ETA025_ALL', 'resize_easy'), ('EPSREC_ETA025_ALL', 'resize_medium'), ('EPSREC_ETA025_ALL', 'resize_hard'), ('EPSREC_ETA025_ALL', 'resize_nonhard'), ('EPSREC_ETA025_ALL', 'all_200'), ('EPSREC_ETA025_ALL', 'all_easy'), ('EPSREC_ETA025_ALL', 'all_medium'), ('EPSREC_ETA025_ALL', 'all_hard'), ('EPSREC_ETA025_ALL', 'all_nonhard'), ('HF30_EPSREC_PURE_ALL', 'move_all'), ('HF30_EPSREC_PURE_ALL', 'move_easy'), ('HF30_EPSREC_PURE_ALL', 'move_medium'), ('HF30_EPSREC_PURE_ALL', 'move_hard'), ('HF30_EPSREC_PURE_ALL', 'move_nonhard'), ('HF30_EPSREC_PURE_ALL', 'rotate_all'), ('HF30_EPSREC_PURE_ALL', 'rotate_easy'), ('HF30_EPSREC_PURE_ALL', 'rotate_medium'), ('HF30_EPSREC_PURE_ALL', 'rotate_hard'), ('HF30_EPSREC_PURE_ALL', 'rotate_nonhard'), ('HF30_EPSREC_PURE_ALL', 'resize_all'), ('HF30_EPSREC_PURE_ALL', 'resize_easy'), ('HF30_EPSREC_PURE_ALL', 'resize_medium'), ('HF30_EPSREC_PURE_ALL', 'resize_hard'), ('HF30_EPSREC_PURE_ALL', 'resize_nonhard'), ('HF30_EPSREC_PURE_ALL', 'all_200'), ('HF30_EPSREC_PURE_ALL', 'all_easy'), ('HF30_EPSREC_PURE_ALL', 'all_medium'), ('HF30_EPSREC_PURE_ALL', 'all_hard'), ('HF30_EPSREC_PURE_ALL', 'all_nonhard'), ('MIDHF_EPSREC_PURE_ALL', 'move_all'), ('MIDHF_EPSREC_PURE_ALL', 'move_easy'), ('MIDHF_EPSREC_PURE_ALL', 'move_medium'), ('MIDHF_EPSREC_PURE_ALL', 'move_hard'), ('MIDHF_EPSREC_PURE_ALL', 'move_nonhard'), ('MIDHF_EPSREC_PURE_ALL', 'rotate_all'), ('MIDHF_EPSREC_PURE_ALL', 'rotate_easy'), ('MIDHF_EPSREC_PURE_ALL', 'rotate_medium'), ('MIDHF_EPSREC_PURE_ALL', 'rotate_hard'), ('MIDHF_EPSREC_PURE_ALL', 'rotate_nonhard'), ('MIDHF_EPSREC_PURE_ALL', 'resize_all'), ('MIDHF_EPSREC_PURE_ALL', 'resize_easy'), ('MIDHF_EPSREC_PURE_ALL', 'resize_medium'), ('MIDHF_EPSREC_PURE_ALL', 'resize_hard'), ('MIDHF_EPSREC_PURE_ALL', 'resize_nonhard'), ('MIDHF_EPSREC_PURE_ALL', 'all_200'), ('MIDHF_EPSREC_PURE_ALL', 'all_easy'), ('MIDHF_EPSREC_PURE_ALL', 'all_medium'), ('MIDHF_EPSREC_PURE_ALL', 'all_hard'), ('MIDHF_EPSREC_PURE_ALL', 'all_nonhard'), ('RING4_MOVE_POST', 'move_all'), ('RING4_MOVE_POST', 'move_easy'), ('RING4_MOVE_POST', 'move_medium'), ('RING4_MOVE_POST', 'move_hard'), ('RING4_MOVE_POST', 'move_nonhard'), ('RING4_MOVE_POST', 'rotate_all'), ('RING4_MOVE_POST', 'rotate_easy'), ('RING4_MOVE_POST', 'rotate_medium'), ('RING4_MOVE_POST', 'rotate_h ...
# remaining queue 336
# saved /kaggle/working/B_core_results.json /kaggle/working/B_core_results.csv
