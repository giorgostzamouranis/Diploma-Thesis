# %% [markdown]
# # FreeFine — Wave 2 C Difficulty Structural — Shard 1/3 — v2
# ## Resumable FID / FDD(DINO) / KD evaluation
#
# This shard evaluates a deterministic sample-count-balanced partition.
# If it ever hits the Kaggle session deadline, Save Version, attach its own saved output, and rerun this SAME notebook.
#
# Use T4×2.

# %% [markdown]
# ## 1. Clone pinned FreeFine

# %%
# ===== Clone pinned FreeFine + clock =====
import os,time,subprocess,json,glob,shutil,csv,re,hashlib,random
NB_START=time.time()
COMMIT="4c9fdb971572b32edbeac13464659274c28decbb"
subprocess.run(
    f"mkdir -p /kaggle/temp && cd /kaggle/temp && rm -rf FreeFine && "
    f"git clone -q https://github.com/CIawevy/FreeFine.git && "
    f"cd FreeFine && git checkout -q {COMMIT}",
    shell=True,check=True
)
print("✓ cloned + pinned FreeFine",COMMIT[:14])
# Out:
# ✓ cloned + pinned FreeFine 4c9fdb971572b3

# %% [markdown]
# ## 2. Metric environment

# %%
# %%bash
# set -e
# V=/kaggle/temp/metric_env
# PY=$V/bin/python
# REPO=/kaggle/temp/FreeFine
# rm -rf "$V"
# uv venv --python 3.10.13 "$V"
# uv pip install --python "$PY" torch==2.6.0 torchvision==0.21.0 torchaudio==2.6.0 --index-url https://download.pytorch.org/whl/cu124
# uv pip install --python "$PY" "setuptools<70" wheel pip
# grep -vi '^clip' $REPO/evaluation/metrics/requirements.txt > /tmp/m.txt
# uv pip install --python "$PY" -r /tmp/m.txt
# uv pip install --python "$PY" "setuptools<70"
# uv pip install --python "$PY" --no-build-isolation "clip @ git+https://github.com/openai/CLIP.git@dcba3cb2e2827b402d2701e7e1c7d9fed8a20ef1"
# uv pip install --python "$PY" "pyarrow<16" "datasets<3"
# wget -q https://dl.fbaipublicfiles.com/mmf/clip/bpe_simple_vocab_16e6.txt.gz -P /tmp
# for d in $(find $V -path '*/site-packages/clip' -o -path '*open_clip' -type d); do
#   cp /tmp/bpe_simple_vocab_16e6.txt.gz "$d/" 2>/dev/null || true
# done
# echo "✓ metric_env OK"
# Out:
# ✓ metric_env OK
# warning: The `--system` flag has no effect, `uv venv` always ignores virtual environments when finding a Python interpreter; did you mean `--no-managed-python`?
# Downloading cpython-3.10.13-linux-x86_64-gnu (download) (26.1MiB)
#  Downloaded cpython-3.10.13-linux-x86_64-gnu (download)
# Using CPython 3.10.13
# Creating virtual environment at: /kaggle/temp/metric_env
# Activate with: source /kaggle/temp/metric_env/bin/activate
# Using Python 3.10.13 environment at: /kaggle/temp/metric_env
# Resolved 27 packages in 586ms
# Downloading networkx (1.6MiB)
# Downloading pillow (6.6MiB)
# Downloading sympy (5.9MiB)
# Downloading nvidia-cudnn-cu12 (634.0MiB)
# Downloading torchaudio (3.3MiB)
# Downloading nvidia-curand-cu12 (53.7MiB)
# Downloading nvidia-nccl-cu12 (179.9MiB)
# Downloading numpy (16.0MiB)
# Downloading torchvision (6.9MiB)
# Downloading triton (158.9MiB)
# Downloading torch (732.8MiB)
# Downloading nvidia-cuda-nvrtc-cu12 (23.5MiB)
# Downloading nvidia-cufft-cu12 (201.7MiB)
# Downloading nvidia-cusparse-cu12 (197.8MiB)
# Downloading nvidia-cuda-cupti-cu12 (13.2MiB)
# Downloading nvidia-cublas-cu12 (346.6MiB)
# Downloading nvidia-cusolver-cu12 (122.0MiB)
# Downloading nvidia-cusparselt-cu12 (143.1MiB)
# Downloading nvidia-nvjitlink-cu12 (20.1MiB)
#  Downloaded torchaudio
#  Downloaded torchvision
#  Downloaded nvidia-cuda-nvrtc-cu12
#  Downloaded nvidia-cuda-cupti-cu12
#  Downloaded nvidia-nvjitlink-cu12
#  Downloaded pillow
#  Downloaded nvidia-nccl-cu12
#  Downloaded networkx
#  Downloaded nvidia-curand-cu12
#  Downloaded triton
#  Downloaded nvidia-cufft-cu12
#  Downloaded numpy
#  Downloaded nvidia-cusparse-cu12
#  Downloaded nvidia-cudnn-cu12
#  Downloaded nvidia-cusolver-cu12
#  Downloaded nvidia-cusparselt-cu12
#  Downloaded sympy
#  Downloaded nvidia-cublas-cu12
#  Downloaded torch
# Prepared 27 packages in 33.98s
# Installed 27 packages in 360ms
#  + filelock==3.32.3
#  + fsspec==2026.7.0
#  + jinja2==3.1.6
#  + markupsafe==3.0.3
#  + mpmath==1.3.0
#  + networkx==3.4.2
#  + numpy==2.2.6
#  + nvidia-cublas-cu12==12.4.5.8
#  + nvidia-cuda-cupti-cu12==12.4.127
#  + nvidia-cuda-nvrtc-cu12==12.4.127
#  + nvidia-cuda-runtime-cu12==12.4.127
#  + nvidia-cudnn-cu12==9.1.0.70
#  + nvidia-cufft-cu12==11.2.1.3
#  + nvidia-curand-cu12==10.3.5.147
#  + nvidia-cusolver-cu12==11.6.1.9
#  + nvidia-cusparse-cu12==12.3.1.170
#  + nvidia-cusparselt-cu12==0.6.2
#  + nvidia-nccl-cu12==2.21.5
#  + nvidia-nvjitlink-cu12==12.4.127
#  + nvidia-nvtx-cu12==12.4.127
#  + pillow==12.3.0
#  + sympy==1.13.1
#  + torch==2.6.0+cu124
#  + torchaudio==2.6.0+cu124
#  + torchvision==0.21.0+cu124
#  + triton==3.2.0
#  + typing-extensions==4.16.0
# Using Python 3.10.13 environment at: /kaggle/temp/metric_env
# Resolved 4 packages in 220ms
# Downloading pip (1.7MiB)
#  Downloaded pip
# Prepared 4 packages in 191ms
# Installed 4 packages in 19ms
#  + packaging==26.3
#  + pip==26.2.1
#  + setuptools==69.5.1
#  + wheel==0.48.0
# Using Python 3.10.13 environment at: /kaggle/temp/metric_env
# Resolved 95 packages in 5.84s
# Downloading protobuf (1.0MiB)
# Downloading aiohttp (1.6MiB)
# Downloading pandas (12.2MiB)
# Downloading fonttools (5.0MiB)
# Downloading kiwisolver (1.6MiB)
# Downloading scipy (35.9MiB)
# Downloading tokenizers (3.0MiB)
# Downloading sentencepiece (1.3MiB)
# Downloading opencv-python (60.1MiB)
# Downloading pyarrow (47.7MiB)
# Downloading diffusers (3.1MiB)
# Downloading matplotlib (8.2MiB)
# Downloading hpsv2 (7.3MiB)
# Downloading numpy (15.6MiB)
# Downloading scikit-learn (12.9MiB)
# Downloading transformers (9.2MiB)
#    Building fairscale==0.4.13
#    Building clint==0.5.1
#    Building args==0.1.0
#  Downloaded protobuf
#  Downloaded sentencepiece
#  Downloaded kiwisolver
#  Downloaded aiohttp
#       Built args==0.1.0
#       Built clint==0.5.1
#       Built fairscale==0.4.13
#  Downloaded tokenizers
#  Downloaded diffusers
#  Downloaded fonttools
#  Downloaded hpsv2
#  Downloaded matplotlib
#  Downloaded scikit-learn
#  Downloaded numpy
#  Downloaded transformers
#  Downloaded pandas
#  Downloaded opencv-python
#  Downloaded scipy
#  Downloaded pyarrow
# Prepared 69 packages in 4.53s
# Uninstalled 1 package in 23ms
# Installed 69 packages in 374ms
#  + accelerate==1.3.0
#  + aiohappyeyeballs==2.7.1
#  + aiohttp==3.14.3
#  + aiosignal==1.4.0
#  + args==0.1.0
#  + async-timeout==5.0.1
#  + attrs==26.1.0
#  + braceexpand==0.1.7
#  + certifi==2026.7.22
#  + charset-normalizer==3.5.1
#  + clint==0.5.1
#  + cloudpickle==3.1.2
#  + contourpy==1.3.2
#  + cycler==0.12.1
#  + datasets==2.14.4
#  + diffusers==0.32.2
#  + dill==0.3.7
#  + einops==0.8.2
#  + exceptiongroup==1.3.1
#  + fairscale==0.4.13
#  + fonttools==4.64.0
#  + frozenlist==1.8.0
#  + ftfy==6.3.1
#  + hpsv2==1.2.0
#  + huggingface-hub==0.28.1
#  + idna==3.19
#  + image-reward==1.5
#  + importlib-metadata==9.0.1
#  + iniconfig==2.3.0
#  + joblib==1.6.0
#  + kiwisolver==1.5.1
#  + matplotlib==3.10.3
#  + multidict==6.7.1
#  + multiprocess==0.70.15
#  - numpy==2.2.6
#  + numpy==2.2.2
#  + opencv-python==4.11.0.86
#  + pandas==2.3.3
#  + pluggy==1.6.0
#  + propcache==0.5.2
#  + protobuf==3.20.3
#  + psutil==7.2.2
#  + pyarrow==25.0.1
#  + pyparsing==3.3.2
#  + pytest==7.2.0
#  + pytest-split==0.8.0
#  + python-dateutil==2.9.0.post0
#  + pytorch-fid==0.3.0
#  + pytz==2026.3.post1
#  + pyyaml==6.0.3
#  + regex==2026.9.3
#  + requests==2.34.2
#  + safetensors==0.8.0
#  + scikit-learn==1.6.1
#  + scipy==1.15.3
#  + sentencepiece==0.2.2
#  + six==1.17.0
#  + threadpoolctl==3.6.0
#  + timm==0.6.13
#  + tokenizers==0.21.4
#  + tomli==2.4.1
#  + tqdm==4.70.0
#  + transformers==4.48.3
#  + tzdata==2026.3
#  + urllib3==2.7.0
#  + wcwidth==0.8.3
#  + webdataset==1.0.2
#  + xxhash==4.0.1
#  + yarl==1.24.5
#  + zipp==4.1.0
# Using Python 3.10.13 environment at: /kaggle/temp/metric_env
# Checked 1 package in 6ms
# Using Python 3.10.13 environment at: /kaggle/temp/metric_env
#    Updating https://github.com/openai/CLIP.git (dcba3cb2e2827b402d2701e7e1c7d9fed8a20ef1)
#     Updated https://github.com/openai/CLIP.git (dcba3cb2e2827b402d2701e7e1c7d9fed8a20ef1)
# Resolved 32 packages in 4.23s
#    Building clip @ git+https://github.com/openai/CLIP.git@dcba3cb2e2827b402d2701e7e1c7d9fed8a20ef1
#       Built clip @ git+https://github.com/openai/CLIP.git@dcba3cb2e2827b402d2701e7e1c7d9fed8a20ef1
# Prepared 1 package in 573ms
# Installed 1 package in 1ms
#  + clip==1.0 (from git+https://github.com/openai/CLIP.git@dcba3cb2e2827b402d2701e7e1c7d9fed8a20ef1)
# Using Python 3.10.13 environment at: /kaggle/temp/metric_env
# Resolved 32 packages in 170ms
# Downloading numpy (17.4MiB)
# Downloading pyarrow (36.6MiB)
#  Downloaded pyarrow
#  Downloaded numpy
# Prepared 2 packages in 1.01s
# Uninstalled 2 packages in 41ms
# Installed 2 packages in 47ms
#  - numpy==2.2.2
#  + numpy==1.26.4
#  - pyarrow==25.0.1
#  + pyarrow==15.0.2

# %% [markdown]
# ## 3. Deterministic metric patches

# %%
# ===== Deterministic metric patches =====
import pathlib,re,py_compile
mr=pathlib.Path("/kaggle/temp/FreeFine/evaluation/metrics")
mp=mr/"main.py"
s=mp.read_text()
s=s.replace("args.3d","getattr(args,'3d')")
anchor="    args = parser.parse_args()\n"
assert anchor in s
seed_patch=anchor+"""    # Reproducible metric-side RNG (especially KD and model initialization paths)
    import random as _random, numpy as _np
    try:
        import torch as _torch
    except Exception:
        _torch=None
    _metric_seed=int(os.environ.get('FF_METRIC_SEED','42'))
    _random.seed(_metric_seed); _np.random.seed(_metric_seed)
    if _torch is not None:
        _torch.manual_seed(_metric_seed)
        if _torch.cuda.is_available(): _torch.cuda.manual_seed_all(_metric_seed)
"""
s=s.replace(anchor,seed_patch,1)
mp.write_text(s)

for f in [mr/"MD"/"mean_distance.py",mr/"MD"/"dift_sd.py"]:
    f.write_text(f.read_text().replace(
        "stabilityai/stable-diffusion-2-1",
        "sd2-community/stable-diffusion-2-1"
    ))

md=mr/"MD"/"mean_distance.py"
s=md.read_text()
needle="all_dist = []"
assert needle in s
s=s.replace(
    needle,
    needle+"\n    import torch as _st, os as _os; "
           "_seed=int(_os.environ.get('FF_MD_SEED','42')); "
           "_st.manual_seed(_seed); _st.cuda.manual_seed_all(_seed)",
    1
)
md.write_text(s)
for f in [mr/"main.py",mr/"MD"/"mean_distance.py",mr/"MD"/"dift_sd.py"]:
    py_compile.compile(str(f),doraise=True)
print("✓ deterministic metric patches installed")
# Out:
# ✓ deterministic metric patches installed

# %% [markdown]
# ## 4. Exact balanced-200 and expanded groups

# %%
# ===== Exact historical balanced-200 + expanded analysis groups =====
import os,glob,json,csv,random,shutil,hashlib
from collections import defaultdict,Counter
GEO="/kaggle/temp/GeoBenchMeta"
os.makedirs(f"{GEO}/Geo-Bench-2D",exist_ok=True)

def one(pattern,desc):
    xs=glob.glob(pattern,recursive=True)
    if not xs:
        raise FileNotFoundError(
            f"Missing {desc}. Attach the same original GeoBench inputs used by the final generation notebooks. Pattern={pattern}"
        )
    return xs[0]

cc=[c for c in glob.glob("/kaggle/input/**/Geo-Bench-2D",recursive=True)
    if os.path.isdir(f"{c}/source_img")]
if not cc:
    raise FileNotFoundError("Geo-Bench-2D/source_img not found under /kaggle/input")
CACHE=cc[0]
COARSE=one("/kaggle/input/**/coarse_img/*/*/*.png","coarse_img").split("/coarse_img/")[0]+"/coarse_img"
GENBASE=one("/kaggle/input/**/gen_results_2d_final/gen_results_2d_backup","baseline generation directory")
IB=os.path.dirname(os.path.dirname(os.path.dirname(
    one("/kaggle/input/**/inp_img_blended/**/inp_img.png","inp_img_blended")
)))
ANNs=one("/kaggle/input/**/annotation_2d.json","annotation_2d.json")
META=one("/kaggle/input/**/sample_metadata.csv","sample_metadata.csv")

for nm in ["source_img","source_mask","target_mask","source_img_full_v2"]:
    d=f"{GEO}/Geo-Bench-2D/{nm}"
    if os.path.lexists(d):
        os.remove(d) if os.path.islink(d) else shutil.rmtree(d)
    os.symlink(f"{CACHE}/{nm}",d)
for nm,sc in [("coarse_img",COARSE),("inp_img_blended",IB)]:
    d=f"{GEO}/Geo-Bench-2D/{nm}"
    if os.path.lexists(d):
        os.remove(d) if os.path.islink(d) else shutil.rmtree(d)
    os.symlink(sc,d)

shutil.copy(ANNs,f"{GEO}/annotation_2d.json")
ann=json.load(open(f"{GEO}/annotation_2d.json"))
meta=[r for r in csv.DictReader(open(META))
      if os.path.exists(f"{IB}/{r['da_n']}/{r['ins_id']}/inp_img.png")]

random.seed(42)
cells=defaultdict(list)
for r in meta:
    cells[(r["edit_type"],r["difficulty"])].append(r)
keys=sorted(cells)
per=200//len(keys)
picked=[]
for k in keys:
    pool=cells[k][:]
    random.shuffle(pool)
    picked += pool[:per]
chosen={(r["da_n"],r["ins_id"],r["case_id"]) for r in picked}
left=[r for r in meta if (r["da_n"],r["ins_id"],r["case_id"]) not in chosen]
random.shuffle(left)
for r in left:
    if len(picked)>=200: break
    picked.append(r)
picked=picked[:200]
counts=Counter(r["edit_type"] for r in picked)
assert counts==Counter({"move":67,"resize":67,"rotate":66}), counts
json.dump(picked,open(f"{GEO}/subset_meta.json","w"),indent=2)
sha=hashlib.sha256(
    "\n".join(sorted(f"{r['da_n']}|{r['ins_id']}|{r['case_id']}" for r in picked)).encode()
).hexdigest()
print("balanced-200:",dict(counts))
print("SHA256:",sha)
assert sha=="3d7c0172cba1e35693a3f20b562004bcfd6fc43e187160c945a23224d40cbd3c"

EVALROOT=f"{GEO}/gen_eval"
os.makedirs(EVALROOT,exist_ok=True)
d=f"{EVALROOT}/baseline"
if os.path.lexists(d):
    os.remove(d) if os.path.islink(d) else shutil.rmtree(d)
os.symlink(GENBASE,d)

def krow(r): return (r["da_n"],r["ins_id"],r["case_id"])
def mem(pred): return [krow(r) for r in picked if pred(r)]

groups={"all_200":mem(lambda r:True)}
for diff in ["easy","medium","hard"]:
    groups[f"all_{diff}"]=mem(lambda r,diff=diff:r["difficulty"]==diff)
groups["all_nonhard"]=mem(lambda r:r["difficulty"]!="hard")
for et in ["move","rotate","resize"]:
    groups[f"{et}_all"]=mem(lambda r,et=et:r["edit_type"]==et)
    groups[f"{et}_nonhard"]=mem(lambda r,et=et:r["edit_type"]==et and r["difficulty"]!="hard")
    for diff in ["easy","medium","hard"]:
        groups[f"{et}_{diff}"]=mem(lambda r,et=et,diff=diff:r["edit_type"]==et and r["difficulty"]==diff)

GROUP_ORDER=[
    "move_all","move_easy","move_medium","move_hard","move_nonhard",
    "rotate_all","rotate_easy","rotate_medium","rotate_hard","rotate_nonhard",
    "resize_all","resize_easy","resize_medium","resize_hard","resize_nonhard",
    "all_200","all_easy","all_medium","all_hard","all_nonhard",
]
assert all(g in groups for g in GROUP_ORDER)
print("group sizes:",{g:len(groups[g]) for g in GROUP_ORDER})
print("✓ dataset + expanded groups ready")
# Out:
# balanced-200: {'move': 67, 'resize': 67, 'rotate': 66}
# SHA256: 3d7c0172cba1e35693a3f20b562004bcfd6fc43e187160c945a23224d40cbd3c
# group sizes: {'move_all': 67, 'move_easy': 23, 'move_medium': 22, 'move_hard': 22, 'move_nonhard': 45, 'rotate_all': 66, 'rotate_easy': 22, 'rotate_medium': 22, 'rotate_hard': 22, 'rotate_nonhard': 44, 'resize_all': 67, 'resize_easy': 22, 'resize_medium': 22, 'resize_hard': 23, 'resize_nonhard': 44, 'all_200': 200, 'all_easy': 67, 'all_medium': 66, 'all_hard': 67, 'all_nonhard': 133}
# ✓ dataset + expanded groups ready

# %% [markdown]
# ## 5. Discover generated outputs

# %%
# ===== Discover best available Account A raw outputs model-by-model =====
import os,glob,json,shutil
RAW=['R1_ALL', 'HF30_ALL', 'FULL30_ALL', 'MID30_ALL', 'MIDHF30_ALL', 'FIXREF_HF30_ALL', 'FIXREF_MIDHF30_ALL', 'DIRHF30_ALL', 'HF30_PURE_ALL', 'FULL30_PURE_ALL', 'MID30_PURE_ALL', 'MIDHF30_PURE_ALL', 'FIXREF_HF30_PURE_ALL', 'FIXREF_MIDHF30_PURE_ALL', 'DIRHF30_PURE_ALL']
def pc(p):
    return len(glob.glob(p+"/**/*.png",recursive=True)) if os.path.isdir(p) else 0
EVALROOT=f"{GEO}/gen_eval"
roots={}
inventory={}
for tag in RAW:
    cands=glob.glob(f"/kaggle/input/**/finalA_structural/variants/{tag}",recursive=True)
    if not cands:
        inventory[tag]={"pngs":0,"expected":200,"complete":False,"root":None}
        print(f"{tag:30s} MISSING")
        continue
    root=max(cands,key=pc)
    n=pc(root)
    roots[tag]=root
    inventory[tag]={"pngs":n,"expected":200,"complete":n>=200,"root":root}
    print(f"{tag:30s} {n}/200", "✓" if n>=200 else "PARTIAL", root)
    d=f"{EVALROOT}/{tag}"
    if os.path.lexists(d):
        os.remove(d) if os.path.islink(d) else shutil.rmtree(d)
    os.symlink(root,d)
json.dump(inventory,open("/kaggle/working/A_inventory.json","w"),indent=2)
COMPLETE=[t for t in RAW if inventory[t]["complete"]]
PARTIAL=[t for t in RAW if inventory[t]["pngs"] and not inventory[t]["complete"]]
print("COMPLETE",len(COMPLETE),COMPLETE)
print("PARTIAL",PARTIAL)
# Out:
# R1_ALL                         200/200 ✓ /kaggle/input/notebooks/georgiostzamouranis/freefine-final-exhaustive-run-account-a-structu/finalA_structural/variants/R1_ALL
# HF30_ALL                       200/200 ✓ /kaggle/input/notebooks/georgiostzamouranis/freefine-final-exhaustive-run-account-a-structu/finalA_structural/variants/HF30_ALL
# FULL30_ALL                     200/200 ✓ /kaggle/input/notebooks/georgiostzamouranis/freefine-final-exhaustive-run-account-a-structu/finalA_structural/variants/FULL30_ALL
# MID30_ALL                      200/200 ✓ /kaggle/input/notebooks/georgiostzamouranis/01-w0a-resume-only-missing-dirhf-t4x2-v2/finalA_structural/variants/MID30_ALL
# MIDHF30_ALL                    200/200 ✓ /kaggle/input/notebooks/georgiostzamouranis/freefine-final-exhaustive-run-account-a-structu/finalA_structural/variants/MIDHF30_ALL
# FIXREF_HF30_ALL                200/200 ✓ /kaggle/input/notebooks/georgiostzamouranis/freefine-final-exhaustive-run-account-a-structu/finalA_structural/variants/FIXREF_HF30_ALL
# FIXREF_MIDHF30_ALL             200/200 ✓ /kaggle/input/notebooks/georgiostzamouranis/freefine-final-exhaustive-run-account-a-structu/finalA_structural/variants/FIXREF_MIDHF30_ALL
# DIRHF30_ALL                    200/200 ✓ /kaggle/input/notebooks/georgiostzamouranis/freefine-final-exhaustive-run-account-a-structu/finalA_structural/variants/DIRHF30_ALL
# HF30_PURE_ALL                  200/200 ✓ /kaggle/input/notebooks/georgiostzamouranis/01-w0a-resume-only-missing-dirhf-t4x2-v2/finalA_structural/variants/HF30_PURE_ALL
# FULL30_PURE_ALL                200/200 ✓ /kaggle/input/notebooks/georgiostzamouranis/01-w0a-resume-only-missing-dirhf-t4x2-v2/finalA_structural/variants/FULL30_PURE_ALL
# MID30_PURE_ALL                 200/200 ✓ /kaggle/input/notebooks/georgiostzamouranis/01-w0a-resume-only-missing-dirhf-t4x2-v2/finalA_structural/variants/MID30_PURE_ALL
# MIDHF30_PURE_ALL               200/200 ✓ /kaggle/input/notebooks/georgiostzamouranis/01-w0a-resume-only-missing-dirhf-t4x2-v2/finalA_structural/variants/MIDHF30_PURE_ALL
# FIXREF_HF30_PURE_ALL           200/200 ✓ /kaggle/input/notebooks/georgiostzamouranis/01-w0a-resume-only-missing-dirhf-t4x2-v2/finalA_structural/variants/FIXREF_HF30_PURE_ALL
# FIXREF_MIDHF30_PURE_ALL        200/200 ✓ /kaggle/input/notebooks/georgiostzamouranis/01-w0a-resume-only-missing-dirhf-t4x2-v2/finalA_structural/variants/FIXREF_MIDHF30_PURE_ALL
# DIRHF30_PURE_ALL               200/200 ✓ /kaggle/input/notebooks/georgiostzamouranis/01-w0a-resume-only-missing-dirhf-t4x2-v2/finalA_structural/variants/DIRHF30_PURE_ALL
# COMPLETE 15 ['R1_ALL', 'HF30_ALL', 'FULL30_ALL', 'MID30_ALL', 'MIDHF30_ALL', 'FIXREF_HF30_ALL', 'FIXREF_MIDHF30_ALL', 'DIRHF30_ALL', 'HF30_PURE_ALL', 'FULL30_PURE_ALL', 'MID30_PURE_ALL', 'MIDHF30_PURE_ALL', 'FIXREF_HF30_PURE_ALL', 'FIXREF_MIDHF30_PURE_ALL', 'DIRHF30_PURE_ALL']
# PARTIAL []

# %% [markdown]
# ## 6. Metric helpers

# %%
# ===== Metric helpers =====
import os,json,re,subprocess,time,threading,queue,pandas as pd
MET="/kaggle/temp/FreeFine/evaluation/metrics"
PY="/kaggle/temp/metric_env/bin/python"
EVALROOT=f"{GEO}/gen_eval"
ann=json.load(open(f"{GEO}/annotation_2d.json"))

def manifest(tag,group_name,ids):
    out={}; base=f"{EVALROOT}/{tag}"; used=0
    for d,i,e in ids:
        gp=f"{base}/{d}/{i}/{e}.png"
        if not os.path.exists(gp): continue
        lf=dict(ann[d]["instances"][i][e])
        lf["gen_img_path"]=f"gen_eval/{tag}/{d}/{i}/{e}.png"
        out.setdefault(d,{"instances":{}})["instances"].setdefault(i,{})[e]=lf
        used+=1
    p=f"{GEO}/m_{re.sub(r'[^A-Za-z0-9_.-]+','_',tag+'_'+group_name)}.json"
    json.dump(out,open(p,"w"))
    return p,used

def run_metric(manifest_path,task,gpu,md_seed=42,metric_seed=42):
    env=os.environ.copy()
    env.update({
        "CUDA_VISIBLE_DEVICES":str(gpu),
        "MPLBACKEND":"Agg",
        "HF_HOME":"/kaggle/temp/hf",
        "TORCH_HOME":"/kaggle/temp/torch",
        "PYTORCH_CUDA_ALLOC_CONF":"expandable_segments:True",
        "FF_MD_SEED":str(md_seed),
        "FF_METRIC_SEED":str(metric_seed),
        "TOKENIZERS_PARALLELISM":"false",
    })
    p=subprocess.run(
        [PY,"main.py","--path",manifest_path,"--use_relative_path","--base_dir",GEO,
         "--fid_path",f"{GEO}/Geo-Bench-2D/source_img_full_v2","--task",task,"--level","0"],
        cwd=MET,env=env,capture_output=True,text=True
    )
    txt=p.stdout+p.stderr
    vals={}
    for k in ["FID_DINO","FID_KD","FID","SUBC","BGC","WRAP_E","MD"]:
        h=re.findall(rf"(?:^|\s){k}:\s*([-\d.eE]+)",txt)
        if h: vals[k]=round(float(h[-1]),4)
    if p.returncode!=0:
        vals["_rc"]=p.returncode; vals["_tail"]=txt[-1800:]
    return vals

def parallel_jobs(jobs,worker_fn,deadline_hours=11.6):
    q=queue.Queue()
    for x in jobs: q.put(x)
    deadline=NB_START+deadline_hours*3600
    def _w(gpu):
        while time.time()<deadline-120:
            try: job=q.get_nowait()
            except queue.Empty: return
            try: worker_fn(gpu,*job)
            finally: q.task_done()
    ts=[threading.Thread(target=_w,args=(g,),daemon=True) for g in [0,1]]
    [t.start() for t in ts]; [t.join() for t in ts]
    return list(q.queue)
print("✓ metric helpers ready")
# Out:
# ✓ metric helpers ready

# %% [markdown]
# ## 7. Run

# %%
# ===== Wave 2 C Difficulty Structural SHARD 1/3: resumable FID/FDD(DINO)/KD =====
import copy, glob, json, os, pandas as pd

SHARD_ID=0
N_SHARDS=3
RESULT_STEM="A_fid_difficulty_results"
OUT_JSON=f"/kaggle/working/{RESULT_STEM}_shard{SHARD_ID+1}of{N_SHARDS}.json"
OUT_CSV=f"/kaggle/working/{RESULT_STEM}_shard{SHARD_ID+1}of{N_SHARDS}.csv"

EXPECTED_TAGS=['baseline', 'R1_ALL', 'HF30_ALL', 'FULL30_ALL', 'MID30_ALL', 'MIDHF30_ALL', 'FIXREF_HF30_ALL', 'FIXREF_MIDHF30_ALL', 'DIRHF30_ALL', 'HF30_PURE_ALL', 'FULL30_PURE_ALL', 'MID30_PURE_ALL', 'MIDHF30_PURE_ALL', 'FIXREF_HF30_PURE_ALL', 'FIXREF_MIDHF30_PURE_ALL', 'DIRHF30_PURE_ALL']
FID_GROUPS=['move_easy', 'move_medium', 'move_hard', 'move_nonhard', 'rotate_easy', 'rotate_medium', 'rotate_hard', 'rotate_nonhard', 'resize_easy', 'resize_medium', 'resize_hard', 'resize_nonhard', 'all_easy', 'all_medium', 'all_hard', 'all_nonhard']
TAGS=["baseline"]+[t for t in COMPLETE if os.path.exists(f"{EVALROOT}/{t}")]
TAGS=list(dict.fromkeys(TAGS))

print("Discovered TAGS",len(TAGS),TAGS)
assert set(TAGS)==set(EXPECTED_TAGS), (
    "Model inventory mismatch. Expected exact tag set but got missing/extra tags. "
    f"missing={sorted(set(EXPECTED_TAGS)-set(TAGS))} "
    f"extra={sorted(set(TAGS)-set(EXPECTED_TAGS))}"
)

# Determinism sanity check on the canonical baseline.
m,u=manifest("baseline","all_200",groups["all_200"])
g0=run_metric(m,"100000011",0,42,42)
assert u==200 and all(k in g0 for k in ["FID","FID_DINO","FID_KD"]),g0
print("✓ baseline FID-family sanity",g0)

def valid(v):
    return isinstance(v,dict) and all(k in v for k in ["FID","FID_DINO","FID_KD"]) and v.get("complete_group")

def score_file(p):
    try:
        x=json.load(open(p))
        return sum(valid(v) for gd in x.values() for v in gd.values())
    except Exception:
        return -1

# Optional self-resume: if a previous saved version of THIS SAME shard is attached,
# continue from it instead of recomputing completed cells.
resume_pattern=f"/kaggle/input/**/{RESULT_STEM}_shard{SHARD_ID+1}of{N_SHARDS}.json"
cands=glob.glob(resume_pattern,recursive=True)
if cands:
    best=max(cands,key=score_file)
    results=json.load(open(best))
    print("✓ resuming same shard from",best,"complete cells",score_file(best))
else:
    results={}
    print("Starting fresh shard")

# Deterministic LPT partition weighted by actual subgroup sample count.
all_jobs=[(tag,g) for tag in TAGS for g in FID_GROUPS]
weighted=sorted(
    [(len(groups[g]),tag,g) for tag,g in all_jobs],
    key=lambda x:(-x[0],x[1],x[2])
)
bins=[[] for _ in range(N_SHARDS)]
loads=[0 for _ in range(N_SHARDS)]
for w,tag,g in weighted:
    j=min(range(N_SHARDS),key=lambda z:(loads[z],z))
    bins[j].append((tag,g))
    loads[j]+=w

assigned=bins[SHARD_ID]
jobs=[(tag,g) for tag,g in assigned if not valid(results.get(tag,{}).get(g,{}))]
print("Balanced shard sample-loads:",loads)
print(f"This shard {SHARD_ID+1}/{N_SHARDS}: assigned={len(assigned)} remaining={len(jobs)} weighted_samples={loads[SHARD_ID]}")
print("First assigned jobs:",assigned[:80])

lock=threading.Lock()

def save():
    with lock:
        json.dump(results,open(OUT_JSON,"w"),indent=2)
        rows=[]
        for tag,gd in results.items():
            for g,v in gd.items():
                rows.append({"set":tag,"group":g,**v})
        pd.DataFrame(rows).to_csv(OUT_CSV,index=False)

def work(gpu,tag,g):
    m,u=manifest(tag,g,groups[g])
    if u!=len(groups[g]):
        with lock:
            results.setdefault(tag,{})[g]={
                "n":u,"expected_n":len(groups[g]),"complete_group":False
            }
        save()
        return
    v=run_metric(m,"100000011",gpu,42,42)
    v["n"]=u
    v["expected_n"]=len(groups[g])
    v["complete_group"]=True
    with lock:
        results.setdefault(tag,{})[g]=v
    save()
    print(f"[GPU{gpu}] {tag:34s} {g:16s} -> {v}",flush=True)

remaining=parallel_jobs(jobs,work,11.65)
save()

missing=[]
for tag,g in assigned:
    if not valid(results.get(tag,{}).get(g,{})):
        missing.append((tag,g))

print("SHARD MISSING",len(missing),missing[:200])
print("remaining queue",len(remaining))
print("saved",OUT_JSON,OUT_CSV)
assert not missing, (
    f"Shard {SHARD_ID+1}/{N_SHARDS} still has {len(missing)} missing cells. "
    "Save Version, attach this shard's own saved output, and rerun the SAME notebook; "
    "it will continue only the missing cells."
)
print(f"✓ WAVE 2 C Difficulty Structural SHARD {SHARD_ID+1}/{N_SHARDS} COMPLETE")
# Out:
# Discovered TAGS 16 ['baseline', 'R1_ALL', 'HF30_ALL', 'FULL30_ALL', 'MID30_ALL', 'MIDHF30_ALL', 'FIXREF_HF30_ALL', 'FIXREF_MIDHF30_ALL', 'DIRHF30_ALL', 'HF30_PURE_ALL', 'FULL30_PURE_ALL', 'MID30_PURE_ALL', 'MIDHF30_PURE_ALL', 'FIXREF_HF30_PURE_ALL', 'FIXREF_MIDHF30_PURE_ALL', 'DIRHF30_PURE_ALL']
# ✓ baseline FID-family sanity {'FID_DINO': 1636.8248, 'FID_KD': 0.1268, 'FID': 132.279}
# Starting fresh shard
# Balanced shard sample-loads: [3551, 3553, 3552]
# This shard 1/3: assigned=84 remaining=84 weighted_samples=3551
# First assigned jobs: [('DIRHF30_ALL', 'all_nonhard'), ('FIXREF_HF30_PURE_ALL', 'all_nonhard'), ('FULL30_ALL', 'all_nonhard'), ('HF30_PURE_ALL', 'all_nonhard'), ('MIDHF30_ALL', 'all_nonhard'), ('baseline', 'all_nonhard'), ('FIXREF_HF30_ALL', 'all_easy'), ('FIXREF_HF30_PURE_ALL', 'all_hard'), ('FIXREF_MIDHF30_PURE_ALL', 'all_easy'), ('FULL30_ALL', 'all_hard'), ('HF30_ALL', 'all_easy'), ('HF30_PURE_ALL', 'all_hard'), ('MID30_PURE_ALL', 'all_easy'), ('MIDHF30_ALL', 'all_hard'), ('R1_ALL', 'all_easy'), ('baseline', 'all_hard'), ('FIXREF_HF30_ALL', 'all_medium'), ('FIXREF_MIDHF30_PURE_ALL', 'all_medium'), ('HF30_ALL', 'all_medium'), ('MID30_PURE_ALL', 'all_medium'), ('R1_ALL', 'all_medium'), ('FIXREF_HF30_ALL', 'move_nonhard'), ('FIXREF_MIDHF30_PURE_ALL', 'move_nonhard'), ('HF30_ALL', 'move_nonhard'), ('MID30_PURE_ALL', 'move_nonhard'), ('R1_ALL', 'move_nonhard'), ('DIRHF30_ALL', 'rotate_nonhard'), ('FIXREF_HF30_ALL', 'resize_nonhard'), ('FIXREF_HF30_PURE_ALL', 'rotate_nonhard'), ('FIXREF_MIDHF30_PURE_ALL', 'resize_nonhard'), ('FULL30_ALL', 'rotate_nonhard'), ('HF30_ALL', 'resize_nonhard'), ('HF30_PURE_ALL', 'rotate_nonhard'), ('MID30_PURE_ALL', 'resize_nonhard'), ('MIDHF30_ALL', 'rotate_nonhard'), ('R1_ALL', 'resize_nonhard'), ('baseline', 'rotate_nonhard'), ('DIRHF30_PURE_ALL', 'resize_hard'), ('FIXREF_HF30_PURE_ALL', 'move_easy'), ('FIXREF_MIDHF30_ALL', 'resize_hard'), ('FULL30_ALL', 'move_easy'), ('FULL30_PURE_ALL', 'resize_hard'), ('HF30_PURE_ALL', 'move_easy'), ('MID30_ALL', 'resize_hard'), ('MIDHF30_ALL', 'move_easy'), ('MIDHF30_PURE_ALL', 'resize_hard'), ('baseline', 'move_easy'), ('DIRHF30_ALL', 'move_medium'), ('DIRHF30_ALL', 'rotate_easy'), ('DIRHF30_PURE_ALL', 'move_hard'), ('DIRHF30_PURE_ALL', 'resize_medium'), ('DIRHF30_PURE_ALL', 'rotate_medium'), ('FIXREF_HF30_ALL', 'resize_easy'), ('FIXREF_HF30_ALL', 'rotate_hard'), ('FIXREF_HF30_PURE_ALL', 'move_medium'), ('FIXREF_HF30_PURE_ALL', 'rotate_easy'), ('FIXREF_MIDHF30_ALL', 'move_hard'), ('FIXREF_MIDHF30_ALL', 'resize_medium'), ('FIXREF_MIDHF30_ALL', 'rotate_medium'), ('FIXREF_MIDHF30_PURE_ALL', 'resize_easy'), ('FIXREF_MIDHF30_PURE_ALL', 'rotate_hard'), ('FULL30_ALL', 'move_medium'), ('FULL30_ALL', 'rotate_easy'), ('FULL30_PURE_ALL', 'move_hard'), ('FULL30_PURE_ALL', 'resize_medium'), ('FULL30_PURE_ALL', 'rotate_medium'), ('HF30_ALL', 'resize_easy'), ('HF30_ALL', 'rotate_hard'), ('HF30_PURE_ALL', 'move_medium'), ('HF30_PURE_ALL', 'rotate_easy'), ('MID30_ALL', 'move_hard'), ('MID30_ALL', 'resize_medium'), ('MID30_ALL', 'rotate_medium'), ('MID30_PURE_ALL', 'resize_easy'), ('MID30_PURE_ALL', 'rotate_hard'), ('MIDHF30_ALL', 'move_medium'), ('MIDHF30_ALL', 'rotate_easy'), ('MIDHF30_PURE_ALL', 'move_hard'), ('MIDHF30_PURE_ALL', 'resize_medium'), ('MIDHF30_PURE_ALL', 'rotate_medium')]
# [GPU0] DIRHF30_ALL                        all_nonhard      -> {'FID_DINO': 1988.9922, 'FID_KD': 0.1823, 'FID': 158.4366, 'n': 133, 'expected_n': 133, 'complete_group': True}
# [GPU1] FIXREF_HF30_PURE_ALL               all_nonhard      -> {'FID_DINO': 1989.1008, 'FID_KD': 0.1785, 'FID': 157.4738, 'n': 133, 'expected_n': 133, 'complete_group': True}
# [GPU0] FULL30_ALL                         all_nonhard      -> {'FID_DINO': 1988.9675, 'FID_KD': 0.1824, 'FID': 158.4195, 'n': 133, 'expected_n': 133, 'complete_group': True}
# [GPU1] HF30_PURE_ALL                      all_nonhard      -> {'FID_DINO': 1989.0808, 'FID_KD': 0.1786, 'FID': 157.4789, 'n': 133, 'expected_n': 133, 'complete_group': True}
# [GPU0] MIDHF30_ALL                        all_nonhard      -> {'FID_DINO': 1989.0092, 'FID_KD': 0.1824, 'FID': 158.4256, 'n': 133, 'expected_n': 133, 'complete_group': True}
# [GPU1] baseline                           all_nonhard      -> {'FID_DINO': 1989.0325, 'FID_KD': 0.1785, 'FID': 157.4796, 'n': 133, 'expected_n': 133, 'complete_group': True}
# [GPU0] FIXREF_HF30_ALL                    all_easy         -> {'FID_DINO': 2518.2616, 'FID_KD': 0.266, 'FID': 203.4308, 'n': 67, 'expected_n': 67, 'complete_group': True}
# [GPU1] FIXREF_HF30_PURE_ALL               all_hard         -> {'FID_DINO': 2482.0086, 'FID_KD': 0.0965, 'FID': 209.8709, 'n': 67, 'expected_n': 67, 'complete_group': True}
# [GPU0] FIXREF_MIDHF30_PURE_ALL            all_easy         -> {'FID_DINO': 2520.4116, 'FID_KD': 0.2632, 'FID': 202.8626, 'n': 67, 'expected_n': 67, 'complete_group': True}
# [GPU1] FULL30_ALL                         all_hard         -> {'FID_DINO': 2485.5695, 'FID_KD': 0.1034, 'FID': 208.691, 'n': 67, 'expected_n': 67, 'complete_group': True}
# [GPU0] HF30_ALL                           all_easy         -> {'FID_DINO': 2518.2442, 'FID_KD': 0.2659, 'FID': 203.4503, 'n': 67, 'expected_n': 67, 'complete_group': True}
# [GPU1] HF30_PURE_ALL                      all_hard         -> {'FID_DINO': 2481.9721, 'FID_KD': 0.0965, 'FID': 209.9328, 'n': 67, 'expected_n': 67, 'complete_group': True}
# [GPU0] MID30_PURE_ALL                     all_easy         -> {'FID_DINO': 2520.3663, 'FID_KD': 0.263, 'FID': 202.8702, 'n': 67, 'expected_n': 67, 'complete_group': True}
# [GPU1] MIDHF30_ALL                        all_hard         -> {'FID_DINO': 2485.594, 'FID_KD': 0.1034, 'FID': 208.7249, 'n': 67, 'expected_n': 67, 'complete_group': True}
# [GPU0] R1_ALL                             all_easy         -> {'FID_DINO': 2518.2959, 'FID_KD': 0.2659, 'FID': 203.4427, 'n': 67, 'expected_n': 67, 'complete_group': True}
# [GPU1] baseline                           all_hard         -> {'FID_DINO': 2481.962, 'FID_KD': 0.0964, 'FID': 209.934, 'n': 67, 'expected_n': 67, 'complete_group': True}
# [GPU0] FIXREF_HF30_ALL                    all_medium       -> {'FID_DINO': 2474.9458, 'FID_KD': 0.1311, 'FID': 200.1682, 'n': 66, 'expected_n': 66, 'complete_group': True}
# [GPU1] FIXREF_MIDHF30_PURE_ALL            all_medium       -> {'FID_DINO': 2473.3179, 'FID_KD': 0.1265, 'FID': 198.8529, 'n': 66, 'expected_n': 66, 'complete_group': True}
# [GPU0] HF30_ALL                           all_medium       -> {'FID_DINO': 2474.9166, 'FID_KD': 0.131, 'FID': 200.18, 'n': 66, 'expected_n': 66, 'complete_group': True}
# [GPU1] MID30_PURE_ALL                     all_medium       -> {'FID_DINO': 2473.2757, 'FID_KD': 0.1266, 'FID': 198.8592, 'n': 66, 'expected_n': 66, 'complete_group': True}
# [GPU0] R1_ALL                             all_medium       -> {'FID_DINO': 2474.8839, 'FID_KD': 0.1308, 'FID': 200.1691, 'n': 66, 'expected_n': 66, 'complete_group': True}
# [GPU1] FIXREF_HF30_ALL                    move_nonhard     -> {'FID_DINO': 2777.3851, 'FID_KD': 0.1173, 'FID': 222.5553, 'n': 45, 'expected_n': 45, 'complete_group': True}
# [GPU0] FIXREF_MIDHF30_PURE_ALL            move_nonhard     -> {'FID_DINO': 2780.0816, 'FID_KD': 0.1036, 'FID': 220.1013, 'n': 45, 'expected_n': 45, 'complete_group': True}
# [GPU1] HF30_ALL                           move_nonhard     -> {'FID_DINO': 2777.3782, 'FID_KD': 0.1173, 'FID': 222.5778, 'n': 45, 'expected_n': 45, 'complete_group': True}
# [GPU0] MID30_PURE_ALL                     move_nonhard     -> {'FID_DINO': 2780.0247, 'FID_KD': 0.1037, 'FID': 220.087, 'n': 45, 'expected_n': 45, 'complete_group': True}
# [GPU1] R1_ALL                             move_nonhard     -> {'FID_DINO': 2777.3295, 'FID_KD': 0.1172, 'FID': 222.565, 'n': 45, 'expected_n': 45, 'complete_group': True}
# [GPU0] DIRHF30_ALL                        rotate_nonhard   -> {'FID_DINO': 2731.2766, 'FID_KD': 0.0992, 'FID': 231.6345, 'n': 44, 'expected_n': 44, 'complete_group': True}
# [GPU0] FIXREF_HF30_PURE_ALL               rotate_nonhard   -> {'FID_DINO': 2731.3759, 'FID_KD': 0.0993, 'FID': 231.5964, 'n': 44, 'expected_n': 44, 'complete_group': True}
# [GPU1] FIXREF_HF30_ALL                    resize_nonhard   -> {'FID_DINO': 2739.0869, 'FID_KD': 0.0653, 'FID': 222.0902, 'n': 44, 'expected_n': 44, 'complete_group': True}
# [GPU0] FIXREF_MIDHF30_PURE_ALL            resize_nonhard   -> {'FID_DINO': 2735.5425, 'FID_KD': 0.0705, 'FID': 221.8347, 'n': 44, 'expected_n': 44, 'complete_group': True}
# [GPU1] FULL30_ALL                         rotate_nonhard   -> {'FID_DINO': 2731.2692, 'FID_KD': 0.0994, 'FID': 231.5865, 'n': 44, 'expected_n': 44, 'complete_group': True}
# [GPU0] HF30_ALL                           resize_nonhard   -> {'FID_DINO': 2739.0774, 'FID_KD': 0.0652, 'FID': 222.0809, 'n': 44, 'expected_n': 44, 'complete_group': True}
# [GPU1] HF30_PURE_ALL                      rotate_nonhard   -> {'FID_DINO': 2731.299, 'FID_KD': 0.0993, 'FID': 231.6316, 'n': 44, 'expected_n': 44, 'complete_group': True}
# [GPU0] MID30_PURE_ALL                     resize_nonhard   -> {'FID_DINO': 2735.4841, 'FID_KD': 0.0705, 'FID': 221.8386, 'n': 44, 'expected_n': 44, 'complete_group': True}
# [GPU1] MIDHF30_ALL                        rotate_nonhard   -> {'FID_DINO': 2731.3699, 'FID_KD': 0.0993, 'FID': 231.6318, 'n': 44, 'expected_n': 44, 'complete_group': True}
# [GPU0] R1_ALL                             resize_nonhard   -> {'FID_DINO': 2739.143, 'FID_KD': 0.0651, 'FID': 222.0704, 'n': 44, 'expected_n': 44, 'complete_group': True}
# [GPU1] baseline                           rotate_nonhard   -> {'FID_DINO': 2731.281, 'FID_KD': 0.099, 'FID': 231.6236, 'n': 44, 'expected_n': 44, 'complete_group': True}
# [GPU0] DIRHF30_PURE_ALL                   resize_hard      -> {'FID_DINO': 3173.6663, 'FID_KD': 0.0435, 'FID': 274.3119, 'n': 23, 'expected_n': 23, 'complete_group': True}
# [GPU1] FIXREF_HF30_PURE_ALL               move_easy        -> {'FID_DINO': 3168.4738, 'FID_KD': 0.06, 'FID': 259.3363, 'n': 23, 'expected_n': 23, 'complete_group': True}
# [GPU0] FIXREF_MIDHF30_ALL                 resize_hard      -> {'FID_DINO': 3181.471, 'FID_KD': 0.0459, 'FID': 271.8312, 'n': 23, 'expected_n': 23, 'complete_group': True}
# [GPU1] FULL30_ALL                         move_easy        -> {'FID_DINO': 3164.249, 'FID_KD': 0.0673, 'FID': 261.1013, 'n': 23, 'expected_n': 23, 'complete_group': True}
# [GPU0] FULL30_PURE_ALL                    resize_hard      -> {'FID_DINO': 3173.6953, 'FID_KD': 0.0435, 'FID': 274.2646, 'n': 23, 'expected_n': 23, 'complete_group': True}
# [GPU1] HF30_PURE_ALL                      move_easy        -> {'FID_DINO': 3168.4047, 'FID_KD': 0.06, 'FID': 259.3703, 'n': 23, 'expected_n': 23, 'complete_group': True}
# [GPU0] MID30_ALL                          resize_hard      -> {'FID_DINO': 3181.6713, 'FID_KD': 0.0463, 'FID': 271.8208, 'n': 23, 'expected_n': 23, 'complete_group': True}
# [GPU1] MIDHF30_ALL                        move_easy        -> {'FID_DINO': 3164.1766, 'FID_KD': 0.0671, 'FID': 261.1153, 'n': 23, 'expected_n': 23, 'complete_group': True}
# [GPU0] MIDHF30_PURE_ALL                   resize_hard      -> {'FID_DINO': 3173.7161, 'FID_KD': 0.0434, 'FID': 274.2858, 'n': 23, 'expected_n': 23, 'complete_group': True}
# [GPU1] baseline                           move_easy        -> {'FID_DINO': 3168.3847, 'FID_KD': 0.0599, 'FID': 259.3902, 'n': 23, 'expected_n': 23, 'complete_group': True}
# [GPU0] DIRHF30_ALL                        move_medium      -> {'FID_DINO': 3276.2248, 'FID_KD': 0.1584, 'FID': 263.1083, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] DIRHF30_ALL                        rotate_easy      -> {'FID_DINO': 3149.6143, 'FID_KD': 0.353, 'FID': 275.7921, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU0] DIRHF30_PURE_ALL                   move_hard        -> {'FID_DINO': 3163.9098, 'FID_KD': -0.0717, 'FID': 279.866, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU0] DIRHF30_PURE_ALL                   rotate_medium    -> {'FID_DINO': 3195.6665, 'FID_KD': -0.0447, 'FID': 275.7605, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] DIRHF30_PURE_ALL                   resize_medium    -> {'FID_DINO': 3131.4911, 'FID_KD': 0.0953, 'FID': 262.3121, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU0] FIXREF_HF30_ALL                    resize_easy      -> {'FID_DINO': 3234.421, 'FID_KD': 0.1152, 'FID': 260.0996, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] FIXREF_HF30_ALL                    rotate_hard      -> {'FID_DINO': 3313.1172, 'FID_KD': 0.2093, 'FID': 273.6024, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU0] FIXREF_HF30_PURE_ALL               move_medium      -> {'FID_DINO': 3277.2188, 'FID_KD': 0.1393, 'FID': 258.7325, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] FIXREF_HF30_PURE_ALL               rotate_easy      -> {'FID_DINO': 3149.7855, 'FID_KD': 0.3534, 'FID': 275.7884, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU0] FIXREF_MIDHF30_ALL                 move_hard        -> {'FID_DINO': 3162.7314, 'FID_KD': -0.0591, 'FID': 277.4608, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] FIXREF_MIDHF30_ALL                 resize_medium    -> {'FID_DINO': 3142.9925, 'FID_KD': 0.0901, 'FID': 262.4571, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU0] FIXREF_MIDHF30_ALL                 rotate_medium    -> {'FID_DINO': 3195.51, 'FID_KD': -0.0447, 'FID': 275.6464, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] FIXREF_MIDHF30_PURE_ALL            resize_easy      -> {'FID_DINO': 3236.008, 'FID_KD': 0.1172, 'FID': 259.407, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU0] FIXREF_MIDHF30_PURE_ALL            rotate_hard      -> {'FID_DINO': 3313.054, 'FID_KD': 0.209, 'FID': 273.6035, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] FULL30_ALL                         move_medium      -> {'FID_DINO': 3276.2292, 'FID_KD': 0.1583, 'FID': 263.0825, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU0] FULL30_ALL                         rotate_easy      -> {'FID_DINO': 3149.5612, 'FID_KD': 0.3532, 'FID': 275.7695, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] FULL30_PURE_ALL                    move_hard        -> {'FID_DINO': 3163.826, 'FID_KD': -0.0715, 'FID': 279.8814, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU0] FULL30_PURE_ALL                    resize_medium    -> {'FID_DINO': 3131.3702, 'FID_KD': 0.0952, 'FID': 262.2665, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] FULL30_PURE_ALL                    rotate_medium    -> {'FID_DINO': 3195.6666, 'FID_KD': -0.0445, 'FID': 275.669, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU0] HF30_ALL                           resize_easy      -> {'FID_DINO': 3234.4812, 'FID_KD': 0.1154, 'FID': 260.1429, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] HF30_ALL                           rotate_hard      -> {'FID_DINO': 3313.2353, 'FID_KD': 0.2096, 'FID': 273.6302, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU0] HF30_PURE_ALL                      move_medium      -> {'FID_DINO': 3277.1993, 'FID_KD': 0.1394, 'FID': 258.754, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] HF30_PURE_ALL                      rotate_easy      -> {'FID_DINO': 3149.6107, 'FID_KD': 0.3531, 'FID': 275.8063, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU0] MID30_ALL                          move_hard        -> {'FID_DINO': 3162.8471, 'FID_KD': -0.0591, 'FID': 277.4402, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] MID30_ALL                          resize_medium    -> {'FID_DINO': 3143.2163, 'FID_KD': 0.0894, 'FID': 262.3598, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU0] MID30_ALL                          rotate_medium    -> {'FID_DINO': 3195.5428, 'FID_KD': -0.0447, 'FID': 275.7501, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU0] MID30_PURE_ALL                     rotate_hard      -> {'FID_DINO': 3313.3141, 'FID_KD': 0.2098, 'FID': 273.5968, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] MID30_PURE_ALL                     resize_easy      -> {'FID_DINO': 3235.9106, 'FID_KD': 0.1167, 'FID': 259.4247, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU0] MIDHF30_ALL                        move_medium      -> {'FID_DINO': 3276.3165, 'FID_KD': 0.1583, 'FID': 263.0831, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] MIDHF30_ALL                        rotate_easy      -> {'FID_DINO': 3149.7433, 'FID_KD': 0.3531, 'FID': 275.7944, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU0] MIDHF30_PURE_ALL                   move_hard        -> {'FID_DINO': 3163.9333, 'FID_KD': -0.0717, 'FID': 279.8881, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] MIDHF30_PURE_ALL                   resize_medium    -> {'FID_DINO': 3131.3487, 'FID_KD': 0.0951, 'FID': 262.2877, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU0] MIDHF30_PURE_ALL                   rotate_medium    -> {'FID_DINO': 3195.7388, 'FID_KD': -0.0446, 'FID': 275.7646, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] R1_ALL                             resize_easy      -> {'FID_DINO': 3234.5185, 'FID_KD': 0.1151, 'FID': 260.1483, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU0] R1_ALL                             rotate_hard      -> {'FID_DINO': 3313.3242, 'FID_KD': 0.2093, 'FID': 273.6189, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] baseline                           move_medium      -> {'FID_DINO': 3277.0153, 'FID_KD': 0.1392, 'FID': 258.6933, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU0] baseline                           rotate_easy      -> {'FID_DINO': 3149.731, 'FID_KD': 0.3529, 'FID': 275.7824, 'n': 22, 'expected_n': 22, 'complete_group': True}
# SHARD MISSING 0 []
# remaining queue 0
# saved /kaggle/working/A_fid_difficulty_results_shard1of3.json /kaggle/working/A_fid_difficulty_results_shard1of3.csv
# ✓ WAVE 2 C Difficulty Structural SHARD 1/3 COMPLETE
