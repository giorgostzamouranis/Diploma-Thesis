# %% [markdown]
# # FreeFine — Wave 2 D Difficulty Guidance/Post — Shard 4/4 — v2
# ## Resumable FID / FDD(DINO) / KD evaluation
#
# This shard evaluates a deterministic sample-count-balanced partition.
# If it ever hits the Kaggle session deadline, Save Version, attach its own saved output, and rerun this SAME notebook.
#
# Use T4×2.

# %% [markdown]
# ## 1. Clone pinned FreeFine

# %%
# ===== Clone pinned FreeFine + clock =====
import os,time,subprocess,json,glob,shutil,csv,re,hashlib,random
NB_START=time.time()
COMMIT="4c9fdb971572b32edbeac13464659274c28decbb"
subprocess.run(
    f"mkdir -p /kaggle/temp && cd /kaggle/temp && rm -rf FreeFine && "
    f"git clone -q https://github.com/CIawevy/FreeFine.git && "
    f"cd FreeFine && git checkout -q {COMMIT}",
    shell=True,check=True
)
print("✓ cloned + pinned FreeFine",COMMIT[:14])
# Out:
# ✓ cloned + pinned FreeFine 4c9fdb971572b3

# %% [markdown]
# ## 2. Metric environment

# %%
# %%bash
# set -e
# V=/kaggle/temp/metric_env
# PY=$V/bin/python
# REPO=/kaggle/temp/FreeFine
# rm -rf "$V"
# uv venv --python 3.10.13 "$V"
# uv pip install --python "$PY" torch==2.6.0 torchvision==0.21.0 torchaudio==2.6.0 --index-url https://download.pytorch.org/whl/cu124
# uv pip install --python "$PY" "setuptools<70" wheel pip
# grep -vi '^clip' $REPO/evaluation/metrics/requirements.txt > /tmp/m.txt
# uv pip install --python "$PY" -r /tmp/m.txt
# uv pip install --python "$PY" "setuptools<70"
# uv pip install --python "$PY" --no-build-isolation "clip @ git+https://github.com/openai/CLIP.git@dcba3cb2e2827b402d2701e7e1c7d9fed8a20ef1"
# uv pip install --python "$PY" "pyarrow<16" "datasets<3"
# wget -q https://dl.fbaipublicfiles.com/mmf/clip/bpe_simple_vocab_16e6.txt.gz -P /tmp
# for d in $(find $V -path '*/site-packages/clip' -o -path '*open_clip' -type d); do
#   cp /tmp/bpe_simple_vocab_16e6.txt.gz "$d/" 2>/dev/null || true
# done
# echo "✓ metric_env OK"
# Out:
# ✓ metric_env OK
# warning: The `--system` flag has no effect, `uv venv` always ignores virtual environments when finding a Python interpreter; did you mean `--no-managed-python`?
# Downloading cpython-3.10.13-linux-x86_64-gnu (download) (26.1MiB)
#  Downloaded cpython-3.10.13-linux-x86_64-gnu (download)
# Using CPython 3.10.13
# Creating virtual environment at: /kaggle/temp/metric_env
# Activate with: source /kaggle/temp/metric_env/bin/activate
# Using Python 3.10.13 environment at: /kaggle/temp/metric_env
# Resolved 27 packages in 702ms
# Downloading nvidia-cudnn-cu12 (634.0MiB)
# Downloading networkx (1.6MiB)
# Downloading numpy (16.0MiB)
# Downloading sympy (5.9MiB)
# Downloading pillow (6.6MiB)
# Downloading torchaudio (3.3MiB)
# Downloading nvidia-nccl-cu12 (179.9MiB)
# Downloading torch (732.8MiB)
# Downloading torchvision (6.9MiB)
# Downloading triton (158.9MiB)
# Downloading nvidia-cuda-nvrtc-cu12 (23.5MiB)
# Downloading nvidia-cufft-cu12 (201.7MiB)
# Downloading nvidia-cusparse-cu12 (197.8MiB)
# Downloading nvidia-cuda-cupti-cu12 (13.2MiB)
# Downloading nvidia-cublas-cu12 (346.6MiB)
# Downloading nvidia-cusolver-cu12 (122.0MiB)
# Downloading nvidia-cusparselt-cu12 (143.1MiB)
# Downloading nvidia-nvjitlink-cu12 (20.1MiB)
# Downloading nvidia-curand-cu12 (53.7MiB)
#  Downloaded torchaudio
#  Downloaded nvidia-cuda-cupti-cu12
#  Downloaded torchvision
#  Downloaded nvidia-cuda-nvrtc-cu12
#  Downloaded nvidia-nvjitlink-cu12
#  Downloaded pillow
#  Downloaded networkx
#  Downloaded triton
#  Downloaded nvidia-curand-cu12
#  Downloaded numpy
#  Downloaded nvidia-nccl-cu12
#  Downloaded nvidia-cufft-cu12
#  Downloaded nvidia-cudnn-cu12
#  Downloaded nvidia-cusolver-cu12
#  Downloaded nvidia-cusparse-cu12
#  Downloaded sympy
#  Downloaded nvidia-cusparselt-cu12
#  Downloaded nvidia-cublas-cu12
#  Downloaded torch
# Prepared 27 packages in 34.35s
# Installed 27 packages in 437ms
#  + filelock==3.32.3
#  + fsspec==2026.7.0
#  + jinja2==3.1.6
#  + markupsafe==3.0.3
#  + mpmath==1.3.0
#  + networkx==3.4.2
#  + numpy==2.2.6
#  + nvidia-cublas-cu12==12.4.5.8
#  + nvidia-cuda-cupti-cu12==12.4.127
#  + nvidia-cuda-nvrtc-cu12==12.4.127
#  + nvidia-cuda-runtime-cu12==12.4.127
#  + nvidia-cudnn-cu12==9.1.0.70
#  + nvidia-cufft-cu12==11.2.1.3
#  + nvidia-curand-cu12==10.3.5.147
#  + nvidia-cusolver-cu12==11.6.1.9
#  + nvidia-cusparse-cu12==12.3.1.170
#  + nvidia-cusparselt-cu12==0.6.2
#  + nvidia-nccl-cu12==2.21.5
#  + nvidia-nvjitlink-cu12==12.4.127
#  + nvidia-nvtx-cu12==12.4.127
#  + pillow==12.3.0
#  + sympy==1.13.1
#  + torch==2.6.0+cu124
#  + torchaudio==2.6.0+cu124
#  + torchvision==0.21.0+cu124
#  + triton==3.2.0
#  + typing-extensions==4.16.0
# Using Python 3.10.13 environment at: /kaggle/temp/metric_env
# Resolved 4 packages in 234ms
# Downloading pip (1.7MiB)
#  Downloaded pip
# Prepared 4 packages in 169ms
# Installed 4 packages in 19ms
#  + packaging==26.3
#  + pip==26.2.1
#  + setuptools==69.5.1
#  + wheel==0.48.0
# Using Python 3.10.13 environment at: /kaggle/temp/metric_env
# Resolved 95 packages in 2.43s
# Downloading numpy (15.6MiB)
# Downloading sentencepiece (1.3MiB)
# Downloading pyarrow (47.7MiB)
# Downloading aiohttp (1.6MiB)
# Downloading fonttools (5.0MiB)
# Downloading pandas (12.2MiB)
# Downloading kiwisolver (1.6MiB)
# Downloading opencv-python (60.1MiB)
# Downloading transformers (9.2MiB)
# Downloading diffusers (3.1MiB)
# Downloading protobuf (1.0MiB)
# Downloading matplotlib (8.2MiB)
# Downloading scipy (35.9MiB)
# Downloading hpsv2 (7.3MiB)
# Downloading scikit-learn (12.9MiB)
# Downloading tokenizers (3.0MiB)
#    Building clint==0.5.1
#    Building fairscale==0.4.13
#    Building args==0.1.0
#  Downloaded protobuf
#       Built args==0.1.0
#  Downloaded sentencepiece
#       Built clint==0.5.1
#  Downloaded kiwisolver
#  Downloaded aiohttp
#       Built fairscale==0.4.13
#  Downloaded tokenizers
#  Downloaded diffusers
#  Downloaded fonttools
#  Downloaded hpsv2
#  Downloaded matplotlib
#  Downloaded scikit-learn
#  Downloaded numpy
#  Downloaded transformers
#  Downloaded pandas
#  Downloaded opencv-python
#  Downloaded scipy
#  Downloaded pyarrow
# Prepared 69 packages in 3.93s
# Uninstalled 1 package in 23ms
# Installed 69 packages in 258ms
#  + accelerate==1.3.0
#  + aiohappyeyeballs==2.7.1
#  + aiohttp==3.14.3
#  + aiosignal==1.4.0
#  + args==0.1.0
#  + async-timeout==5.0.1
#  + attrs==26.1.0
#  + braceexpand==0.1.7
#  + certifi==2026.7.22
#  + charset-normalizer==3.5.1
#  + clint==0.5.1
#  + cloudpickle==3.1.2
#  + contourpy==1.3.2
#  + cycler==0.12.1
#  + datasets==2.14.4
#  + diffusers==0.32.2
#  + dill==0.3.7
#  + einops==0.8.2
#  + exceptiongroup==1.3.1
#  + fairscale==0.4.13
#  + fonttools==4.64.0
#  + frozenlist==1.8.0
#  + ftfy==6.3.1
#  + hpsv2==1.2.0
#  + huggingface-hub==0.28.1
#  + idna==3.19
#  + image-reward==1.5
#  + importlib-metadata==9.0.1
#  + iniconfig==2.3.0
#  + joblib==1.6.0
#  + kiwisolver==1.5.1
#  + matplotlib==3.10.3
#  + multidict==6.7.1
#  + multiprocess==0.70.15
#  - numpy==2.2.6
#  + numpy==2.2.2
#  + opencv-python==4.11.0.86
#  + pandas==2.3.3
#  + pluggy==1.6.0
#  + propcache==0.5.2
#  + protobuf==3.20.3
#  + psutil==7.2.2
#  + pyarrow==25.0.1
#  + pyparsing==3.3.2
#  + pytest==7.2.0
#  + pytest-split==0.8.0
#  + python-dateutil==2.9.0.post0
#  + pytorch-fid==0.3.0
#  + pytz==2026.3.post1
#  + pyyaml==6.0.3
#  + regex==2026.9.3
#  + requests==2.34.2
#  + safetensors==0.8.0
#  + scikit-learn==1.6.1
#  + scipy==1.15.3
#  + sentencepiece==0.2.2
#  + six==1.17.0
#  + threadpoolctl==3.6.0
#  + timm==0.6.13
#  + tokenizers==0.21.4
#  + tomli==2.4.1
#  + tqdm==4.70.0
#  + transformers==4.48.3
#  + tzdata==2026.3
#  + urllib3==2.7.0
#  + wcwidth==0.8.3
#  + webdataset==1.0.2
#  + xxhash==4.0.1
#  + yarl==1.24.5
#  + zipp==4.1.0
# Using Python 3.10.13 environment at: /kaggle/temp/metric_env
# Checked 1 package in 4ms
# Using Python 3.10.13 environment at: /kaggle/temp/metric_env
#    Updating https://github.com/openai/CLIP.git (dcba3cb2e2827b402d2701e7e1c7d9fed8a20ef1)
#     Updated https://github.com/openai/CLIP.git (dcba3cb2e2827b402d2701e7e1c7d9fed8a20ef1)
# Resolved 32 packages in 3.47s
#    Building clip @ git+https://github.com/openai/CLIP.git@dcba3cb2e2827b402d2701e7e1c7d9fed8a20ef1
#       Built clip @ git+https://github.com/openai/CLIP.git@dcba3cb2e2827b402d2701e7e1c7d9fed8a20ef1
# Prepared 1 package in 443ms
# Installed 1 package in 1ms
#  + clip==1.0 (from git+https://github.com/openai/CLIP.git@dcba3cb2e2827b402d2701e7e1c7d9fed8a20ef1)
# Using Python 3.10.13 environment at: /kaggle/temp/metric_env
# Resolved 32 packages in 134ms
# Downloading numpy (17.4MiB)
# Downloading pyarrow (36.6MiB)
#  Downloaded pyarrow
#  Downloaded numpy
# Prepared 2 packages in 832ms
# Uninstalled 2 packages in 30ms
# Installed 2 packages in 29ms
#  - numpy==2.2.2
#  + numpy==1.26.4
#  - pyarrow==25.0.1
#  + pyarrow==15.0.2

# %% [markdown]
# ## 3. Deterministic metric patches

# %%
# ===== Deterministic metric patches =====
import pathlib,re,py_compile
mr=pathlib.Path("/kaggle/temp/FreeFine/evaluation/metrics")
mp=mr/"main.py"
s=mp.read_text()
s=s.replace("args.3d","getattr(args,'3d')")
anchor="    args = parser.parse_args()\n"
assert anchor in s
seed_patch=anchor+"""    # Reproducible metric-side RNG (especially KD and model initialization paths)
    import random as _random, numpy as _np
    try:
        import torch as _torch
    except Exception:
        _torch=None
    _metric_seed=int(os.environ.get('FF_METRIC_SEED','42'))
    _random.seed(_metric_seed); _np.random.seed(_metric_seed)
    if _torch is not None:
        _torch.manual_seed(_metric_seed)
        if _torch.cuda.is_available(): _torch.cuda.manual_seed_all(_metric_seed)
"""
s=s.replace(anchor,seed_patch,1)
mp.write_text(s)

for f in [mr/"MD"/"mean_distance.py",mr/"MD"/"dift_sd.py"]:
    f.write_text(f.read_text().replace(
        "stabilityai/stable-diffusion-2-1",
        "sd2-community/stable-diffusion-2-1"
    ))

md=mr/"MD"/"mean_distance.py"
s=md.read_text()
needle="all_dist = []"
assert needle in s
s=s.replace(
    needle,
    needle+"\n    import torch as _st, os as _os; "
           "_seed=int(_os.environ.get('FF_MD_SEED','42')); "
           "_st.manual_seed(_seed); _st.cuda.manual_seed_all(_seed)",
    1
)
md.write_text(s)
for f in [mr/"main.py",mr/"MD"/"mean_distance.py",mr/"MD"/"dift_sd.py"]:
    py_compile.compile(str(f),doraise=True)
print("✓ deterministic metric patches installed")
# Out:
# ✓ deterministic metric patches installed

# %% [markdown]
# ## 4. Exact balanced-200 and expanded groups

# %%
# ===== Exact historical balanced-200 + expanded analysis groups =====
import os,glob,json,csv,random,shutil,hashlib
from collections import defaultdict,Counter
GEO="/kaggle/temp/GeoBenchMeta"
os.makedirs(f"{GEO}/Geo-Bench-2D",exist_ok=True)

def one(pattern,desc):
    xs=glob.glob(pattern,recursive=True)
    if not xs:
        raise FileNotFoundError(
            f"Missing {desc}. Attach the same original GeoBench inputs used by the final generation notebooks. Pattern={pattern}"
        )
    return xs[0]

cc=[c for c in glob.glob("/kaggle/input/**/Geo-Bench-2D",recursive=True)
    if os.path.isdir(f"{c}/source_img")]
if not cc:
    raise FileNotFoundError("Geo-Bench-2D/source_img not found under /kaggle/input")
CACHE=cc[0]
COARSE=one("/kaggle/input/**/coarse_img/*/*/*.png","coarse_img").split("/coarse_img/")[0]+"/coarse_img"
GENBASE=one("/kaggle/input/**/gen_results_2d_final/gen_results_2d_backup","baseline generation directory")
IB=os.path.dirname(os.path.dirname(os.path.dirname(
    one("/kaggle/input/**/inp_img_blended/**/inp_img.png","inp_img_blended")
)))
ANNs=one("/kaggle/input/**/annotation_2d.json","annotation_2d.json")
META=one("/kaggle/input/**/sample_metadata.csv","sample_metadata.csv")

for nm in ["source_img","source_mask","target_mask","source_img_full_v2"]:
    d=f"{GEO}/Geo-Bench-2D/{nm}"
    if os.path.lexists(d):
        os.remove(d) if os.path.islink(d) else shutil.rmtree(d)
    os.symlink(f"{CACHE}/{nm}",d)
for nm,sc in [("coarse_img",COARSE),("inp_img_blended",IB)]:
    d=f"{GEO}/Geo-Bench-2D/{nm}"
    if os.path.lexists(d):
        os.remove(d) if os.path.islink(d) else shutil.rmtree(d)
    os.symlink(sc,d)

shutil.copy(ANNs,f"{GEO}/annotation_2d.json")
ann=json.load(open(f"{GEO}/annotation_2d.json"))
meta=[r for r in csv.DictReader(open(META))
      if os.path.exists(f"{IB}/{r['da_n']}/{r['ins_id']}/inp_img.png")]

random.seed(42)
cells=defaultdict(list)
for r in meta:
    cells[(r["edit_type"],r["difficulty"])].append(r)
keys=sorted(cells)
per=200//len(keys)
picked=[]
for k in keys:
    pool=cells[k][:]
    random.shuffle(pool)
    picked += pool[:per]
chosen={(r["da_n"],r["ins_id"],r["case_id"]) for r in picked}
left=[r for r in meta if (r["da_n"],r["ins_id"],r["case_id"]) not in chosen]
random.shuffle(left)
for r in left:
    if len(picked)>=200: break
    picked.append(r)
picked=picked[:200]
counts=Counter(r["edit_type"] for r in picked)
assert counts==Counter({"move":67,"resize":67,"rotate":66}), counts
json.dump(picked,open(f"{GEO}/subset_meta.json","w"),indent=2)
sha=hashlib.sha256(
    "\n".join(sorted(f"{r['da_n']}|{r['ins_id']}|{r['case_id']}" for r in picked)).encode()
).hexdigest()
print("balanced-200:",dict(counts))
print("SHA256:",sha)
assert sha=="3d7c0172cba1e35693a3f20b562004bcfd6fc43e187160c945a23224d40cbd3c"

EVALROOT=f"{GEO}/gen_eval"
os.makedirs(EVALROOT,exist_ok=True)
d=f"{EVALROOT}/baseline"
if os.path.lexists(d):
    os.remove(d) if os.path.islink(d) else shutil.rmtree(d)
os.symlink(GENBASE,d)

def krow(r): return (r["da_n"],r["ins_id"],r["case_id"])
def mem(pred): return [krow(r) for r in picked if pred(r)]

groups={"all_200":mem(lambda r:True)}
for diff in ["easy","medium","hard"]:
    groups[f"all_{diff}"]=mem(lambda r,diff=diff:r["difficulty"]==diff)
groups["all_nonhard"]=mem(lambda r:r["difficulty"]!="hard")
for et in ["move","rotate","resize"]:
    groups[f"{et}_all"]=mem(lambda r,et=et:r["edit_type"]==et)
    groups[f"{et}_nonhard"]=mem(lambda r,et=et:r["edit_type"]==et and r["difficulty"]!="hard")
    for diff in ["easy","medium","hard"]:
        groups[f"{et}_{diff}"]=mem(lambda r,et=et,diff=diff:r["edit_type"]==et and r["difficulty"]==diff)

GROUP_ORDER=[
    "move_all","move_easy","move_medium","move_hard","move_nonhard",
    "rotate_all","rotate_easy","rotate_medium","rotate_hard","rotate_nonhard",
    "resize_all","resize_easy","resize_medium","resize_hard","resize_nonhard",
    "all_200","all_easy","all_medium","all_hard","all_nonhard",
]
assert all(g in groups for g in GROUP_ORDER)
print("group sizes:",{g:len(groups[g]) for g in GROUP_ORDER})
print("✓ dataset + expanded groups ready")
# Out:
# balanced-200: {'move': 67, 'resize': 67, 'rotate': 66}
# SHA256: 3d7c0172cba1e35693a3f20b562004bcfd6fc43e187160c945a23224d40cbd3c
# group sizes: {'move_all': 67, 'move_easy': 23, 'move_medium': 22, 'move_hard': 22, 'move_nonhard': 45, 'rotate_all': 66, 'rotate_easy': 22, 'rotate_medium': 22, 'rotate_hard': 22, 'rotate_nonhard': 44, 'resize_all': 67, 'resize_easy': 22, 'resize_medium': 22, 'resize_hard': 23, 'resize_nonhard': 44, 'all_200': 200, 'all_easy': 67, 'all_medium': 66, 'all_hard': 67, 'all_nonhard': 133}
# ✓ dataset + expanded groups ready

# %% [markdown]
# ## 5. Discover generated outputs

# %%
# ===== Discover Account B raw outputs + rebuild full post-hoc variants =====
import os,glob,json,shutil,numpy as np,cv2
from PIL import Image
RAW_ALL=['CFG10_PROMPT_ALL', 'EPSREC_PROMPT_ALL', 'EPSREC_R1_ALL', 'PRES03_GLOBAL', 'HF30_EPSREC_R1_ALL', 'HF30_EPSREC_PROMPT_ALL', 'MIDHF_EPSREC_PROMPT_ALL', 'EPSREC_PURE_ALL', 'EPSREC_BETA05_ALL', 'APG_NOMOM_ALL', 'EPSREC_ETA025_ALL', 'HF30_EPSREC_PURE_ALL', 'MIDHF_EPSREC_PURE_ALL']
MOVE_RAW=['EXACT_RING8_MOVE', 'AA_RING8_MOVE']
EXPECTED={**{t:200 for t in RAW_ALL}, **{t:67 for t in MOVE_RAW}}
RAW=RAW_ALL+MOVE_RAW

def pc(p):
    return len(glob.glob(p+"/**/*.png",recursive=True)) if os.path.isdir(p) else 0

EVALROOT=f"{GEO}/gen_eval"
roots={}; inventory={}
for tag in RAW:
    cands=glob.glob(f"/kaggle/input/**/finalB_guidance_move/variants/{tag}",recursive=True)
    if not cands:
        inventory[tag]={"pngs":0,"expected":EXPECTED[tag],"complete":False,"root":None}
        print(f"{tag:32s} MISSING")
        continue
    root=max(cands,key=pc); n=pc(root); roots[tag]=root
    inventory[tag]={"pngs":n,"expected":EXPECTED[tag],"complete":n>=EXPECTED[tag],"root":root}
    print(f"{tag:32s} {n}/{EXPECTED[tag]}", "✓" if n>=EXPECTED[tag] else "PARTIAL", root)
    d=f"{EVALROOT}/{tag}"
    if os.path.lexists(d):
        os.remove(d) if os.path.islink(d) else shutil.rmtree(d)
    os.symlink(root,d)
json.dump(inventory,open("/kaggle/working/B_inventory.json","w"),indent=2)
COMPLETE_ALL=[t for t in RAW_ALL if inventory[t]["complete"]]

BASE=f"{EVALROOT}/baseline"
WORK="/kaggle/working/finalB_post_variants"
os.makedirs(WORK,exist_ok=True)
picked=json.load(open(f"{GEO}/subset_meta.json"))

def key(r): return (r["da_n"],r["ins_id"],r["case_id"])
def reset(p):
    if os.path.lexists(p):
        os.remove(p) if os.path.islink(p) or os.path.isfile(p) else shutil.rmtree(p)
    os.makedirs(p,exist_ok=True)
def link(tag,root):
    d=f"{EVALROOT}/{tag}"
    if os.path.lexists(d):
        os.remove(d) if os.path.islink(d) else shutil.rmtree(d)
    os.symlink(root,d)
def ring(tag,w,global_apply=False):
    root=f"{WORK}/{tag}"; reset(root)
    for r in picked:
        d,i,e=key(r)
        bp=f"{BASE}/{d}/{i}/{e}.png"
        dst=f"{root}/{d}/{i}/{e}.png"
        os.makedirs(os.path.dirname(dst),exist_ok=True)
        if not(global_apply or r["edit_type"]=="move"):
            os.symlink(os.path.realpath(bp),dst); continue
        C=np.array(Image.open(f"{GEO}/Geo-Bench-2D/coarse_img/{d}/{i}/{e}.png").convert("RGB"))
        G=np.array(Image.open(bp).convert("RGB"))
        T=np.array(Image.open(f"{GEO}/Geo-Bench-2D/target_mask/{d}/{i}/{e}.png").convert("L"))>127
        interior=cv2.erode(T.astype(np.uint8),np.ones((2*w+1,2*w+1),np.uint8),iterations=1).astype(bool)
        Image.fromarray(np.where(interior[:,:,None],C,G).astype(np.uint8)).save(dst)
    link(tag,root); print("built",tag)

for w in [4,8,16,24]:
    ring(f"RING{w}_MOVE_POST",w)
ring("RING8_GLOBAL_POST",8,True)

def task_model(tag,source,task):
    assert source in roots and inventory[source]["complete"], (source,inventory.get(source))
    root=f"{WORK}/{tag}"; reset(root); srcroot=roots[source]
    for r in picked:
        d,i,e=key(r)
        src=f"{srcroot}/{d}/{i}/{e}.png" if r["edit_type"]==task else f"{BASE}/{d}/{i}/{e}.png"
        dst=f"{root}/{d}/{i}/{e}.png"; os.makedirs(os.path.dirname(dst),exist_ok=True)
        os.symlink(os.path.realpath(src),dst)
    link(tag,root); print("built",tag)

if inventory.get("EXACT_RING8_MOVE",{}).get("complete"):
    task_model("EXACT_RING8_MODEL","EXACT_RING8_MOVE","move")
if inventory.get("AA_RING8_MOVE",{}).get("complete"):
    task_model("AA_RING8_MODEL","AA_RING8_MOVE","move")
if inventory.get("PRES03_GLOBAL",{}).get("complete"):
    task_model("PRES03_MOVE_MODEL","PRES03_GLOBAL","move")

def hard_router(tag,source,task="resize"):
    assert source in roots and inventory[source]["complete"]
    root=f"{WORK}/{tag}"; reset(root); srcroot=roots[source]
    for r in picked:
        d,i,e=key(r)
        use=(r["edit_type"]==task and r["difficulty"]=="hard")
        src=f"{srcroot}/{d}/{i}/{e}.png" if use else f"{BASE}/{d}/{i}/{e}.png"
        dst=f"{root}/{d}/{i}/{e}.png"; os.makedirs(os.path.dirname(dst),exist_ok=True)
        os.symlink(os.path.realpath(src),dst)
    link(tag,root); print("built",tag)

for source,tag in [
    ("EPSREC_R1_ALL","ROUTER_EPSREC_RES_HARD"),
    ("EPSREC_PROMPT_ALL","ROUTER_EPSREC_PROMPT_RES_HARD"),
    ("HF30_EPSREC_R1_ALL","ROUTER_HF30_EPSREC_RES_HARD"),
    ("EPSREC_PURE_ALL","ROUTER_EPSREC_PURE_RES_HARD"),
]:
    if inventory.get(source,{}).get("complete"):
        hard_router(tag,source)

POST=[
    "RING4_MOVE_POST","RING8_MOVE_POST","RING16_MOVE_POST","RING24_MOVE_POST","RING8_GLOBAL_POST",
    "EXACT_RING8_MODEL","AA_RING8_MODEL","PRES03_MOVE_MODEL",
    "ROUTER_EPSREC_RES_HARD","ROUTER_EPSREC_PROMPT_RES_HARD",
    "ROUTER_HF30_EPSREC_RES_HARD","ROUTER_EPSREC_PURE_RES_HARD",
]
POST=[t for t in POST if os.path.exists(f"{EVALROOT}/{t}")]
print("COMPLETE RAW ALL",COMPLETE_ALL)
print("POST",POST)
# Out:
# CFG10_PROMPT_ALL                 200/200 ✓ /kaggle/input/notebooks/giorgostzam/freefine-final-exhaustive-run-account-b-guidan/finalB_guidance_move/variants/CFG10_PROMPT_ALL
# EPSREC_PROMPT_ALL                200/200 ✓ /kaggle/input/notebooks/giorgostzam/freefine-final-exhaustive-run-account-b-guidan/finalB_guidance_move/variants/EPSREC_PROMPT_ALL
# EPSREC_R1_ALL                    200/200 ✓ /kaggle/input/notebooks/giorgostzam/freefine-final-exhaustive-run-account-b-guidan/finalB_guidance_move/variants/EPSREC_R1_ALL
# PRES03_GLOBAL                    200/200 ✓ /kaggle/input/notebooks/giorgostzam/02-w0b-complete-pres03-and-guidance-gaps-t4x2-v1/finalB_guidance_move/variants/PRES03_GLOBAL
# HF30_EPSREC_R1_ALL               200/200 ✓ /kaggle/input/notebooks/giorgostzam/freefine-final-exhaustive-run-account-b-guidan/finalB_guidance_move/variants/HF30_EPSREC_R1_ALL
# HF30_EPSREC_PROMPT_ALL           200/200 ✓ /kaggle/input/notebooks/giorgostzam/freefine-final-exhaustive-run-account-b-guidan/finalB_guidance_move/variants/HF30_EPSREC_PROMPT_ALL
# MIDHF_EPSREC_PROMPT_ALL          200/200 ✓ /kaggle/input/notebooks/giorgostzam/freefine-final-exhaustive-run-account-b-guidan/finalB_guidance_move/variants/MIDHF_EPSREC_PROMPT_ALL
# EPSREC_PURE_ALL                  200/200 ✓ /kaggle/input/notebooks/giorgostzam/02-w0b-complete-pres03-and-guidance-gaps-t4x2-v1/finalB_guidance_move/variants/EPSREC_PURE_ALL
# EPSREC_BETA05_ALL                200/200 ✓ /kaggle/input/notebooks/giorgostzam/02-w0b-complete-pres03-and-guidance-gaps-t4x2-v1/finalB_guidance_move/variants/EPSREC_BETA05_ALL
# APG_NOMOM_ALL                    200/200 ✓ /kaggle/input/notebooks/giorgostzam/02-w0b-complete-pres03-and-guidance-gaps-t4x2-v1/finalB_guidance_move/variants/APG_NOMOM_ALL
# EPSREC_ETA025_ALL                200/200 ✓ /kaggle/input/notebooks/giorgostzam/02-w0b-complete-pres03-and-guidance-gaps-t4x2-v1/finalB_guidance_move/variants/EPSREC_ETA025_ALL
# HF30_EPSREC_PURE_ALL             200/200 ✓ /kaggle/input/notebooks/giorgostzam/02-w0b-complete-pres03-and-guidance-gaps-t4x2-v1/finalB_guidance_move/variants/HF30_EPSREC_PURE_ALL
# MIDHF_EPSREC_PURE_ALL            200/200 ✓ /kaggle/input/notebooks/giorgostzam/02-w0b-complete-pres03-and-guidance-gaps-t4x2-v1/finalB_guidance_move/variants/MIDHF_EPSREC_PURE_ALL
# EXACT_RING8_MOVE                 67/67 ✓ /kaggle/input/notebooks/giorgostzam/freefine-final-exhaustive-run-account-b-guidan/finalB_guidance_move/variants/EXACT_RING8_MOVE
# AA_RING8_MOVE                    67/67 ✓ /kaggle/input/notebooks/giorgostzam/freefine-final-exhaustive-run-account-b-guidan/finalB_guidance_move/variants/AA_RING8_MOVE
# built RING4_MOVE_POST
# built RING8_MOVE_POST
# built RING16_MOVE_POST
# built RING24_MOVE_POST
# built RING8_GLOBAL_POST
# built EXACT_RING8_MODEL
# built AA_RING8_MODEL
# built PRES03_MOVE_MODEL
# built ROUTER_EPSREC_RES_HARD
# built ROUTER_EPSREC_PROMPT_RES_HARD
# built ROUTER_HF30_EPSREC_RES_HARD
# built ROUTER_EPSREC_PURE_RES_HARD
# COMPLETE RAW ALL ['CFG10_PROMPT_ALL', 'EPSREC_PROMPT_ALL', 'EPSREC_R1_ALL', 'PRES03_GLOBAL', 'HF30_EPSREC_R1_ALL', 'HF30_EPSREC_PROMPT_ALL', 'MIDHF_EPSREC_PROMPT_ALL', 'EPSREC_PURE_ALL', 'EPSREC_BETA05_ALL', 'APG_NOMOM_ALL', 'EPSREC_ETA025_ALL', 'HF30_EPSREC_PURE_ALL', 'MIDHF_EPSREC_PURE_ALL']
# POST ['RING4_MOVE_POST', 'RING8_MOVE_POST', 'RING16_MOVE_POST', 'RING24_MOVE_POST', 'RING8_GLOBAL_POST', 'EXACT_RING8_MODEL', 'AA_RING8_MODEL', 'PRES03_MOVE_MODEL', 'ROUTER_EPSREC_RES_HARD', 'ROUTER_EPSREC_PROMPT_RES_HARD', 'ROUTER_HF30_EPSREC_RES_HARD', 'ROUTER_EPSREC_PURE_RES_HARD']

# %% [markdown]
# ## 6. Metric helpers

# %%
# ===== Metric helpers =====
import os,json,re,subprocess,time,threading,queue,pandas as pd
MET="/kaggle/temp/FreeFine/evaluation/metrics"
PY="/kaggle/temp/metric_env/bin/python"
EVALROOT=f"{GEO}/gen_eval"
ann=json.load(open(f"{GEO}/annotation_2d.json"))

def manifest(tag,group_name,ids):
    out={}; base=f"{EVALROOT}/{tag}"; used=0
    for d,i,e in ids:
        gp=f"{base}/{d}/{i}/{e}.png"
        if not os.path.exists(gp): continue
        lf=dict(ann[d]["instances"][i][e])
        lf["gen_img_path"]=f"gen_eval/{tag}/{d}/{i}/{e}.png"
        out.setdefault(d,{"instances":{}})["instances"].setdefault(i,{})[e]=lf
        used+=1
    p=f"{GEO}/m_{re.sub(r'[^A-Za-z0-9_.-]+','_',tag+'_'+group_name)}.json"
    json.dump(out,open(p,"w"))
    return p,used

def run_metric(manifest_path,task,gpu,md_seed=42,metric_seed=42):
    env=os.environ.copy()
    env.update({
        "CUDA_VISIBLE_DEVICES":str(gpu),
        "MPLBACKEND":"Agg",
        "HF_HOME":"/kaggle/temp/hf",
        "TORCH_HOME":"/kaggle/temp/torch",
        "PYTORCH_CUDA_ALLOC_CONF":"expandable_segments:True",
        "FF_MD_SEED":str(md_seed),
        "FF_METRIC_SEED":str(metric_seed),
        "TOKENIZERS_PARALLELISM":"false",
    })
    p=subprocess.run(
        [PY,"main.py","--path",manifest_path,"--use_relative_path","--base_dir",GEO,
         "--fid_path",f"{GEO}/Geo-Bench-2D/source_img_full_v2","--task",task,"--level","0"],
        cwd=MET,env=env,capture_output=True,text=True
    )
    txt=p.stdout+p.stderr
    vals={}
    for k in ["FID_DINO","FID_KD","FID","SUBC","BGC","WRAP_E","MD"]:
        h=re.findall(rf"(?:^|\s){k}:\s*([-\d.eE]+)",txt)
        if h: vals[k]=round(float(h[-1]),4)
    if p.returncode!=0:
        vals["_rc"]=p.returncode; vals["_tail"]=txt[-1800:]
    return vals

def parallel_jobs(jobs,worker_fn,deadline_hours=11.6):
    q=queue.Queue()
    for x in jobs: q.put(x)
    deadline=NB_START+deadline_hours*3600
    def _w(gpu):
        while time.time()<deadline-120:
            try: job=q.get_nowait()
            except queue.Empty: return
            try: worker_fn(gpu,*job)
            finally: q.task_done()
    ts=[threading.Thread(target=_w,args=(g,),daemon=True) for g in [0,1]]
    [t.start() for t in ts]; [t.join() for t in ts]
    return list(q.queue)
print("✓ metric helpers ready")
# Out:
# ✓ metric helpers ready

# %% [markdown]
# ## 7. Run

# %%
# ===== Wave 2 D Difficulty Guidance/Post SHARD 1/4: resumable FID/FDD(DINO)/KD =====
import copy, glob, json, os, pandas as pd

SHARD_ID=3
N_SHARDS=4
RESULT_STEM="B_fid_difficulty_results"
OUT_JSON=f"/kaggle/working/{RESULT_STEM}_shard{SHARD_ID+1}of{N_SHARDS}.json"
OUT_CSV=f"/kaggle/working/{RESULT_STEM}_shard{SHARD_ID+1}of{N_SHARDS}.csv"

EXPECTED_TAGS=['baseline', 'CFG10_PROMPT_ALL', 'EPSREC_PROMPT_ALL', 'EPSREC_R1_ALL', 'PRES03_GLOBAL', 'HF30_EPSREC_R1_ALL', 'HF30_EPSREC_PROMPT_ALL', 'MIDHF_EPSREC_PROMPT_ALL', 'EPSREC_PURE_ALL', 'EPSREC_BETA05_ALL', 'APG_NOMOM_ALL', 'EPSREC_ETA025_ALL', 'HF30_EPSREC_PURE_ALL', 'MIDHF_EPSREC_PURE_ALL', 'RING4_MOVE_POST', 'RING8_MOVE_POST', 'RING16_MOVE_POST', 'RING24_MOVE_POST', 'RING8_GLOBAL_POST', 'EXACT_RING8_MODEL', 'AA_RING8_MODEL', 'PRES03_MOVE_MODEL', 'ROUTER_EPSREC_RES_HARD', 'ROUTER_EPSREC_PROMPT_RES_HARD', 'ROUTER_HF30_EPSREC_RES_HARD', 'ROUTER_EPSREC_PURE_RES_HARD']
FID_GROUPS=['move_easy', 'move_medium', 'move_hard', 'move_nonhard', 'rotate_easy', 'rotate_medium', 'rotate_hard', 'rotate_nonhard', 'resize_easy', 'resize_medium', 'resize_hard', 'resize_nonhard', 'all_easy', 'all_medium', 'all_hard', 'all_nonhard']
TAGS=["baseline"]+[t for t in (COMPLETE_ALL+POST) if os.path.exists(f"{EVALROOT}/{t}")]
TAGS=list(dict.fromkeys(TAGS))

print("Discovered TAGS",len(TAGS),TAGS)
assert set(TAGS)==set(EXPECTED_TAGS), (
    "Model inventory mismatch. Expected exact tag set but got missing/extra tags. "
    f"missing={sorted(set(EXPECTED_TAGS)-set(TAGS))} "
    f"extra={sorted(set(TAGS)-set(EXPECTED_TAGS))}"
)

# Determinism sanity check on the canonical baseline.
m,u=manifest("baseline","all_200",groups["all_200"])
g0=run_metric(m,"100000011",0,42,42)
assert u==200 and all(k in g0 for k in ["FID","FID_DINO","FID_KD"]),g0
print("✓ baseline FID-family sanity",g0)

def valid(v):
    return isinstance(v,dict) and all(k in v for k in ["FID","FID_DINO","FID_KD"]) and v.get("complete_group")

def score_file(p):
    try:
        x=json.load(open(p))
        return sum(valid(v) for gd in x.values() for v in gd.values())
    except Exception:
        return -1

# Optional self-resume: if a previous saved version of THIS SAME shard is attached,
# continue from it instead of recomputing completed cells.
resume_pattern=f"/kaggle/input/**/{RESULT_STEM}_shard{SHARD_ID+1}of{N_SHARDS}.json"
cands=glob.glob(resume_pattern,recursive=True)
if cands:
    best=max(cands,key=score_file)
    results=json.load(open(best))
    print("✓ resuming same shard from",best,"complete cells",score_file(best))
else:
    results={}
    print("Starting fresh shard")

# Deterministic LPT partition weighted by actual subgroup sample count.
all_jobs=[(tag,g) for tag in TAGS for g in FID_GROUPS]
weighted=sorted(
    [(len(groups[g]),tag,g) for tag,g in all_jobs],
    key=lambda x:(-x[0],x[1],x[2])
)
bins=[[] for _ in range(N_SHARDS)]
loads=[0 for _ in range(N_SHARDS)]
for w,tag,g in weighted:
    j=min(range(N_SHARDS),key=lambda z:(loads[z],z))
    bins[j].append((tag,g))
    loads[j]+=w

assigned=bins[SHARD_ID]
jobs=[(tag,g) for tag,g in assigned if not valid(results.get(tag,{}).get(g,{}))]
print("Balanced shard sample-loads:",loads)
print(f"This shard {SHARD_ID+1}/{N_SHARDS}: assigned={len(assigned)} remaining={len(jobs)} weighted_samples={loads[SHARD_ID]}")
print("First assigned jobs:",assigned[:80])

lock=threading.Lock()

def save():
    with lock:
        json.dump(results,open(OUT_JSON,"w"),indent=2)
        rows=[]
        for tag,gd in results.items():
            for g,v in gd.items():
                rows.append({"set":tag,"group":g,**v})
        pd.DataFrame(rows).to_csv(OUT_CSV,index=False)

def work(gpu,tag,g):
    m,u=manifest(tag,g,groups[g])
    if u!=len(groups[g]):
        with lock:
            results.setdefault(tag,{})[g]={
                "n":u,"expected_n":len(groups[g]),"complete_group":False
            }
        save()
        return
    v=run_metric(m,"100000011",gpu,42,42)
    v["n"]=u
    v["expected_n"]=len(groups[g])
    v["complete_group"]=True
    with lock:
        results.setdefault(tag,{})[g]=v
    save()
    print(f"[GPU{gpu}] {tag:34s} {g:16s} -> {v}",flush=True)

remaining=parallel_jobs(jobs,work,11.65)
save()

missing=[]
for tag,g in assigned:
    if not valid(results.get(tag,{}).get(g,{})):
        missing.append((tag,g))

print("SHARD MISSING",len(missing),missing[:200])
print("remaining queue",len(remaining))
print("saved",OUT_JSON,OUT_CSV)
assert not missing, (
    f"Shard {SHARD_ID+1}/{N_SHARDS} still has {len(missing)} missing cells. "
    "Save Version, attach this shard's own saved output, and rerun the SAME notebook; "
    "it will continue only the missing cells."
)
print(f"✓ WAVE 2 D Difficulty Guidance/Post SHARD {SHARD_ID+1}/{N_SHARDS} COMPLETE")
# Out:
# Discovered TAGS 26 ['baseline', 'CFG10_PROMPT_ALL', 'EPSREC_PROMPT_ALL', 'EPSREC_R1_ALL', 'PRES03_GLOBAL', 'HF30_EPSREC_R1_ALL', 'HF30_EPSREC_PROMPT_ALL', 'MIDHF_EPSREC_PROMPT_ALL', 'EPSREC_PURE_ALL', 'EPSREC_BETA05_ALL', 'APG_NOMOM_ALL', 'EPSREC_ETA025_ALL', 'HF30_EPSREC_PURE_ALL', 'MIDHF_EPSREC_PURE_ALL', 'RING4_MOVE_POST', 'RING8_MOVE_POST', 'RING16_MOVE_POST', 'RING24_MOVE_POST', 'RING8_GLOBAL_POST', 'EXACT_RING8_MODEL', 'AA_RING8_MODEL', 'PRES03_MOVE_MODEL', 'ROUTER_EPSREC_RES_HARD', 'ROUTER_EPSREC_PROMPT_RES_HARD', 'ROUTER_HF30_EPSREC_RES_HARD', 'ROUTER_EPSREC_PURE_RES_HARD']
# ✓ baseline FID-family sanity {'FID_DINO': 1636.8248, 'FID_KD': 0.1268, 'FID': 132.279}
# Starting fresh shard
# Balanced shard sample-loads: [4328, 4328, 4330, 4330]
# This shard 4/4: assigned=105 remaining=105 weighted_samples=4330
# First assigned jobs: [('EPSREC_BETA05_ALL', 'all_nonhard'), ('EPSREC_R1_ALL', 'all_nonhard'), ('HF30_EPSREC_R1_ALL', 'all_nonhard'), ('PRES03_MOVE_MODEL', 'all_nonhard'), ('RING8_GLOBAL_POST', 'all_nonhard'), ('ROUTER_EPSREC_RES_HARD', 'all_nonhard'), ('AA_RING8_MODEL', 'all_hard'), ('APG_NOMOM_ALL', 'all_hard'), ('EPSREC_BETA05_ALL', 'all_hard'), ('EPSREC_PROMPT_ALL', 'all_hard'), ('EPSREC_R1_ALL', 'all_hard'), ('HF30_EPSREC_PROMPT_ALL', 'all_hard'), ('HF30_EPSREC_R1_ALL', 'all_hard'), ('MIDHF_EPSREC_PURE_ALL', 'all_hard'), ('PRES03_MOVE_MODEL', 'all_hard'), ('RING24_MOVE_POST', 'all_hard'), ('RING8_GLOBAL_POST', 'all_hard'), ('ROUTER_EPSREC_PROMPT_RES_HARD', 'all_hard'), ('ROUTER_EPSREC_RES_HARD', 'all_hard'), ('baseline', 'all_hard'), ('EPSREC_BETA05_ALL', 'all_medium'), ('EPSREC_R1_ALL', 'all_medium'), ('HF30_EPSREC_R1_ALL', 'all_medium'), ('PRES03_MOVE_MODEL', 'all_medium'), ('RING8_GLOBAL_POST', 'all_medium'), ('ROUTER_EPSREC_RES_HARD', 'all_medium'), ('APG_NOMOM_ALL', 'move_nonhard'), ('EPSREC_BETA05_ALL', 'move_nonhard'), ('EPSREC_R1_ALL', 'move_nonhard'), ('HF30_EPSREC_R1_ALL', 'move_nonhard'), ('PRES03_MOVE_MODEL', 'move_nonhard'), ('RING8_GLOBAL_POST', 'move_nonhard'), ('ROUTER_EPSREC_RES_HARD', 'move_nonhard'), ('AA_RING8_MODEL', 'rotate_nonhard'), ('CFG10_PROMPT_ALL', 'rotate_nonhard'), ('EPSREC_ETA025_ALL', 'rotate_nonhard'), ('EPSREC_PURE_ALL', 'rotate_nonhard'), ('EXACT_RING8_MODEL', 'rotate_nonhard'), ('HF30_EPSREC_PURE_ALL', 'rotate_nonhard'), ('MIDHF_EPSREC_PROMPT_ALL', 'rotate_nonhard'), ('PRES03_GLOBAL', 'rotate_nonhard'), ('RING16_MOVE_POST', 'rotate_nonhard'), ('RING4_MOVE_POST', 'rotate_nonhard'), ('RING8_MOVE_POST', 'rotate_nonhard'), ('ROUTER_EPSREC_PURE_RES_HARD', 'rotate_nonhard'), ('ROUTER_HF30_EPSREC_RES_HARD', 'rotate_nonhard'), ('AA_RING8_MODEL', 'resize_hard'), ('CFG10_PROMPT_ALL', 'resize_hard'), ('EPSREC_ETA025_ALL', 'resize_hard'), ('EPSREC_PURE_ALL', 'resize_hard'), ('EXACT_RING8_MODEL', 'resize_hard'), ('HF30_EPSREC_PURE_ALL', 'resize_hard'), ('MIDHF_EPSREC_PROMPT_ALL', 'resize_hard'), ('PRES03_GLOBAL', 'resize_hard'), ('RING16_MOVE_POST', 'resize_hard'), ('RING4_MOVE_POST', 'resize_hard'), ('RING8_MOVE_POST', 'resize_hard'), ('ROUTER_EPSREC_PURE_RES_HARD', 'resize_hard'), ('ROUTER_HF30_EPSREC_RES_HARD', 'resize_hard'), ('AA_RING8_MODEL', 'move_medium'), ('AA_RING8_MODEL', 'rotate_hard'), ('APG_NOMOM_ALL', 'resize_easy'), ('APG_NOMOM_ALL', 'rotate_medium'), ('CFG10_PROMPT_ALL', 'resize_medium'), ('EPSREC_BETA05_ALL', 'move_hard'), ('EPSREC_BETA05_ALL', 'rotate_easy'), ('EPSREC_ETA025_ALL', 'move_medium'), ('EPSREC_ETA025_ALL', 'rotate_hard'), ('EPSREC_PROMPT_ALL', 'resize_easy'), ('EPSREC_PROMPT_ALL', 'rotate_medium'), ('EPSREC_PURE_ALL', 'resize_medium'), ('EPSREC_R1_ALL', 'move_hard'), ('EPSREC_R1_ALL', 'rotate_easy'), ('EXACT_RING8_MODEL', 'move_medium'), ('EXACT_RING8_MODEL', 'rotate_hard'), ('HF30_EPSREC_PROMPT_ALL', 'resize_easy'), ('HF30_EPSREC_PROMPT_ALL', 'rotate_medium'), ('HF30_EPSREC_PURE_ALL', 'resize_medium'), ('HF30_EPSREC_R1_ALL', 'move_hard'), ('HF30_EPSREC_R1_ALL', 'rotate_easy')]
# [GPU1] EPSREC_R1_ALL                      all_nonhard      -> {'FID_DINO': 1988.8965, 'FID_KD': 0.1824, 'FID': 158.2259, 'n': 133, 'expected_n': 133, 'complete_group': True}
# [GPU0] EPSREC_BETA05_ALL                  all_nonhard      -> {'FID_DINO': 1989.033, 'FID_KD': 0.1785, 'FID': 157.4796, 'n': 133, 'expected_n': 133, 'complete_group': True}
# [GPU1] HF30_EPSREC_R1_ALL                 all_nonhard      -> {'FID_DINO': 1988.9295, 'FID_KD': 0.1825, 'FID': 158.2166, 'n': 133, 'expected_n': 133, 'complete_group': True}
# [GPU0] PRES03_MOVE_MODEL                  all_nonhard      -> {'FID_DINO': 1988.2861, 'FID_KD': 0.1828, 'FID': 158.1843, 'n': 133, 'expected_n': 133, 'complete_group': True}
# [GPU1] RING8_GLOBAL_POST                  all_nonhard      -> {'FID_DINO': 1991.8289, 'FID_KD': 0.178, 'FID': 158.214, 'n': 133, 'expected_n': 133, 'complete_group': True}
# [GPU0] ROUTER_EPSREC_RES_HARD             all_nonhard      -> {'FID_DINO': 1989.0325, 'FID_KD': 0.1785, 'FID': 157.4796, 'n': 133, 'expected_n': 133, 'complete_group': True}
# [GPU1] AA_RING8_MODEL                     all_hard         -> {'FID_DINO': 2484.3191, 'FID_KD': 0.0974, 'FID': 209.6862, 'n': 67, 'expected_n': 67, 'complete_group': True}
# [GPU0] APG_NOMOM_ALL                      all_hard         -> {'FID_DINO': 2481.9608, 'FID_KD': 0.0964, 'FID': 209.9336, 'n': 67, 'expected_n': 67, 'complete_group': True}
# [GPU1] EPSREC_BETA05_ALL                  all_hard         -> {'FID_DINO': 2481.9608, 'FID_KD': 0.0964, 'FID': 209.9336, 'n': 67, 'expected_n': 67, 'complete_group': True}
# [GPU0] EPSREC_PROMPT_ALL                  all_hard         -> {'FID_DINO': 2486.7308, 'FID_KD': 0.0968, 'FID': 209.7075, 'n': 67, 'expected_n': 67, 'complete_group': True}
# [GPU1] EPSREC_R1_ALL                      all_hard         -> {'FID_DINO': 2485.3221, 'FID_KD': 0.1036, 'FID': 209.0312, 'n': 67, 'expected_n': 67, 'complete_group': True}
# [GPU0] HF30_EPSREC_PROMPT_ALL             all_hard         -> {'FID_DINO': 2486.6075, 'FID_KD': 0.0968, 'FID': 209.6652, 'n': 67, 'expected_n': 67, 'complete_group': True}
# [GPU1] HF30_EPSREC_R1_ALL                 all_hard         -> {'FID_DINO': 2485.232, 'FID_KD': 0.1036, 'FID': 208.9801, 'n': 67, 'expected_n': 67, 'complete_group': True}
# [GPU0] MIDHF_EPSREC_PURE_ALL              all_hard         -> {'FID_DINO': 2482.0224, 'FID_KD': 0.0966, 'FID': 209.9179, 'n': 67, 'expected_n': 67, 'complete_group': True}
# [GPU1] PRES03_MOVE_MODEL                  all_hard         -> {'FID_DINO': 2481.6231, 'FID_KD': 0.1021, 'FID': 209.5179, 'n': 67, 'expected_n': 67, 'complete_group': True}
# [GPU0] RING24_MOVE_POST                   all_hard         -> {'FID_DINO': 2484.1011, 'FID_KD': 0.0972, 'FID': 209.9196, 'n': 67, 'expected_n': 67, 'complete_group': True}
# [GPU1] RING8_GLOBAL_POST                  all_hard         -> {'FID_DINO': 2485.2568, 'FID_KD': 0.0987, 'FID': 209.3435, 'n': 67, 'expected_n': 67, 'complete_group': True}
# [GPU0] ROUTER_EPSREC_PROMPT_RES_HARD      all_hard         -> {'FID_DINO': 2485.7075, 'FID_KD': 0.0978, 'FID': 209.4665, 'n': 67, 'expected_n': 67, 'complete_group': True}
# [GPU1] ROUTER_EPSREC_RES_HARD             all_hard         -> {'FID_DINO': 2485.7075, 'FID_KD': 0.0978, 'FID': 209.4665, 'n': 67, 'expected_n': 67, 'complete_group': True}
# [GPU0] baseline                           all_hard         -> {'FID_DINO': 2481.962, 'FID_KD': 0.0964, 'FID': 209.934, 'n': 67, 'expected_n': 67, 'complete_group': True}
# [GPU1] EPSREC_BETA05_ALL                  all_medium       -> {'FID_DINO': 2473.3719, 'FID_KD': 0.1267, 'FID': 198.8772, 'n': 66, 'expected_n': 66, 'complete_group': True}
# [GPU0] EPSREC_R1_ALL                      all_medium       -> {'FID_DINO': 2474.3251, 'FID_KD': 0.1313, 'FID': 200.0176, 'n': 66, 'expected_n': 66, 'complete_group': True}
# [GPU1] HF30_EPSREC_R1_ALL                 all_medium       -> {'FID_DINO': 2474.3928, 'FID_KD': 0.1313, 'FID': 199.9928, 'n': 66, 'expected_n': 66, 'complete_group': True}
# [GPU0] PRES03_MOVE_MODEL                  all_medium       -> {'FID_DINO': 2471.4322, 'FID_KD': 0.131, 'FID': 200.2088, 'n': 66, 'expected_n': 66, 'complete_group': True}
# [GPU1] RING8_GLOBAL_POST                  all_medium       -> {'FID_DINO': 2473.4652, 'FID_KD': 0.125, 'FID': 199.5462, 'n': 66, 'expected_n': 66, 'complete_group': True}
# [GPU0] ROUTER_EPSREC_RES_HARD             all_medium       -> {'FID_DINO': 2473.372, 'FID_KD': 0.1267, 'FID': 198.8771, 'n': 66, 'expected_n': 66, 'complete_group': True}
# [GPU1] APG_NOMOM_ALL                      move_nonhard     -> {'FID_DINO': 2780.046, 'FID_KD': 0.1037, 'FID': 220.0889, 'n': 45, 'expected_n': 45, 'complete_group': True}
# [GPU0] EPSREC_BETA05_ALL                  move_nonhard     -> {'FID_DINO': 2780.046, 'FID_KD': 0.1037, 'FID': 220.0889, 'n': 45, 'expected_n': 45, 'complete_group': True}
# [GPU1] EPSREC_R1_ALL                      move_nonhard     -> {'FID_DINO': 2777.3295, 'FID_KD': 0.1172, 'FID': 222.565, 'n': 45, 'expected_n': 45, 'complete_group': True}
# [GPU0] HF30_EPSREC_R1_ALL                 move_nonhard     -> {'FID_DINO': 2777.3782, 'FID_KD': 0.1173, 'FID': 222.5778, 'n': 45, 'expected_n': 45, 'complete_group': True}
# [GPU1] PRES03_MOVE_MODEL                  move_nonhard     -> {'FID_DINO': 2777.3295, 'FID_KD': 0.1172, 'FID': 222.565, 'n': 45, 'expected_n': 45, 'complete_group': True}
# [GPU0] RING8_GLOBAL_POST                  move_nonhard     -> {'FID_DINO': 2783.6277, 'FID_KD': 0.0984, 'FID': 221.4074, 'n': 45, 'expected_n': 45, 'complete_group': True}
# [GPU1] ROUTER_EPSREC_RES_HARD             move_nonhard     -> {'FID_DINO': 2780.0456, 'FID_KD': 0.1037, 'FID': 220.0886, 'n': 45, 'expected_n': 45, 'complete_group': True}
# [GPU0] AA_RING8_MODEL                     rotate_nonhard   -> {'FID_DINO': 2731.281, 'FID_KD': 0.099, 'FID': 231.6236, 'n': 44, 'expected_n': 44, 'complete_group': True}
# [GPU1] CFG10_PROMPT_ALL                   rotate_nonhard   -> {'FID_DINO': 2734.2916, 'FID_KD': 0.0981, 'FID': 231.5499, 'n': 44, 'expected_n': 44, 'complete_group': True}
# [GPU0] EPSREC_ETA025_ALL                  rotate_nonhard   -> {'FID_DINO': 2731.2843, 'FID_KD': 0.099, 'FID': 231.624, 'n': 44, 'expected_n': 44, 'complete_group': True}
# [GPU1] EPSREC_PURE_ALL                    rotate_nonhard   -> {'FID_DINO': 2731.2843, 'FID_KD': 0.099, 'FID': 231.624, 'n': 44, 'expected_n': 44, 'complete_group': True}
# [GPU0] EXACT_RING8_MODEL                  rotate_nonhard   -> {'FID_DINO': 2731.281, 'FID_KD': 0.099, 'FID': 231.6236, 'n': 44, 'expected_n': 44, 'complete_group': True}
# [GPU1] HF30_EPSREC_PURE_ALL               rotate_nonhard   -> {'FID_DINO': 2731.3082, 'FID_KD': 0.0993, 'FID': 231.6319, 'n': 44, 'expected_n': 44, 'complete_group': True}
# [GPU0] MIDHF_EPSREC_PROMPT_ALL            rotate_nonhard   -> {'FID_DINO': 2733.1853, 'FID_KD': 0.0983, 'FID': 231.5519, 'n': 44, 'expected_n': 44, 'complete_group': True}
# [GPU1] PRES03_GLOBAL                      rotate_nonhard   -> {'FID_DINO': 2735.5965, 'FID_KD': 0.1091, 'FID': 234.2813, 'n': 44, 'expected_n': 44, 'complete_group': True}
# [GPU0] RING16_MOVE_POST                   rotate_nonhard   -> {'FID_DINO': 2731.281, 'FID_KD': 0.099, 'FID': 231.6236, 'n': 44, 'expected_n': 44, 'complete_group': True}
# [GPU1] RING4_MOVE_POST                    rotate_nonhard   -> {'FID_DINO': 2731.281, 'FID_KD': 0.099, 'FID': 231.6236, 'n': 44, 'expected_n': 44, 'complete_group': True}
# [GPU0] RING8_MOVE_POST                    rotate_nonhard   -> {'FID_DINO': 2731.281, 'FID_KD': 0.099, 'FID': 231.6236, 'n': 44, 'expected_n': 44, 'complete_group': True}
# [GPU1] ROUTER_EPSREC_PURE_RES_HARD        rotate_nonhard   -> {'FID_DINO': 2731.281, 'FID_KD': 0.099, 'FID': 231.6236, 'n': 44, 'expected_n': 44, 'complete_group': True}
# [GPU0] ROUTER_HF30_EPSREC_RES_HARD        rotate_nonhard   -> {'FID_DINO': 2731.281, 'FID_KD': 0.099, 'FID': 231.6236, 'n': 44, 'expected_n': 44, 'complete_group': True}
# [GPU1] AA_RING8_MODEL                     resize_hard      -> {'FID_DINO': 3173.6142, 'FID_KD': 0.0433, 'FID': 274.3424, 'n': 23, 'expected_n': 23, 'complete_group': True}
# [GPU0] CFG10_PROMPT_ALL                   resize_hard      -> {'FID_DINO': 3181.5005, 'FID_KD': 0.046, 'FID': 271.8452, 'n': 23, 'expected_n': 23, 'complete_group': True}
# [GPU1] EPSREC_ETA025_ALL                  resize_hard      -> {'FID_DINO': 3173.6111, 'FID_KD': 0.0433, 'FID': 274.3422, 'n': 23, 'expected_n': 23, 'complete_group': True}
# [GPU0] EPSREC_PURE_ALL                    resize_hard      -> {'FID_DINO': 3173.6111, 'FID_KD': 0.0433, 'FID': 274.3422, 'n': 23, 'expected_n': 23, 'complete_group': True}
# [GPU1] EXACT_RING8_MODEL                  resize_hard      -> {'FID_DINO': 3173.6142, 'FID_KD': 0.0433, 'FID': 274.3424, 'n': 23, 'expected_n': 23, 'complete_group': True}
# [GPU0] HF30_EPSREC_PURE_ALL               resize_hard      -> {'FID_DINO': 3173.6335, 'FID_KD': 0.0433, 'FID': 274.3445, 'n': 23, 'expected_n': 23, 'complete_group': True}
# [GPU1] MIDHF_EPSREC_PROMPT_ALL            resize_hard      -> {'FID_DINO': 3181.3228, 'FID_KD': 0.0488, 'FID': 272.7497, 'n': 23, 'expected_n': 23, 'complete_group': True}
# [GPU0] PRES03_GLOBAL                      resize_hard      -> {'FID_DINO': 3170.5003, 'FID_KD': 0.055, 'FID': 274.2107, 'n': 23, 'expected_n': 23, 'complete_group': True}
# [GPU1] RING16_MOVE_POST                   resize_hard      -> {'FID_DINO': 3173.6142, 'FID_KD': 0.0433, 'FID': 274.3424, 'n': 23, 'expected_n': 23, 'complete_group': True}
# [GPU0] RING4_MOVE_POST                    resize_hard      -> {'FID_DINO': 3173.6142, 'FID_KD': 0.0433, 'FID': 274.3424, 'n': 23, 'expected_n': 23, 'complete_group': True}
# [GPU1] RING8_MOVE_POST                    resize_hard      -> {'FID_DINO': 3173.6142, 'FID_KD': 0.0433, 'FID': 274.3424, 'n': 23, 'expected_n': 23, 'complete_group': True}
# [GPU0] ROUTER_EPSREC_PURE_RES_HARD        resize_hard      -> {'FID_DINO': 3173.6111, 'FID_KD': 0.0433, 'FID': 274.3422, 'n': 23, 'expected_n': 23, 'complete_group': True}
# [GPU1] ROUTER_HF30_EPSREC_RES_HARD        resize_hard      -> {'FID_DINO': 3181.3174, 'FID_KD': 0.0486, 'FID': 272.6952, 'n': 23, 'expected_n': 23, 'complete_group': True}
# [GPU0] AA_RING8_MODEL                     move_medium      -> {'FID_DINO': 3278.6124, 'FID_KD': 0.1232, 'FID': 260.544, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] AA_RING8_MODEL                     rotate_hard      -> {'FID_DINO': 3313.3242, 'FID_KD': 0.2093, 'FID': 273.6189, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU0] APG_NOMOM_ALL                      resize_easy      -> {'FID_DINO': 3236.0243, 'FID_KD': 0.1168, 'FID': 259.4084, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] APG_NOMOM_ALL                      rotate_medium    -> {'FID_DINO': 3195.606, 'FID_KD': -0.0448, 'FID': 275.7461, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU0] CFG10_PROMPT_ALL                   resize_medium    -> {'FID_DINO': 3143.1281, 'FID_KD': 0.0895, 'FID': 262.3639, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] EPSREC_BETA05_ALL                  move_hard        -> {'FID_DINO': 3163.8655, 'FID_KD': -0.0719, 'FID': 279.8618, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU0] EPSREC_BETA05_ALL                  rotate_easy      -> {'FID_DINO': 3149.7362, 'FID_KD': 0.3529, 'FID': 275.7821, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] EPSREC_ETA025_ALL                  move_medium      -> {'FID_DINO': 3277.0151, 'FID_KD': 0.1392, 'FID': 258.6921, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU0] EPSREC_ETA025_ALL                  rotate_hard      -> {'FID_DINO': 3313.3225, 'FID_KD': 0.2093, 'FID': 273.6194, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] EPSREC_PROMPT_ALL                  resize_easy      -> {'FID_DINO': 3235.1304, 'FID_KD': 0.1168, 'FID': 259.7312, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU0] EPSREC_PROMPT_ALL                  rotate_medium    -> {'FID_DINO': 3196.4725, 'FID_KD': -0.0426, 'FID': 275.7889, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] EPSREC_PURE_ALL                    resize_medium    -> {'FID_DINO': 3131.2922, 'FID_KD': 0.0952, 'FID': 262.3727, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU0] EPSREC_R1_ALL                      move_hard        -> {'FID_DINO': 3162.7635, 'FID_KD': -0.0592, 'FID': 277.4351, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] EPSREC_R1_ALL                      rotate_easy      -> {'FID_DINO': 3149.731, 'FID_KD': 0.3529, 'FID': 275.7824, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU0] EXACT_RING8_MODEL                  move_medium      -> {'FID_DINO': 3277.9255, 'FID_KD': 0.1245, 'FID': 259.3748, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] EXACT_RING8_MODEL                  rotate_hard      -> {'FID_DINO': 3313.3242, 'FID_KD': 0.2093, 'FID': 273.6189, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU0] HF30_EPSREC_PROMPT_ALL             resize_easy      -> {'FID_DINO': 3235.157, 'FID_KD': 0.1169, 'FID': 259.7257, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] HF30_EPSREC_PROMPT_ALL             rotate_medium    -> {'FID_DINO': 3196.6356, 'FID_KD': -0.0424, 'FID': 275.72, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU0] HF30_EPSREC_PURE_ALL               resize_medium    -> {'FID_DINO': 3131.464, 'FID_KD': 0.0956, 'FID': 262.3131, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] HF30_EPSREC_R1_ALL                 move_hard        -> {'FID_DINO': 3162.6876, 'FID_KD': -0.0591, 'FID': 277.4173, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU0] HF30_EPSREC_R1_ALL                 rotate_easy      -> {'FID_DINO': 3149.6107, 'FID_KD': 0.3531, 'FID': 275.8063, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] MIDHF_EPSREC_PROMPT_ALL            move_medium      -> {'FID_DINO': 3276.662, 'FID_KD': 0.1365, 'FID': 258.1561, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU0] MIDHF_EPSREC_PROMPT_ALL            rotate_hard      -> {'FID_DINO': 3315.219, 'FID_KD': 0.2017, 'FID': 273.758, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] MIDHF_EPSREC_PURE_ALL              resize_easy      -> {'FID_DINO': 3236.0052, 'FID_KD': 0.1169, 'FID': 259.4232, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU0] MIDHF_EPSREC_PURE_ALL              rotate_medium    -> {'FID_DINO': 3195.7369, 'FID_KD': -0.0446, 'FID': 275.7668, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] PRES03_GLOBAL                      resize_medium    -> {'FID_DINO': 3138.0924, 'FID_KD': 0.1097, 'FID': 267.3993, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU0] PRES03_MOVE_MODEL                  move_hard        -> {'FID_DINO': 3162.7635, 'FID_KD': -0.0592, 'FID': 277.4351, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] PRES03_MOVE_MODEL                  rotate_easy      -> {'FID_DINO': 3149.731, 'FID_KD': 0.3529, 'FID': 275.7824, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU0] RING16_MOVE_POST                   move_medium      -> {'FID_DINO': 3277.4385, 'FID_KD': 0.1264, 'FID': 261.5248, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] RING16_MOVE_POST                   rotate_hard      -> {'FID_DINO': 3313.3242, 'FID_KD': 0.2093, 'FID': 273.6189, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU0] RING24_MOVE_POST                   resize_easy      -> {'FID_DINO': 3236.0256, 'FID_KD': 0.1168, 'FID': 259.4123, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] RING24_MOVE_POST                   rotate_medium    -> {'FID_DINO': 3195.6048, 'FID_KD': -0.0448, 'FID': 275.7454, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU0] RING4_MOVE_POST                    resize_medium    -> {'FID_DINO': 3131.2903, 'FID_KD': 0.0952, 'FID': 262.3714, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] RING8_GLOBAL_POST                  move_hard        -> {'FID_DINO': 3173.1944, 'FID_KD': -0.0657, 'FID': 278.0818, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU0] RING8_GLOBAL_POST                  rotate_easy      -> {'FID_DINO': 3156.4679, 'FID_KD': 0.3505, 'FID': 277.1813, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] RING8_MOVE_POST                    move_medium      -> {'FID_DINO': 3277.9255, 'FID_KD': 0.1245, 'FID': 259.3748, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU0] RING8_MOVE_POST                    rotate_hard      -> {'FID_DINO': 3313.3242, 'FID_KD': 0.2093, 'FID': 273.6189, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] ROUTER_EPSREC_PROMPT_RES_HARD      resize_easy      -> {'FID_DINO': 3236.0256, 'FID_KD': 0.1168, 'FID': 259.4123, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU0] ROUTER_EPSREC_PROMPT_RES_HARD      rotate_medium    -> {'FID_DINO': 3195.6048, 'FID_KD': -0.0448, 'FID': 275.7454, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] ROUTER_EPSREC_PURE_RES_HARD        resize_medium    -> {'FID_DINO': 3131.2903, 'FID_KD': 0.0952, 'FID': 262.3714, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU0] ROUTER_EPSREC_RES_HARD             move_hard        -> {'FID_DINO': 3163.8624, 'FID_KD': -0.0719, 'FID': 279.8631, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] ROUTER_EPSREC_RES_HARD             rotate_easy      -> {'FID_DINO': 3149.731, 'FID_KD': 0.3529, 'FID': 275.7824, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU0] ROUTER_HF30_EPSREC_RES_HARD        move_medium      -> {'FID_DINO': 3277.0153, 'FID_KD': 0.1392, 'FID': 258.6933, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] ROUTER_HF30_EPSREC_RES_HARD        rotate_hard      -> {'FID_DINO': 3313.3242, 'FID_KD': 0.2093, 'FID': 273.6189, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU0] baseline                           resize_easy      -> {'FID_DINO': 3236.0256, 'FID_KD': 0.1168, 'FID': 259.4123, 'n': 22, 'expected_n': 22, 'complete_group': True}
# [GPU1] baseline                           rotate_medium    -> {'FID_DINO': 3195.6048, 'FID_KD': -0.0448, 'FID': 275.7454, 'n': 22, 'expected_n': 22, 'complete_group': True}
# SHARD MISSING 0 []
# remaining queue 0
# saved /kaggle/working/B_fid_difficulty_results_shard4of4.json /kaggle/working/B_fid_difficulty_results_shard4of4.csv
# ✓ WAVE 2 D Difficulty Guidance/Post SHARD 4/4 COMPLETE
